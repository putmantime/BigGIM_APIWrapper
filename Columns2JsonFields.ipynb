# %%
import requests
from pprint import pprint
import json
import pandas as pd

# %%
uberon_bto_map = json.loads(open ('bto_uberon_bg.json').read())

# %%
def id2term(var, key, return_key, json_blob):
    """
    check json map of uberbon, bto an bg terms for id
    :param var: identifier
    :param key: source of identifier
    :param return_key: key to return in matched object
    :param json_blob: json to search
    :return: bg term name if mapping to that id exists, input var if no mapping exists
    """
    result = None
    for obj in json_blob:
        if obj[key] == var:
            result = obj[return_key]
    return result

# %%
tables = requests.get('http://127.0.0.1:5000/metadata/table').json()

# %%
table_names = list()
for table in tables:
    table_names.append(table['name'])
table_names
# Out:
# ['BigGIM_70_v1',
#  'BigGIM_80_v1',
#  'BigGIM_90_v1',
#  'BigGIM_v1',
#  'CRC_70_v1',
#  'CRC_80_v1',
#  'CRC_90_v1',
#  'CRC_v1',
#  'FA_70_v1',
#  'FA_80_v1',
#  'FA_90_v1',
#  'FA_v1']

# %%
all_columns = list()
sep_columns = dict()
for tn in table_names:
    sep_columns[tn] = list()
    bg_table = requests.get('http://127.0.0.1:5000/metadata/table/{}'.format(tn)).json()
    for column in bg_table['columns']:
        all_columns.append(column['name'])
        sep_columns[tn].append(column['name'])

# %%
bg_columns_set = list(set(all_columns))

# %%
for cs in bg_columns_set:
    if 'BioGRID' in cs:
        print(cs)
# Out:
# BioGRID_Experimental_System_Type
# BioGRID_Interaction
# BioGRID_Throughput
# BioGRID_Experimental_System

# %%
bg_columns_set
# Out:
# ['GIANT_tear_gland_ProbabilityOfFunctionalInteraction',
#  'GTEx_Nerve_Pvalue',
#  'GIANT_medulla_oblongata_ProbabilityOfFunctionalInteraction',
#  'GIANT_thyroid_gland_ProbabilityOfFunctionalInteraction',
#  'GIANT_blood_vessel_KnownFunctionalInteraction',
#  'GIANT_basophil_ProbabilityOfFunctionalInteraction',
#  'GIANT_testis_ProbabilityOfFunctionalInteraction',
#  'GIANT_glia_KnownFunctionalInteraction',
#  'GIANT_all_tissues_KnownFunctionalInteraction',
#  'TCGA_PRAD_Pvalue',
#  'GIANT_occipital_pole_KnownFunctionalInteraction',
#  'GTEx_Breast_Pvalue',
#  'TCGA_COAD_Correlation',
#  'GIANT_large_intestine_KnownFunctionalInteraction',
#  'GIANT_megakaryocyte_KnownFunctionalInteraction',
#  'GIANT_skeletal_muscle_ProbabilityOfFunctionalInteraction',
#  'GTEx_Adipose_Tissue_Pvalue',
#  'GIANT_cardiac_muscle_ProbabilityOfFunctionalInteraction',
#  'GIANT_telencephalon_ProbabilityOfFunctionalInteraction',
#  'GIANT_oviduct_KnownFunctionalInteraction',
#  'GIANT_cecum_KnownFunctionalInteraction',
#  'GIANT_corpus_callosum_ProbabilityOfFunctionalInteraction',
#  'GIANT_hepatocyte_KnownFunctionalInteraction',
#  'GIANT_prostate_gland_KnownFunctionalInteraction',
#  'GIANT_thymocyte_KnownFunctionalInteraction',
#  'GIANT_corpus_striatum_ProbabilityOfFunctionalInteraction',
#  'GIANT_cochlea_KnownFunctionalInteraction',
#  'GIANT_bone_marrow_ProbabilityOfFunctionalInteraction',
#  'GIANT_skin_ProbabilityOfFunctionalInteraction',
#  'GIANT_tooth_ProbabilityOfFunctionalInteraction',
#  'GIANT_b_lymphocyte_ProbabilityOfFunctionalInteraction',
#  'TCGA_UCEC_Correlation',
#  'TCGA_KICH_Pvalue',
#  'GIANT_granulocyte_KnownFunctionalInteraction',
#  'GIANT_subthalamic_nucleus_ProbabilityOfFunctionalInteraction',
#  'TCGA_MESO_Correlation',
#  'GTEx_Stomach_Pvalue',
#  'TCGA_LUAD_Pvalue',
#  'GIANT_urinary_bladder_KnownFunctionalInteraction',
#  'GIANT_stomach_KnownFunctionalInteraction',
#  'BioGRID_Experimental_System_Type',
#  'GIANT_substantia_nigra_ProbabilityOfFunctionalInteraction',
#  'GIANT_uterine_endometrium_KnownFunctionalInteraction',
#  'GIANT_spermatogonium_KnownFunctionalInteraction',
#  'GTEx_Muscle_Pvalue',
#  'GIANT_spermatid_KnownFunctionalInteraction',
#  'TCGA_COAD_Pvalue',
#  'GIANT_muscle_ProbabilityOfFunctionalInteraction',
#  'GIANT_parietal_lobe_KnownFunctionalInteraction',
#  'GIANT_hypothalamus_KnownFunctionalInteraction',
#  'GIANT_placenta_ProbabilityOfFunctionalInteraction',
#  'TCGA_CESC_Pvalue',
#  'GIANT_adrenal_gland_KnownFunctionalInteraction',
#  'GIANT_osteoblast_ProbabilityOfFunctionalInteraction',
#  'GIANT_peripheral_nervous_system_ProbabilityOfFunctionalInteraction',
#  'GIANT_ovarian_follicle_ProbabilityOfFunctionalInteraction',
#  'GIANT_diencephalon_ProbabilityOfFunctionalInteraction',
#  'GIANT_mammary_gland_KnownFunctionalInteraction',
#  'TCGA_UVM_Pvalue',
#  'GIANT_renal_glomerulus_ProbabilityOfFunctionalInteraction',
#  'GIANT_heart_KnownFunctionalInteraction',
#  'GIANT_hair_follicle_ProbabilityOfFunctionalInteraction',
#  'GIANT_corpus_callosum_KnownFunctionalInteraction',
#  'GIANT_monocyte_ProbabilityOfFunctionalInteraction',
#  'GIANT_esophagus_ProbabilityOfFunctionalInteraction',
#  'GIANT_ovarian_follicle_KnownFunctionalInteraction',
#  'GTEx_Esophagus_Correlation',
#  'GIANT_lymph_node_KnownFunctionalInteraction',
#  'GIANT_natural_killer_cell_ProbabilityOfFunctionalInteraction',
#  'GIANT_jejunum_KnownFunctionalInteraction',
#  'TCGA_UCS_Pvalue',
#  'GIANT_choroid_ProbabilityOfFunctionalInteraction',
#  'GIANT_urinary_bladder_ProbabilityOfFunctionalInteraction',
#  'GIANT_cartilage_ProbabilityOfFunctionalInteraction',
#  'GIANT_smooth_muscle_ProbabilityOfFunctionalInteraction',
#  'GIANT_bronchus_ProbabilityOfFunctionalInteraction',
#  'GIANT_aorta_KnownFunctionalInteraction',
#  'GIANT_nervous_system_KnownFunctionalInteraction',
#  'GTEx_Blood_Vessel_Correlation',
#  'GIANT_serum_ProbabilityOfFunctionalInteraction',
#  'GIANT_colon_KnownFunctionalInteraction',
#  'TCGA_BLCA_Correlation',
#  'GIANT_vascular_endothelium_KnownFunctionalInteraction',
#  'GIANT_vermiform_appendix_ProbabilityOfFunctionalInteraction',
#  'GIANT_brain_KnownFunctionalInteraction',
#  'GTEx_Heart_Correlation',
#  'GIANT_natural_killer_cell_KnownFunctionalInteraction',
#  'GIANT_placenta_KnownFunctionalInteraction',
#  'GIANT_basal_ganglion_KnownFunctionalInteraction',
#  'TCGA_KIRP_Pvalue',
#  'GIANT_basophil_KnownFunctionalInteraction',
#  'GIANT_occipital_lobe_ProbabilityOfFunctionalInteraction',
#  'GIANT_mononuclear_phagocyte_KnownFunctionalInteraction',
#  'GIANT_nucleus_accumbens_ProbabilityOfFunctionalInteraction',
#  'GTEx_Prostate_Correlation',
#  'GIANT_nucleus_accumbens_KnownFunctionalInteraction',
#  'GTEx_Esophagus_Pvalue',
#  'GIANT_lymphocyte_ProbabilityOfFunctionalInteraction',
#  'GIANT_neutrophil_ProbabilityOfFunctionalInteraction',
#  'TCGA_BRCA_Pvalue',
#  'GIANT_large_intestine_ProbabilityOfFunctionalInteraction',
#  'GIANT_trophoblast_ProbabilityOfFunctionalInteraction',
#  'GIANT_trophoblast_KnownFunctionalInteraction',
#  'GIANT_myometrium_ProbabilityOfFunctionalInteraction',
#  'GIANT_hypophysis_KnownFunctionalInteraction',
#  'GIANT_locus_ceruleus_KnownFunctionalInteraction',
#  'TCGA_PCPG_Correlation',
#  'GTEx_Thyroid_Pvalue',
#  'TCGA_PCPG_Pvalue',
#  'GTEx_Pituitary_Pvalue',
#  'TCGA_SKCM_Pvalue',
#  'TCGA_STAD_Pvalue',
#  'GIANT_retina_ProbabilityOfFunctionalInteraction',
#  'GIANT_mononuclear_phagocyte_ProbabilityOfFunctionalInteraction',
#  'GIANT_uterine_endometrium_ProbabilityOfFunctionalInteraction',
#  'GIANT_thymocyte_ProbabilityOfFunctionalInteraction',
#  'GIANT_umbilical_cord_ProbabilityOfFunctionalInteraction',
#  'GIANT_forebrain_KnownFunctionalInteraction',
#  'GIANT_hematopoietic_stem_cell_ProbabilityOfFunctionalInteraction',
#  'GIANT_frontal_lobe_ProbabilityOfFunctionalInteraction',
#  'GIANT_bronchial_epithelial_cell_ProbabilityOfFunctionalInteraction',
#  'GTEx_Thyroid_Correlation',
#  'GIANT_adrenal_cortex_KnownFunctionalInteraction',
#  'GIANT_myometrium_KnownFunctionalInteraction',
#  'TCGA_SARC_Pvalue',
#  'GIANT_subthalamic_nucleus_KnownFunctionalInteraction',
#  'GIANT_cerebellum_ProbabilityOfFunctionalInteraction',
#  'GIANT_spermatocyte_KnownFunctionalInteraction',
#  'GIANT_vermiform_appendix_KnownFunctionalInteraction',
#  'TCGA_READ_Correlation',
#  'GIANT_keratinocyte_KnownFunctionalInteraction',
#  'GIANT_uterine_cervix_ProbabilityOfFunctionalInteraction',
#  'GIANT_b_lymphocyte_KnownFunctionalInteraction',
#  'GIANT_uterine_cervix_KnownFunctionalInteraction',
#  'GIANT_pancreatic_islet_ProbabilityOfFunctionalInteraction',
#  'GIANT_trachea_ProbabilityOfFunctionalInteraction',
#  'GIANT_salivary_gland_ProbabilityOfFunctionalInteraction',
#  'GTEx_Brain_Pvalue',
#  'GIANT_pancreas_ProbabilityOfFunctionalInteraction',
#  'GTEx_Blood_Correlation',
#  'TCGA_THCA_Pvalue',
#  'GIANT_diencephalon_KnownFunctionalInteraction',
#  'GIANT_uterus_KnownFunctionalInteraction',
#  'GIANT_hippocampus_KnownFunctionalInteraction',
#  'GIANT_mast_cell_ProbabilityOfFunctionalInteraction',
#  'GIANT_caudate_nucleus_ProbabilityOfFunctionalInteraction',
#  'GIANT_fetus_KnownFunctionalInteraction',
#  'GIANT_embryo_KnownFunctionalInteraction',
#  'GIANT_t_lymphocyte_KnownFunctionalInteraction',
#  'GIANT_nervous_system_ProbabilityOfFunctionalInteraction',
#  'TCGA_MESO_Pvalue',
#  'GIANT_skin_fibroblast_ProbabilityOfFunctionalInteraction',
#  'GIANT_mammary_epithelium_ProbabilityOfFunctionalInteraction',
#  'GIANT_temporal_lobe_ProbabilityOfFunctionalInteraction',
#  'TCGA_ESCA_Pvalue',
#  'GIANT_umbilical_vein_endothelial_cell_KnownFunctionalInteraction',
#  'GIANT_lens_KnownFunctionalInteraction',
#  'TCGA_CESC_Correlation',
#  'GIANT_serum_KnownFunctionalInteraction',
#  'GIANT_spleen_KnownFunctionalInteraction',
#  'GIANT_temporal_lobe_KnownFunctionalInteraction',
#  'TCGA_BRCA_Correlation',
#  'GIANT_spinal_cord_ProbabilityOfFunctionalInteraction',
#  'GIANT_ear_ProbabilityOfFunctionalInteraction',
#  'GIANT_skin_KnownFunctionalInteraction',
#  'GIANT_cerebral_cortex_KnownFunctionalInteraction',
#  'GIANT_monocyte_KnownFunctionalInteraction',
#  'GIANT_frontal_lobe_KnownFunctionalInteraction',
#  'GIANT_skin_fibroblast_KnownFunctionalInteraction',
#  'GIANT_occipital_pole_ProbabilityOfFunctionalInteraction',
#  'GIANT_amygdala_KnownFunctionalInteraction',
#  'TCGA_PAAD_Pvalue',
#  'GIANT_thyroid_gland_KnownFunctionalInteraction',
#  'GIANT_vascular_endothelial_cell_KnownFunctionalInteraction',
#  'GIANT_cerebral_cortex_ProbabilityOfFunctionalInteraction',
#  'TCGA_OV_Pvalue',
#  'GIANT_pons_KnownFunctionalInteraction',
#  'TCGA_LIHC_Correlation',
#  'GIANT_dentate_gyrus_KnownFunctionalInteraction',
#  'TCGA_ACC_Correlation',
#  'GTEx_Liver_Pvalue',
#  'GIANT_eosinophil_ProbabilityOfFunctionalInteraction',
#  'GIANT_umbilical_vein_endothelial_cell_ProbabilityOfFunctionalInteraction',
#  'TCGA_GBM_Pvalue',
#  'TCGA_LUSC_Pvalue',
#  'TCGA_KICH_Correlation',
#  'TCGA_TGCT_Correlation',
#  'GIANT_oviduct_ProbabilityOfFunctionalInteraction',
#  'TCGA_GBM_Correlation',
#  'GIANT_smooth_muscle_KnownFunctionalInteraction',
#  'GIANT_keratinocyte_ProbabilityOfFunctionalInteraction',
#  'GIANT_spermatid_ProbabilityOfFunctionalInteraction',
#  'GIANT_testis_KnownFunctionalInteraction',
#  'GIANT_lymph_node_ProbabilityOfFunctionalInteraction',
#  'GIANT_neuron_KnownFunctionalInteraction',
#  'TCGA_LAML_Correlation',
#  'GIANT_parietal_lobe_ProbabilityOfFunctionalInteraction',
#  'GIANT_uterus_ProbabilityOfFunctionalInteraction',
#  'GIANT_telencephalon_KnownFunctionalInteraction',
#  'GTEx_Pancreas_Pvalue',
#  'GIANT_bronchial_epithelial_cell_KnownFunctionalInteraction',
#  'GTEx_Liver_Correlation',
#  'GIANT_artery_KnownFunctionalInteraction',
#  'GIANT_corpus_luteum_KnownFunctionalInteraction',
#  'GIANT_lung_ProbabilityOfFunctionalInteraction',
#  'GIANT_thalamus_KnownFunctionalInteraction',
#  'GIANT_lymphocyte_KnownFunctionalInteraction',
#  'GIANT_epidermis_ProbabilityOfFunctionalInteraction',
#  'GIANT_pons_ProbabilityOfFunctionalInteraction',
#  'GIANT_caudate_putamen_KnownFunctionalInteraction',
#  'GIANT_substantia_nigra_KnownFunctionalInteraction',
#  'GTEx_Lung_Pvalue',
#  'GIANT_mammary_gland_ProbabilityOfFunctionalInteraction',
#  'GTEx_Adrenal_Gland_Pvalue',
#  'GIANT_adipose_tissue_KnownFunctionalInteraction',
#  'GIANT_blood_vessel_ProbabilityOfFunctionalInteraction',
#  'TCGA_TGCT_Pvalue',
#  'GIANT_heart_ProbabilityOfFunctionalInteraction',
#  'GIANT_astrocyte_ProbabilityOfFunctionalInteraction',
#  'TCGA_HNSC_Correlation',
#  'GIANT_culture_condition_cd8_cell_KnownFunctionalInteraction',
#  'GIANT_stomach_ProbabilityOfFunctionalInteraction',
#  'GIANT_pancreatic_islet_KnownFunctionalInteraction',
#  'GIANT_salivary_gland_KnownFunctionalInteraction',
#  'GTEx_Blood_Vessel_Pvalue',
#  'GIANT_central_nervous_system_ProbabilityOfFunctionalInteraction',
#  'TCGA_CHOL_Correlation',
#  'TCGA_OV_Correlation',
#  'GIANT_hypophysis_ProbabilityOfFunctionalInteraction',
#  'GIANT_bronchus_KnownFunctionalInteraction',
#  'TCGA_UVM_Correlation',
#  'GIANT_adipose_tissue_ProbabilityOfFunctionalInteraction',
#  'GIANT_trachea_KnownFunctionalInteraction',
#  'GIANT_small_intestine_KnownFunctionalInteraction',
#  'GIANT_liver_KnownFunctionalInteraction',
#  'GTEx_Brain_Correlation',
#  'GIANT_neutrophil_KnownFunctionalInteraction',
#  'GIANT_ovary_KnownFunctionalInteraction',
#  'GIANT_spermatocyte_ProbabilityOfFunctionalInteraction',
#  'TCGA_LUAD_Correlation',
#  'GIANT_renal_tubule_KnownFunctionalInteraction',
#  'GTEx_Muscle_Correlation',
#  'GIANT_intestine_KnownFunctionalInteraction',
#  'GIANT_nephron_ProbabilityOfFunctionalInteraction',
#  'GIANT_blood_KnownFunctionalInteraction',
#  'GIANT_dendritic_cell_ProbabilityOfFunctionalInteraction',
#  'GTEx_Testis_Correlation',
#  'GIANT_ileum_KnownFunctionalInteraction',
#  'TCGA_LIHC_Pvalue',
#  'GIANT_podocyte_KnownFunctionalInteraction',
#  'GTEx_Skin_Correlation',
#  'GIANT_eosinophil_KnownFunctionalInteraction',
#  'GIANT_cornea_KnownFunctionalInteraction',
#  'GIANT_spinal_cord_KnownFunctionalInteraction',
#  'TCGA_THCA_Correlation',
#  'TCGA_KIRP_Correlation',
#  'GIANT_cerebellar_cortex_ProbabilityOfFunctionalInteraction',
#  'GIANT_umbilical_cord_KnownFunctionalInteraction',
#  'GIANT_aorta_ProbabilityOfFunctionalInteraction',
#  'GIANT_eye_ProbabilityOfFunctionalInteraction',
#  'GIANT_renal_glomerulus_KnownFunctionalInteraction',
#  'GIANT_podocyte_ProbabilityOfFunctionalInteraction',
#  'TCGA_ACC_Pvalue',
#  'GIANT_duodenum_ProbabilityOfFunctionalInteraction',
#  'TCGA_LGG_Pvalue',
#  'GIANT_embryo_ProbabilityOfFunctionalInteraction',
#  'GIANT_kidney_KnownFunctionalInteraction',
#  'GIANT_bone_marrow_KnownFunctionalInteraction',
#  'GIANT_hippocampus_ProbabilityOfFunctionalInteraction',
#  'GIANT_corpus_luteum_ProbabilityOfFunctionalInteraction',
#  'GIANT_gastrointestinal_tract_ProbabilityOfFunctionalInteraction',
#  'GIANT_blood_platelet_ProbabilityOfFunctionalInteraction',
#  'GIANT_duodenum_KnownFunctionalInteraction',
#  'TCGA_PAAD_Correlation',
#  'GIANT_all_tissues_ProbabilityOfFunctionalInteraction',
#  'TCGA_STAD_Correlation',
#  'GIANT_lens_ProbabilityOfFunctionalInteraction',
#  'GIANT_colon_ProbabilityOfFunctionalInteraction',
#  'GIANT_ear_KnownFunctionalInteraction',
#  'GTEx_Stomach_Correlation',
#  'TCGA_BLCA_Pvalue',
#  'GTEx_Spleen_Correlation',
#  'GIANT_thalamus_ProbabilityOfFunctionalInteraction',
#  'GIANT_uroepithelium_KnownFunctionalInteraction',
#  'GIANT_bone_ProbabilityOfFunctionalInteraction',
#  'GTEx_Testis_Pvalue',
#  'TCGA_LUSC_Correlation',
#  'GIANT_chondrocyte_ProbabilityOfFunctionalInteraction',
#  'GTEx_Nerve_Correlation',
#  'GIANT_hair_follicle_KnownFunctionalInteraction',
#  'GIANT_hepatocyte_ProbabilityOfFunctionalInteraction',
#  'GIANT_caudate_putamen_ProbabilityOfFunctionalInteraction',
#  'BioGRID_Interaction',
#  'GTEx_Pancreas_Correlation',
#  'GIANT_renal_tubule_ProbabilityOfFunctionalInteraction',
#  'GIANT_prostate_gland_ProbabilityOfFunctionalInteraction',
#  'GIANT_cecum_ProbabilityOfFunctionalInteraction',
#  'TCGA_THYM_Correlation',
#  'GIANT_esophagus_KnownFunctionalInteraction',
#  'GIANT_tear_gland_KnownFunctionalInteraction',
#  'TCGA_KIRC_Pvalue',
#  'TCGA_UCEC_Pvalue',
#  'GIANT_ovary_ProbabilityOfFunctionalInteraction',
#  'GIANT_eye_KnownFunctionalInteraction',
#  'GIANT_blood_platelet_KnownFunctionalInteraction',
#  'GIANT_uroepithelium_ProbabilityOfFunctionalInteraction',
#  'GTEx_Pituitary_Correlation',
#  'TCGA_LAML_Pvalue',
#  'TCGA_HNSC_Pvalue',
#  'GIANT_occipital_lobe_KnownFunctionalInteraction',
#  'GTEx_Spleen_Pvalue',
#  'GIANT_bone_KnownFunctionalInteraction',
#  'GIANT_locus_ceruleus_ProbabilityOfFunctionalInteraction',
#  'GIANT_forebrain_ProbabilityOfFunctionalInteraction',
#  'GTEx_Breast_Correlation',
#  'TCGA_ESCA_Correlation',
#  'BioGRID_Throughput',
#  'GIANT_skeletal_muscle_KnownFunctionalInteraction',
#  'GIANT_tonsil_ProbabilityOfFunctionalInteraction',
#  'TCGA_DLBC_Correlation',
#  'GIANT_neuron_ProbabilityOfFunctionalInteraction',
#  'BioGRID_Experimental_System',
#  'TCGA_UCS_Correlation',
#  'GIANT_liver_ProbabilityOfFunctionalInteraction',
#  'GIANT_peripheral_nervous_system_KnownFunctionalInteraction',
#  'GIANT_midbrain_ProbabilityOfFunctionalInteraction',
#  'GIANT_glia_ProbabilityOfFunctionalInteraction',
#  'GIANT_retina_KnownFunctionalInteraction',
#  'GIANT_hematopoietic_stem_cell_KnownFunctionalInteraction',
#  'GIANT_leukocyte_KnownFunctionalInteraction',
#  'GTEx_Adipose_Tissue_Correlation',
#  'GIANT_caudate_nucleus_KnownFunctionalInteraction',
#  'GIANT_leukocyte_ProbabilityOfFunctionalInteraction',
#  'GIANT_blood_plasma_ProbabilityOfFunctionalInteraction',
#  'GTEx_Blood_Pvalue',
#  'GIANT_mammary_epithelium_KnownFunctionalInteraction',
#  'GIANT_cerebellar_cortex_KnownFunctionalInteraction',
#  'GIANT_granulocyte_ProbabilityOfFunctionalInteraction',
#  'GIANT_cartilage_KnownFunctionalInteraction',
#  'GIANT_lung_KnownFunctionalInteraction',
#  'GIANT_midbrain_KnownFunctionalInteraction',
#  'TCGA_SKCM_Correlation',
#  'GIANT_blood_plasma_KnownFunctionalInteraction',
#  'TCGA_READ_Pvalue',
#  'GIANT_spleen_ProbabilityOfFunctionalInteraction',
#  'GIANT_vascular_endothelium_ProbabilityOfFunctionalInteraction',
#  'GIANT_medulla_oblongata_KnownFunctionalInteraction',
#  'GIANT_muscle_KnownFunctionalInteraction',
#  'GTEx_Skin_Pvalue',
#  'GIANT_astrocyte_KnownFunctionalInteraction',
#  'GIANT_jejunum_ProbabilityOfFunctionalInteraction',
#  'GIANT_vascular_endothelial_cell_ProbabilityOfFunctionalInteraction',
#  'TCGA_THYM_Pvalue',
#  'TCGA_SARC_Correlation',
#  'GIANT_intestine_ProbabilityOfFunctionalInteraction',
#  'GIANT_pancreas_KnownFunctionalInteraction',
#  'GIANT_adrenal_cortex_ProbabilityOfFunctionalInteraction',
#  'GIANT_chondrocyte_KnownFunctionalInteraction',
#  'GIANT_adrenal_gland_ProbabilityOfFunctionalInteraction',
#  'GTEx_Colon_Correlation',
#  'GIANT_macrophage_ProbabilityOfFunctionalInteraction',
#  'GIANT_corpus_striatum_KnownFunctionalInteraction',
#  'TCGA_LGG_Correlation',
#  'GIANT_cardiac_muscle_KnownFunctionalInteraction',
#  'GIANT_amygdala_ProbabilityOfFunctionalInteraction',
#  'GIANT_tooth_KnownFunctionalInteraction',
#  'GIANT_t_lymphocyte_ProbabilityOfFunctionalInteraction',
#  'GIANT_cornea_ProbabilityOfFunctionalInteraction',
#  'GIANT_hypothalamus_ProbabilityOfFunctionalInteraction',
#  'GIANT_cerebellum_KnownFunctionalInteraction',
#  'GTEx_Lung_Correlation',
#  'GIANT_fetus_ProbabilityOfFunctionalInteraction',
#  'GIANT_culture_condition_cd8_cell_ProbabilityOfFunctionalInteraction',
#  'GIANT_blood_ProbabilityOfFunctionalInteraction',
#  'GIANT_dentate_gyrus_ProbabilityOfFunctionalInteraction',
#  'GTEx_Colon_Pvalue',
#  'GIANT_spermatogonium_ProbabilityOfFunctionalInteraction',
#  'GIANT_dendritic_cell_KnownFunctionalInteraction',
#  'GTEx_Adrenal_Gland_Correlation',
#  'GIANT_macrophage_KnownFunctionalInteraction',
#  'GIANT_brain_ProbabilityOfFunctionalInteraction',
#  'GIANT_kidney_ProbabilityOfFunctionalInteraction',
#  'GIANT_cochlea_ProbabilityOfFunctionalInteraction',
#  'GIANT_nephron_KnownFunctionalInteraction',
#  'GIANT_tonsil_KnownFunctionalInteraction',
#  'GIANT_central_nervous_system_KnownFunctionalInteraction',
#  'GTEx_Heart_Pvalue',
#  'TCGA_DLBC_Pvalue',
#  'GIANT_gastrointestinal_tract_KnownFunctionalInteraction',
#  'GIANT_small_intestine_ProbabilityOfFunctionalInteraction',
#  'GIANT_megakaryocyte_ProbabilityOfFunctionalInteraction',
#  'GIANT_mast_cell_KnownFunctionalInteraction',
#  'TCGA_PRAD_Correlation',
#  'GIANT_osteoblast_KnownFunctionalInteraction',
#  'TCGA_KIRC_Correlation',
#  'TCGA_CHOL_Pvalue',
#  'GIANT_epidermis_KnownFunctionalInteraction',
#  'GIANT_ileum_ProbabilityOfFunctionalInteraction',
#  'GIANT_choroid_KnownFunctionalInteraction',
#  'GTEx_Prostate_Pvalue',
#  'GIANT_basal_ganglion_ProbabilityOfFunctionalInteraction',
#  'GIANT_artery_ProbabilityOfFunctionalInteraction']

# %%
column_map = dict()
for col1 in bg_columns_set:
    col = col1.split('_')
    source = col[0]
    column_map[col1] = {
        "source": source,
        "type": None,
        "tissue": None,
        "cancer_type": None,
    }
    if source == 'BioGRID':
        column_map[col1]["type"] = "_".join(col[1:])
    if source == 'GIANT' or source == 'GTEx':
        tissue = dict()
        bg_term = "_".join(col[1:-1]).lower()
        tissue['bg_label'] = bg_term
        tissue['uberon'] = id2term(var=bg_term, key='bg_label', return_key='uberon_id', json_blob=uberon_bto_map)
        tissue['bto'] = id2term(var=bg_term, key='bg_label', return_key='bto_id', json_blob=uberon_bto_map)
        column_map[col1]['bg_term'] = bg_term
        column_map[col1]['tissue'] = tissue
        column_map[col1]['type'] = col[-1]
    if source == 'TCGA':
        cancer_type = "_".join(col[1:-1])
        column_map[col1]['cancer_type'] = cancer_type
        column_map[col1]['type'] = col[-1]
pprint(column_map)
# Out:
# {'BioGRID_Experimental_System': {'cancer_type': None,
#                                  'source': 'BioGRID',
#                                  'tissue': None,
#                                  'type': 'Experimental_System'},
#  'BioGRID_Experimental_System_Type': {'cancer_type': None,
#                                       'source': 'BioGRID',
#                                       'tissue': None,
#                                       'type': 'Experimental_System_Type'},
#  'BioGRID_Interaction': {'cancer_type': None,
#                          'source': 'BioGRID',
#                          'tissue': None,
#                          'type': 'Interaction'},
#  'BioGRID_Throughput': {'cancer_type': None,
#                         'source': 'BioGRID',
#                         'tissue': None,
#                         'type': 'Throughput'},
#  'GIANT_adipose_tissue_KnownFunctionalInteraction': {'bg_term': 'adipose_tissue',
#                                                      'cancer_type': None,
#                                                      'source': 'GIANT',
#                                                      'tissue': {'bg_label': 'adipose_tissue',
#                                                                 'bto': 'BTO:0001487',
#                                                                 'uberon': 'UBERON:0001013'},
#                                                      'type': 'KnownFunctionalInteraction'},
#  'GIANT_adipose_tissue_ProbabilityOfFunctionalInteraction': {'bg_term': 'adipose_tissue',
#                                                              'cancer_type': None,
#                                                              'source': 'GIANT',
#                                                              'tissue': {'bg_label': 'adipose_tissue',
#                                                                         'bto': 'BTO:0001487',
#                                                                         'uberon': 'UBERON:0001013'},
#                                                              'type': 'ProbabilityOfFunctionalInteraction'},
#  'GIANT_adrenal_cortex_KnownFunctionalInteraction': {'bg_term': 'adrenal_cortex',
#                                                      'cancer_type': None,
#                                                      'source': 'GIANT',
#                                                      'tissue': {'bg_label': 'adrenal_cortex',
#                                                                 'bto': 'BTO:0000045',
#                                                                 'uberon': 'UBERON:0001235'},
#                                                      'type': 'KnownFunctionalInteraction'},
#  'GIANT_adrenal_cortex_ProbabilityOfFunctionalInteraction': {'bg_term': 'adrenal_cortex',
#                                                              'cancer_type': None,
#                                                              'source': 'GIANT',
#                                                              'tissue': {'bg_label': 'adrenal_cortex',
#                                                                         'bto': 'BTO:0000045',
#                                                                         'uberon': 'UBERON:0001235'},
#                                                              'type': 'ProbabilityOfFunctionalInteraction'},
#  'GIANT_adrenal_gland_KnownFunctionalInteraction': {'bg_term': 'adrenal_gland',
#                                                     'cancer_type': None,
#                                                     'source': 'GIANT',
#                                                     'tissue': {'bg_label': 'adrenal_gland',
#                                                                'bto': 'BTO:0000047',
#                                                                'uberon': 'UBERON:0002369'},
#                                                     'type': 'KnownFunctionalInteraction'},
#  'GIANT_adrenal_gland_ProbabilityOfFunctionalInteraction': {'bg_term': 'adrenal_gland',
#                                                             'cancer_type': None,
#                                                             'source': 'GIANT',
#                                                             'tissue': {'bg_label': 'adrenal_gland',
#                                                                        'bto': 'BTO:0000047',
#                                                                        'uberon': 'UBERON:0002369'},
#                                                             'type': 'ProbabilityOfFunctionalInteraction'},
#  'GIANT_all_tissues_KnownFunctionalInteraction': {'bg_term': 'all_tissues',
#                                                   'cancer_type': None,
#                                                   'source': 'GIANT',
#                                                   'tissue': {'bg_label': 'all_tissues',
#                                                              'bto': None,
#                                                              'uberon': None},
#                                                   'type': 'KnownFunctionalInteraction'},
#  'GIANT_all_tissues_ProbabilityOfFunctionalInteraction': {'bg_term': 'all_tissues',
#                                                           'cancer_type': None,
#                                                           'source': 'GIANT',
#                                                           'tissue': {'bg_label': 'all_tissues',
#                                                                      'bto': None,
#                                                                      'uberon': None},
#                                                           'type': 'ProbabilityOfFunctionalInteraction'},
#  'GIANT_amygdala_KnownFunctionalInteraction': {'bg_term': 'amygdala',
#                                                'cancer_type': None,
#                                                'source': 'GIANT',
#                                                'tissue': {'bg_label': 'amygdala',
#                                                           'bto': 'BTO:0001042',
#                                                           'uberon': 'UBERON:0001876'},
#                                                'type': 'KnownFunctionalInteraction'},
#  'GIANT_amygdala_ProbabilityOfFunctionalInteraction': {'bg_term': 'amygdala',
#                                                        'cancer_type': None,
#                                                        'source': 'GIANT',
#                                                        'tissue': {'bg_label': 'amygdala',
#                                                                   'bto': 'BTO:0001042',
#                                                                   'uberon': 'UBERON:0001876'},
#                                                        'type': 'ProbabilityOfFunctionalInteraction'},
#  'GIANT_aorta_KnownFunctionalInteraction': {'bg_term': 'aorta',
#                                             'cancer_type': None,
#                                             'source': 'GIANT',
#                                             'tissue': {'bg_label': 'aorta',
#                                                        'bto': 'BTO:0000135',
#                                                        'uberon': 'UBERON:0000947'},
#                                             'type': 'KnownFunctionalInteraction'},
#  'GIANT_aorta_ProbabilityOfFunctionalInteraction': {'bg_term': 'aorta',
#                                                     'cancer_type': None,
#                                                     'source': 'GIANT',
#                                                     'tissue': {'bg_label': 'aorta',
#                                                                'bto': 'BTO:0000135',
#                                                                'uberon': 'UBERON:0000947'},
#                                                     'type': 'ProbabilityOfFunctionalInteraction'},
#  'GIANT_artery_KnownFunctionalInteraction': {'bg_term': 'artery',
#                                              'cancer_type': None,
#                                              'source': 'GIANT',
#                                              'tissue': {'bg_label': 'artery',
#                                                         'bto': 'BTO:0000573',
#                                                         'uberon': 'UBERON:0001637'},
#                                              'type': 'KnownFunctionalInteraction'},
#  'GIANT_artery_ProbabilityOfFunctionalInteraction': {'bg_term': 'artery',
#                                                      'cancer_type': None,
#                                                      'source': 'GIANT',
#                                                      'tissue': {'bg_label': 'artery',
#                                                                 'bto': 'BTO:0000573',
#                                                                 'uberon': 'UBERON:0001637'},
#                                                      'type': 'ProbabilityOfFunctionalInteraction'},
#  'GIANT_astrocyte_KnownFunctionalInteraction': {'bg_term': 'astrocyte',
#                                                 'cancer_type': None,
#                                                 'source': 'GIANT',
#                                                 'tissue': {'bg_label': 'astrocyte',
#                                                            'bto': 'BTO:0000099',
#                                                            'uberon': None},
#                                                 'type': 'KnownFunctionalInteraction'},
#  'GIANT_astrocyte_ProbabilityOfFunctionalInteraction': {'bg_term': 'astrocyte',
#                                                         'cancer_type': None,
#                                                         'source': 'GIANT',
#                                                         'tissue': {'bg_label': 'astrocyte',
#                                                                    'bto': 'BTO:0000099',
#                                                                    'uberon': None},
#                                                         'type': 'ProbabilityOfFunctionalInteraction'},
#  'GIANT_b_lymphocyte_KnownFunctionalInteraction': {'bg_term': 'b_lymphocyte',
#                                                    'cancer_type': None,
#                                                    'source': 'GIANT',
#                                                    'tissue': {'bg_label': 'b_lymphocyte',
#                                                               'bto': None,
#                                                               'uberon': None},
#                                                    'type': 'KnownFunctionalInteraction'},
#  'GIANT_b_lymphocyte_ProbabilityOfFunctionalInteraction': {'bg_term': 'b_lymphocyte',
#                                                            'cancer_type': None,
#                                                            'source': 'GIANT',
#                                                            'tissue': {'bg_label': 'b_lymphocyte',
#                                                                       'bto': None,
#                                                                       'uberon': None},
#                                                            'type': 'ProbabilityOfFunctionalInteraction'},
#  'GIANT_basal_ganglion_KnownFunctionalInteraction': {'bg_term': 'basal_ganglion',
#                                                      'cancer_type': None,
#                                                      'source': 'GIANT',
#                                                      'tissue': {'bg_label': 'basal_ganglion',
#                                                                 'bto': 'BTO:0000235',
#                                                                 'uberon': 'UBERON:0002420'},
#                                                      'type': 'KnownFunctionalInteraction'},
#  'GIANT_basal_ganglion_ProbabilityOfFunctionalInteraction': {'bg_term': 'basal_ganglion',
#                                                              'cancer_type': None,
#                                                              'source': 'GIANT',
#                                                              'tissue': {'bg_label': 'basal_ganglion',
#                                                                         'bto': 'BTO:0000235',
#                                                                         'uberon': 'UBERON:0002420'},
#                                                              'type': 'ProbabilityOfFunctionalInteraction'},
#  'GIANT_basophil_KnownFunctionalInteraction': {'bg_term': 'basophil',
#                                                'cancer_type': None,
#                                                'source': 'GIANT',
#                                                'tissue': {'bg_label': 'basophil',
#                                                           'bto': 'BTO:0000129',
#                                                           'uberon': None},
#                                                'type': 'KnownFunctionalInteraction'},
#  'GIANT_basophil_ProbabilityOfFunctionalInteraction': {'bg_term': 'basophil',
#                                                        'cancer_type': None,
#                                                        'source': 'GIANT',
#                                                        'tissue': {'bg_label': 'basophil',
#                                                                   'bto': 'BTO:0000129',
#                                                                   'uberon': None},
#                                                        'type': 'ProbabilityOfFunctionalInteraction'},
#  'GIANT_blood_KnownFunctionalInteraction': {'bg_term': 'blood',
#                                             'cancer_type': None,
#                                             'source': 'GIANT',
#                                             'tissue': {'bg_label': 'blood',
#                                                        'bto': 'BTO:0000089',
#                                                        'uberon': 'UBERON:0000178'},
#                                             'type': 'KnownFunctionalInteraction'},
#  'GIANT_blood_ProbabilityOfFunctionalInteraction': {'bg_term': 'blood',
#                                                     'cancer_type': None,
#                                                     'source': 'GIANT',
#                                                     'tissue': {'bg_label': 'blood',
#                                                                'bto': 'BTO:0000089',
#                                                                'uberon': 'UBERON:0000178'},
#                                                     'type': 'ProbabilityOfFunctionalInteraction'},
#  'GIANT_blood_plasma_KnownFunctionalInteraction': {'bg_term': 'blood_plasma',
#                                                    'cancer_type': None,
#                                                    'source': 'GIANT',
#                                                    'tissue': {'bg_label': 'blood_plasma',
#                                                               'bto': 'BTO:0000131',
#                                                               'uberon': 'UBERON:0001969'},
#                                                    'type': 'KnownFunctionalInteraction'},
#  'GIANT_blood_plasma_ProbabilityOfFunctionalInteraction': {'bg_term': 'blood_plasma',
#                                                            'cancer_type': None,
#                                                            'source': 'GIANT',
#                                                            'tissue': {'bg_label': 'blood_plasma',
#                                                                       'bto': 'BTO:0000131',
#                                                                       'uberon': 'UBERON:0001969'},
#                                                            'type': 'ProbabilityOfFunctionalInteraction'},
#  'GIANT_blood_platelet_KnownFunctionalInteraction': {'bg_term': 'blood_platelet',
#                                                      'cancer_type': None,
#                                                      'source': 'GIANT',
#                                                      'tissue': {'bg_label': 'blood_platelet',
#                                                                 'bto': 'BTO:0000132',
#                                                                 'uberon': None},
#                                                      'type': 'KnownFunctionalInteraction'},
#  'GIANT_blood_platelet_ProbabilityOfFunctionalInteraction': {'bg_term': 'blood_platelet',
#                                                              'cancer_type': None,
#                                                              'source': 'GIANT',
#                                                              'tissue': {'bg_label': 'blood_platelet',
#                                                                         'bto': 'BTO:0000132',
#                                                                         'uberon': None},
#                                                              'type': 'ProbabilityOfFunctionalInteraction'},
#  'GIANT_blood_vessel_KnownFunctionalInteraction': {'bg_term': 'blood_vessel',
#                                                    'cancer_type': None,
#                                                    'source': 'GIANT',
#                                                    'tissue': {'bg_label': 'blood_vessel',
#                                                               'bto': 'BTO:0001102',
#                                                               'uberon': 'UBERON:0001981'},
#                                                    'type': 'KnownFunctionalInteraction'},
#  'GIANT_blood_vessel_ProbabilityOfFunctionalInteraction': {'bg_term': 'blood_vessel',
#                                                            'cancer_type': None,
#                                                            'source': 'GIANT',
#                                                            'tissue': {'bg_label': 'blood_vessel',
#                                                                       'bto': 'BTO:0001102',
#                                                                       'uberon': 'UBERON:0001981'},
#                                                            'type': 'ProbabilityOfFunctionalInteraction'},
#  'GIANT_bone_KnownFunctionalInteraction': {'bg_term': 'bone',
#                                            'cancer_type': None,
#                                            'source': 'GIANT',
#                                            'tissue': {'bg_label': 'bone',
#                                                       'bto': 'BTO:0000140',
#                                                       'uberon': 'UBERON:0001474'},
#                                            'type': 'KnownFunctionalInteraction'},
#  'GIANT_bone_ProbabilityOfFunctionalInteraction': {'bg_term': 'bone',
#                                                    'cancer_type': None,
#                                                    'source': 'GIANT',
#                                                    'tissue': {'bg_label': 'bone',
#                                                               'bto': 'BTO:0000140',
#                                                               'uberon': 'UBERON:0001474'},
#                                                    'type': 'ProbabilityOfFunctionalInteraction'},
#  'GIANT_bone_marrow_KnownFunctionalInteraction': {'bg_term': 'bone_marrow',
#                                                   'cancer_type': None,
#                                                   'source': 'GIANT',
#                                                   'tissue': {'bg_label': 'bone_marrow',
#                                                              'bto': 'BTO:0000141',
#                                                              'uberon': 'UBERON:0002371'},
#                                                   'type': 'KnownFunctionalInteraction'},
#  'GIANT_bone_marrow_ProbabilityOfFunctionalInteraction': {'bg_term': 'bone_marrow',
#                                                           'cancer_type': None,
#                                                           'source': 'GIANT',
#                                                           'tissue': {'bg_label': 'bone_marrow',
#                                                                      'bto': 'BTO:0000141',
#                                                                      'uberon': 'UBERON:0002371'},
#                                                           'type': 'ProbabilityOfFunctionalInteraction'},
#  'GIANT_brain_KnownFunctionalInteraction': {'bg_term': 'brain',
#                                             'cancer_type': None,
#                                             'source': 'GIANT',
#                                             'tissue': {'bg_label': 'brain',
#                                                        'bto': 'BTO:0000142',
#                                                        'uberon': 'UBERON:0000955'},
#                                             'type': 'KnownFunctionalInteraction'},
#  'GIANT_brain_ProbabilityOfFunctionalInteraction': {'bg_term': 'brain',
#                                                     'cancer_type': None,
#                                                     'source': 'GIANT',
#                                                     'tissue': {'bg_label': 'brain',
#                                                                'bto': 'BTO:0000142',
#                                                                'uberon': 'UBERON:0000955'},
#                                                     'type': 'ProbabilityOfFunctionalInteraction'},
#  'GIANT_bronchial_epithelial_cell_KnownFunctionalInteraction': {'bg_term': 'bronchial_epithelial_cell',
#                                                                 'cancer_type': None,
#                                                                 'source': 'GIANT',
#                                                                 'tissue': {'bg_label': 'bronchial_epithelial_cell',
#                                                                            'bto': 'BTO:0002922',
#                                                                            'uberon': None},
#                                                                 'type': 'KnownFunctionalInteraction'},
#  'GIANT_bronchial_epithelial_cell_ProbabilityOfFunctionalInteraction': {'bg_term': 'bronchial_epithelial_cell',
#                                                                         'cancer_type': None,
#                                                                         'source': 'GIANT',
#                                                                         'tissue': {'bg_label': 'bronchial_epithelial_cell',
#                                                                                    'bto': 'BTO:0002922',
#                                                                                    'uberon': None},
#                                                                         'type': 'ProbabilityOfFunctionalInteraction'},
#  'GIANT_bronchus_KnownFunctionalInteraction': {'bg_term': 'bronchus',
#                                                'cancer_type': None,
#                                                'source': 'GIANT',
#                                                'tissue': {'bg_label': 'bronchus',
#                                                           'bto': 'BTO:0001340',
#                                                           'uberon': 'UBERON:0002185'},
#                                                'type': 'KnownFunctionalInteraction'},
#  'GIANT_bronchus_ProbabilityOfFunctionalInteraction': {'bg_term': 'bronchus',
#                                                        'cancer_type': None,
#                                                        'source': 'GIANT',
#                                                        'tissue': {'bg_label': 'bronchus',
#                                                                   'bto': 'BTO:0001340',
#                                                                   'uberon': 'UBERON:0002185'},
#                                                        'type': 'ProbabilityOfFunctionalInteraction'},
#  'GIANT_cardiac_muscle_KnownFunctionalInteraction': {'bg_term': 'cardiac_muscle',
#                                                      'cancer_type': None,
#                                                      'source': 'GIANT',
#                                                      'tissue': {'bg_label': 'cardiac_muscle',
#                                                                 'bto': 'BTO:0000199',
#                                                                 'uberon': 'UBERON:0001133'},
#                                                      'type': 'KnownFunctionalInteraction'},
#  'GIANT_cardiac_muscle_ProbabilityOfFunctionalInteraction': {'bg_term': 'cardiac_muscle',
#                                                              'cancer_type': None,
#                                                              'source': 'GIANT',
#                                                              'tissue': {'bg_label': 'cardiac_muscle',
#                                                                         'bto': 'BTO:0000199',
#                                                                         'uberon': 'UBERON:0001133'},
#                                                              'type': 'ProbabilityOfFunctionalInteraction'},
#  'GIANT_cartilage_KnownFunctionalInteraction': {'bg_term': 'cartilage',
#                                                 'cancer_type': None,
#                                                 'source': 'GIANT',
#                                                 'tissue': {'bg_label': 'cartilage',
#                                                            'bto': 'BTO:0000206',
#                                                            'uberon': 'UBERON:0002418'},
#                                                 'type': 'KnownFunctionalInteraction'},
#  'GIANT_cartilage_ProbabilityOfFunctionalInteraction': {'bg_term': 'cartilage',
#                                                         'cancer_type': None,
#                                                         'source': 'GIANT',
#                                                         'tissue': {'bg_label': 'cartilage',
#                                                                    'bto': 'BTO:0000206',
#                                                                    'uberon': 'UBERON:0002418'},
#                                                         'type': 'ProbabilityOfFunctionalInteraction'},
#  'GIANT_caudate_nucleus_KnownFunctionalInteraction': {'bg_term': 'caudate_nucleus',
#                                                       'cancer_type': None,
#                                                       'source': 'GIANT',
#                                                       'tissue': {'bg_label': 'caudate_nucleus',
#                                                                  'bto': 'BTO:0000211',
#                                                                  'uberon': 'UBERON:0001873'},
#                                                       'type': 'KnownFunctionalInteraction'},
#  'GIANT_caudate_nucleus_ProbabilityOfFunctionalInteraction': {'bg_term': 'caudate_nucleus',
#                                                               'cancer_type': None,
#                                                               'source': 'GIANT',
#                                                               'tissue': {'bg_label': 'caudate_nucleus',
#                                                                          'bto': 'BTO:0000211',
#                                                                          'uberon': 'UBERON:0001873'},
#                                                               'type': 'ProbabilityOfFunctionalInteraction'},
#  'GIANT_caudate_putamen_KnownFunctionalInteraction': {'bg_term': 'caudate_putamen',
#                                                       'cancer_type': None,
#                                                       'source': 'GIANT',
#                                                       'tissue': {'bg_label': 'caudate_putamen',
#                                                                  'bto': 'BTO:0000212',
#                                                                  'uberon': 'UBERON:0005383'},
#                                                       'type': 'KnownFunctionalInteraction'},
#  'GIANT_caudate_putamen_ProbabilityOfFunctionalInteraction': {'bg_term': 'caudate_putamen',
#                                                               'cancer_type': None,
#                                                               'source': 'GIANT',
#                                                               'tissue': {'bg_label': 'caudate_putamen',
#                                                                          'bto': 'BTO:0000212',
#                                                                          'uberon': 'UBERON:0005383'},
#                                                               'type': 'ProbabilityOfFunctionalInteraction'},
#  'GIANT_cecum_KnownFunctionalInteraction': {'bg_term': 'cecum',
#                                             'cancer_type': None,
#                                             'source': 'GIANT',
#                                             'tissue': {'bg_label': 'cecum',
#                                                        'bto': 'BTO:0000166',
#                                                        'uberon': 'UBERON:0001153'},
#                                             'type': 'KnownFunctionalInteraction'},
#  'GIANT_cecum_ProbabilityOfFunctionalInteraction': {'bg_term': 'cecum',
#                                                     'cancer_type': None,
#                                                     'source': 'GIANT',
#                                                     'tissue': {'bg_label': 'cecum',
#                                                                'bto': 'BTO:0000166',
#                                                                'uberon': 'UBERON:0001153'},
#                                                     'type': 'ProbabilityOfFunctionalInteraction'},
#  'GIANT_central_nervous_system_KnownFunctionalInteraction': {'bg_term': 'central_nervous_system',
#                                                              'cancer_type': None,
#                                                              'source': 'GIANT',
#                                                              'tissue': {'bg_label': 'central_nervous_system',
#                                                                         'bto': 'BTO:0000227',
#                                                                         'uberon': 'UBERON:0001017'},
#                                                              'type': 'KnownFunctionalInteraction'},
#  'GIANT_central_nervous_system_ProbabilityOfFunctionalInteraction': {'bg_term': 'central_nervous_system',
#                                                                      'cancer_type': None,
#                                                                      'source': 'GIANT',
#                                                                      'tissue': {'bg_label': 'central_nervous_system',
#                                                                                 'bto': 'BTO:0000227',
#                                                                                 'uberon': 'UBERON:0001017'},
#                                                                      'type': 'ProbabilityOfFunctionalInteraction'},
#  'GIANT_cerebellar_cortex_KnownFunctionalInteraction': {'bg_term': 'cerebellar_cortex',
#                                                         'cancer_type': None,
#                                                         'source': 'GIANT',
#                                                         'tissue': {'bg_label': 'cerebellar_cortex',
#                                                                    'bto': 'BTO:0000043',
#                                                                    'uberon': 'UBERON:0002129'},
#                                                         'type': 'KnownFunctionalInteraction'},
#  'GIANT_cerebellar_cortex_ProbabilityOfFunctionalInteraction': {'bg_term': 'cerebellar_cortex',
#                                                                 'cancer_type': None,
#                                                                 'source': 'GIANT',
#                                                                 'tissue': {'bg_label': 'cerebellar_cortex',
#                                                                            'bto': 'BTO:0000043',
#                                                                            'uberon': 'UBERON:0002129'},
#                                                                 'type': 'ProbabilityOfFunctionalInteraction'},
#  'GIANT_cerebellum_KnownFunctionalInteraction': {'bg_term': 'cerebellum',
#                                                  'cancer_type': None,
#                                                  'source': 'GIANT',
#                                                  'tissue': {'bg_label': 'cerebellum',
#                                                             'bto': 'BTO:0000232',
#                                                             'uberon': 'UBERON:0002037'},
#                                                  'type': 'KnownFunctionalInteraction'},
#  'GIANT_cerebellum_ProbabilityOfFunctionalInteraction': {'bg_term': 'cerebellum',
#                                                          'cancer_type': None,
#                                                          'source': 'GIANT',
#                                                          'tissue': {'bg_label': 'cerebellum',
#                                                                     'bto': 'BTO:0000232',
#                                                                     'uberon': 'UBERON:0002037'},
#                                                          'type': 'ProbabilityOfFunctionalInteraction'},
#  'GIANT_cerebral_cortex_KnownFunctionalInteraction': {'bg_term': 'cerebral_cortex',
#                                                       'cancer_type': None,
#                                                       'source': 'GIANT',
#                                                       'tissue': {'bg_label': 'cerebral_cortex',
#                                                                  'bto': 'BTO:0000233',
#                                                                  'uberon': 'UBERON:0000956'},
#                                                       'type': 'KnownFunctionalInteraction'},
#  'GIANT_cerebral_cortex_ProbabilityOfFunctionalInteraction': {'bg_term': 'cerebral_cortex',
#                                                               'cancer_type': None,
#                                                               'source': 'GIANT',
#                                                               'tissue': {'bg_label': 'cerebral_cortex',
#                                                                          'bto': 'BTO:0000233',
#                                                                          'uberon': 'UBERON:0000956'},
#                                                               'type': 'ProbabilityOfFunctionalInteraction'},
#  'GIANT_chondrocyte_KnownFunctionalInteraction': {'bg_term': 'chondrocyte',
#                                                   'cancer_type': None,
#                                                   'source': 'GIANT',
#                                                   'tissue': {'bg_label': 'chondrocyte',
#                                                              'bto': 'BTO:0000249',
#                                                              'uberon': None},
#                                                   'type': 'KnownFunctionalInteraction'},
#  'GIANT_chondrocyte_ProbabilityOfFunctionalInteraction': {'bg_term': 'chondrocyte',
#                                                           'cancer_type': None,
#                                                           'source': 'GIANT',
#                                                           'tissue': {'bg_label': 'chondrocyte',
#                                                                      'bto': 'BTO:0000249',
#                                                                      'uberon': None},
#                                                           'type': 'ProbabilityOfFunctionalInteraction'},
#  'GIANT_choroid_KnownFunctionalInteraction': {'bg_term': 'choroid',
#                                               'cancer_type': None,
#                                               'source': 'GIANT',
#                                               'tissue': {'bg_label': 'choroid',
#                                                          'bto': 'BTO:0001829',
#                                                          'uberon': 'UBERON:0001776'},
#                                               'type': 'KnownFunctionalInteraction'},
#  'GIANT_choroid_ProbabilityOfFunctionalInteraction': {'bg_term': 'choroid',
#                                                       'cancer_type': None,
#                                                       'source': 'GIANT',
#                                                       'tissue': {'bg_label': 'choroid',
#                                                                  'bto': 'BTO:0001829',
#                                                                  'uberon': 'UBERON:0001776'},
#                                                       'type': 'ProbabilityOfFunctionalInteraction'},
#  'GIANT_cochlea_KnownFunctionalInteraction': {'bg_term': 'cochlea',
#                                               'cancer_type': None,
#                                               'source': 'GIANT',
#                                               'tissue': {'bg_label': 'cochlea',
#                                                          'bto': 'BTO:0000267',
#                                                          'uberon': 'UBERON:0001844'},
#                                               'type': 'KnownFunctionalInteraction'},
#  'GIANT_cochlea_ProbabilityOfFunctionalInteraction': {'bg_term': 'cochlea',
#                                                       'cancer_type': None,
#                                                       'source': 'GIANT',
#                                                       'tissue': {'bg_label': 'cochlea',
#                                                                  'bto': 'BTO:0000267',
#                                                                  'uberon': 'UBERON:0001844'},
#                                                       'type': 'ProbabilityOfFunctionalInteraction'},
#  'GIANT_colon_KnownFunctionalInteraction': {'bg_term': 'colon',
#                                             'cancer_type': None,
#                                             'source': 'GIANT',
#                                             'tissue': {'bg_label': 'colon',
#                                                        'bto': 'BTO:0000269',
#                                                        'uberon': 'UBERON:0001155'},
#                                             'type': 'KnownFunctionalInteraction'},
#  'GIANT_colon_ProbabilityOfFunctionalInteraction': {'bg_term': 'colon',
#                                                     'cancer_type': None,
#                                                     'source': 'GIANT',
#                                                     'tissue': {'bg_label': 'colon',
#                                                                'bto': 'BTO:0000269',
#                                                                'uberon': 'UBERON:0001155'},
#                                                     'type': 'ProbabilityOfFunctionalInteraction'},
#  'GIANT_cornea_KnownFunctionalInteraction': {'bg_term': 'cornea',
#                                              'cancer_type': None,
#                                              'source': 'GIANT',
#                                              'tissue': {'bg_label': 'cornea',
#                                                         'bto': 'BTO:0000286',
#                                                         'uberon': 'UBERON:0000964'},
#                                              'type': 'KnownFunctionalInteraction'},
#  'GIANT_cornea_ProbabilityOfFunctionalInteraction': {'bg_term': 'cornea',
#                                                      'cancer_type': None,
#                                                      'source': 'GIANT',
#                                                      'tissue': {'bg_label': 'cornea',
#                                                                 'bto': 'BTO:0000286',
#                                                                 'uberon': 'UBERON:0000964'},
#                                                      'type': 'ProbabilityOfFunctionalInteraction'},
#  'GIANT_corpus_callosum_KnownFunctionalInteraction': {'bg_term': 'corpus_callosum',
#                                                       'cancer_type': None,
#                                                       'source': 'GIANT',
#                                                       'tissue': {'bg_label': 'corpus_callosum',
#                                                                  'bto': 'BTO:0000615',
#                                                                  'uberon': 'UBERON:0002336'},
#                                                       'type': 'KnownFunctionalInteraction'},
#  'GIANT_corpus_callosum_ProbabilityOfFunctionalInteraction': {'bg_term': 'corpus_callosum',
#                                                               'cancer_type': None,
#                                                               'source': 'GIANT',
#                                                               'tissue': {'bg_label': 'corpus_callosum',
#                                                                          'bto': 'BTO:0000615',
#                                                                          'uberon': 'UBERON:0002336'},
#                                                               'type': 'ProbabilityOfFunctionalInteraction'},
#  'GIANT_corpus_luteum_KnownFunctionalInteraction': {'bg_term': 'corpus_luteum',
#                                                     'cancer_type': None,
#                                                     'source': 'GIANT',
#                                                     'tissue': {'bg_label': 'corpus_luteum',
#                                                                'bto': 'BTO:0000292',
#                                                                'uberon': 'UBERON:0002512'},
#                                                     'type': 'KnownFunctionalInteraction'},
#  'GIANT_corpus_luteum_ProbabilityOfFunctionalInteraction': {'bg_term': 'corpus_luteum',
#                                                             'cancer_type': None,
#                                                             'source': 'GIANT',
#                                                             'tissue': {'bg_label': 'corpus_luteum',
#                                                                        'bto': 'BTO:0000292',
#                                                                        'uberon': 'UBERON:0002512'},
#                                                             'type': 'ProbabilityOfFunctionalInteraction'},
#  'GIANT_corpus_striatum_KnownFunctionalInteraction': {'bg_term': 'corpus_striatum',
#                                                       'cancer_type': None,
#                                                       'source': 'GIANT',
#                                                       'tissue': {'bg_label': 'corpus_striatum',
#                                                                  'bto': 'BTO:0001311',
#                                                                  'uberon': 'UBERON:0000369'},
#                                                       'type': 'KnownFunctionalInteraction'},
#  'GIANT_corpus_striatum_ProbabilityOfFunctionalInteraction': {'bg_term': 'corpus_striatum',
#                                                               'cancer_type': None,
#                                                               'source': 'GIANT',
#                                                               'tissue': {'bg_label': 'corpus_striatum',
#                                                                          'bto': 'BTO:0001311',
#                                                                          'uberon': 'UBERON:0000369'},
#                                                               'type': 'ProbabilityOfFunctionalInteraction'},
#  'GIANT_culture_condition_cd8_cell_KnownFunctionalInteraction': {'bg_term': 'culture_condition_cd8_cell',
#                                                                  'cancer_type': None,
#                                                                  'source': 'GIANT',
#                                                                  'tissue': {'bg_label': 'culture_condition_cd8_cell',
#                                                                             'bto': None,
#                                                                             'uberon': None},
#                                                                  'type': 'KnownFunctionalInteraction'},
#  'GIANT_culture_condition_cd8_cell_ProbabilityOfFunctionalInteraction': {'bg_term': 'culture_condition_cd8_cell',
#                                                                          'cancer_type': None,
#                                                                          'source': 'GIANT',
#                                                                          'tissue': {'bg_label': 'culture_condition_cd8_cell',
#                                                                                     'bto': None,
#                                                                                     'uberon': None},
#                                                                          'type': 'ProbabilityOfFunctionalInteraction'},
#  'GIANT_dendritic_cell_KnownFunctionalInteraction': {'bg_term': 'dendritic_cell',
#                                                      'cancer_type': None,
#                                                      'source': 'GIANT',
#                                                      'tissue': {'bg_label': 'dendritic_cell',
#                                                                 'bto': 'BTO:0002042',
#                                                                 'uberon': None},
#                                                      'type': 'KnownFunctionalInteraction'},
#  'GIANT_dendritic_cell_ProbabilityOfFunctionalInteraction': {'bg_term': 'dendritic_cell',
#                                                              'cancer_type': None,
#                                                              'source': 'GIANT',
#                                                              'tissue': {'bg_label': 'dendritic_cell',
#                                                                         'bto': 'BTO:0002042',
#                                                                         'uberon': None},
#                                                              'type': 'ProbabilityOfFunctionalInteraction'},
#  'GIANT_dentate_gyrus_KnownFunctionalInteraction': {'bg_term': 'dentate_gyrus',
#                                                     'cancer_type': None,
#                                                     'source': 'GIANT',
#                                                     'tissue': {'bg_label': 'dentate_gyrus',
#                                                                'bto': 'BTO:0002496',
# ...
#                                'cancer_type': None,
#                                'source': 'GTEx',
#                                'tissue': {'bg_label': 'prostate',
#                                           'bto': None,
#                                           'uberon': None},
#                                'type': 'Correlation'},
#  'GTEx_Prostate_Pvalue': {'bg_term': 'prostate',
#                           'cancer_type': None,
#                           'source': 'GTEx',
#                           'tissue': {'bg_label': 'prostate',
#                                      'bto': None,
#                                      'uberon': None},
#                           'type': 'Pvalue'},
#  'GTEx_Skin_Correlation': {'bg_term': 'skin',
#                            'cancer_type': None,
#                            'source': 'GTEx',
#                            'tissue': {'bg_label': 'skin',
#                                       'bto': 'BTO:0001253',
#                                       'uberon': 'UBERON:0002097'},
#                            'type': 'Correlation'},
#  'GTEx_Skin_Pvalue': {'bg_term': 'skin',
#                       'cancer_type': None,
#                       'source': 'GTEx',
#                       'tissue': {'bg_label': 'skin',
#                                  'bto': 'BTO:0001253',
#                                  'uberon': 'UBERON:0002097'},
#                       'type': 'Pvalue'},
#  'GTEx_Spleen_Correlation': {'bg_term': 'spleen',
#                              'cancer_type': None,
#                              'source': 'GTEx',
#                              'tissue': {'bg_label': 'spleen',
#                                         'bto': 'BTO:0001281',
#                                         'uberon': 'UBERON:0002106'},
#                              'type': 'Correlation'},
#  'GTEx_Spleen_Pvalue': {'bg_term': 'spleen',
#                         'cancer_type': None,
#                         'source': 'GTEx',
#                         'tissue': {'bg_label': 'spleen',
#                                    'bto': 'BTO:0001281',
#                                    'uberon': 'UBERON:0002106'},
#                         'type': 'Pvalue'},
#  'GTEx_Stomach_Correlation': {'bg_term': 'stomach',
#                               'cancer_type': None,
#                               'source': 'GTEx',
#                               'tissue': {'bg_label': 'stomach',
#                                          'bto': 'BTO:0001307',
#                                          'uberon': 'UBERON:0000945'},
#                               'type': 'Correlation'},
#  'GTEx_Stomach_Pvalue': {'bg_term': 'stomach',
#                          'cancer_type': None,
#                          'source': 'GTEx',
#                          'tissue': {'bg_label': 'stomach',
#                                     'bto': 'BTO:0001307',
#                                     'uberon': 'UBERON:0000945'},
#                          'type': 'Pvalue'},
#  'GTEx_Testis_Correlation': {'bg_term': 'testis',
#                              'cancer_type': None,
#                              'source': 'GTEx',
#                              'tissue': {'bg_label': 'testis',
#                                         'bto': 'BTO:0001363',
#                                         'uberon': 'UBERON:0000473'},
#                              'type': 'Correlation'},
#  'GTEx_Testis_Pvalue': {'bg_term': 'testis',
#                         'cancer_type': None,
#                         'source': 'GTEx',
#                         'tissue': {'bg_label': 'testis',
#                                    'bto': 'BTO:0001363',
#                                    'uberon': 'UBERON:0000473'},
#                         'type': 'Pvalue'},
#  'GTEx_Thyroid_Correlation': {'bg_term': 'thyroid',
#                               'cancer_type': None,
#                               'source': 'GTEx',
#                               'tissue': {'bg_label': 'thyroid',
#                                          'bto': None,
#                                          'uberon': None},
#                               'type': 'Correlation'},
#  'GTEx_Thyroid_Pvalue': {'bg_term': 'thyroid',
#                          'cancer_type': None,
#                          'source': 'GTEx',
#                          'tissue': {'bg_label': 'thyroid',
#                                     'bto': None,
#                                     'uberon': None},
#                          'type': 'Pvalue'},
#  'TCGA_ACC_Correlation': {'cancer_type': 'ACC',
#                           'source': 'TCGA',
#                           'tissue': None,
#                           'type': 'Correlation'},
#  'TCGA_ACC_Pvalue': {'cancer_type': 'ACC',
#                      'source': 'TCGA',
#                      'tissue': None,
#                      'type': 'Pvalue'},
#  'TCGA_BLCA_Correlation': {'cancer_type': 'BLCA',
#                            'source': 'TCGA',
#                            'tissue': None,
#                            'type': 'Correlation'},
#  'TCGA_BLCA_Pvalue': {'cancer_type': 'BLCA',
#                       'source': 'TCGA',
#                       'tissue': None,
#                       'type': 'Pvalue'},
#  'TCGA_BRCA_Correlation': {'cancer_type': 'BRCA',
#                            'source': 'TCGA',
#                            'tissue': None,
#                            'type': 'Correlation'},
#  'TCGA_BRCA_Pvalue': {'cancer_type': 'BRCA',
#                       'source': 'TCGA',
#                       'tissue': None,
#                       'type': 'Pvalue'},
#  'TCGA_CESC_Correlation': {'cancer_type': 'CESC',
#                            'source': 'TCGA',
#                            'tissue': None,
#                            'type': 'Correlation'},
#  'TCGA_CESC_Pvalue': {'cancer_type': 'CESC',
#                       'source': 'TCGA',
#                       'tissue': None,
#                       'type': 'Pvalue'},
#  'TCGA_CHOL_Correlation': {'cancer_type': 'CHOL',
#                            'source': 'TCGA',
#                            'tissue': None,
#                            'type': 'Correlation'},
#  'TCGA_CHOL_Pvalue': {'cancer_type': 'CHOL',
#                       'source': 'TCGA',
#                       'tissue': None,
#                       'type': 'Pvalue'},
#  'TCGA_COAD_Correlation': {'cancer_type': 'COAD',
#                            'source': 'TCGA',
#                            'tissue': None,
#                            'type': 'Correlation'},
#  'TCGA_COAD_Pvalue': {'cancer_type': 'COAD',
#                       'source': 'TCGA',
#                       'tissue': None,
#                       'type': 'Pvalue'},
#  'TCGA_DLBC_Correlation': {'cancer_type': 'DLBC',
#                            'source': 'TCGA',
#                            'tissue': None,
#                            'type': 'Correlation'},
#  'TCGA_DLBC_Pvalue': {'cancer_type': 'DLBC',
#                       'source': 'TCGA',
#                       'tissue': None,
#                       'type': 'Pvalue'},
#  'TCGA_ESCA_Correlation': {'cancer_type': 'ESCA',
#                            'source': 'TCGA',
#                            'tissue': None,
#                            'type': 'Correlation'},
#  'TCGA_ESCA_Pvalue': {'cancer_type': 'ESCA',
#                       'source': 'TCGA',
#                       'tissue': None,
#                       'type': 'Pvalue'},
#  'TCGA_GBM_Correlation': {'cancer_type': 'GBM',
#                           'source': 'TCGA',
#                           'tissue': None,
#                           'type': 'Correlation'},
#  'TCGA_GBM_Pvalue': {'cancer_type': 'GBM',
#                      'source': 'TCGA',
#                      'tissue': None,
#                      'type': 'Pvalue'},
#  'TCGA_HNSC_Correlation': {'cancer_type': 'HNSC',
#                            'source': 'TCGA',
#                            'tissue': None,
#                            'type': 'Correlation'},
#  'TCGA_HNSC_Pvalue': {'cancer_type': 'HNSC',
#                       'source': 'TCGA',
#                       'tissue': None,
#                       'type': 'Pvalue'},
#  'TCGA_KICH_Correlation': {'cancer_type': 'KICH',
#                            'source': 'TCGA',
#                            'tissue': None,
#                            'type': 'Correlation'},
#  'TCGA_KICH_Pvalue': {'cancer_type': 'KICH',
#                       'source': 'TCGA',
#                       'tissue': None,
#                       'type': 'Pvalue'},
#  'TCGA_KIRC_Correlation': {'cancer_type': 'KIRC',
#                            'source': 'TCGA',
#                            'tissue': None,
#                            'type': 'Correlation'},
#  'TCGA_KIRC_Pvalue': {'cancer_type': 'KIRC',
#                       'source': 'TCGA',
#                       'tissue': None,
#                       'type': 'Pvalue'},
#  'TCGA_KIRP_Correlation': {'cancer_type': 'KIRP',
#                            'source': 'TCGA',
#                            'tissue': None,
#                            'type': 'Correlation'},
#  'TCGA_KIRP_Pvalue': {'cancer_type': 'KIRP',
#                       'source': 'TCGA',
#                       'tissue': None,
#                       'type': 'Pvalue'},
#  'TCGA_LAML_Correlation': {'cancer_type': 'LAML',
#                            'source': 'TCGA',
#                            'tissue': None,
#                            'type': 'Correlation'},
#  'TCGA_LAML_Pvalue': {'cancer_type': 'LAML',
#                       'source': 'TCGA',
#                       'tissue': None,
#                       'type': 'Pvalue'},
#  'TCGA_LGG_Correlation': {'cancer_type': 'LGG',
#                           'source': 'TCGA',
#                           'tissue': None,
#                           'type': 'Correlation'},
#  'TCGA_LGG_Pvalue': {'cancer_type': 'LGG',
#                      'source': 'TCGA',
#                      'tissue': None,
#                      'type': 'Pvalue'},
#  'TCGA_LIHC_Correlation': {'cancer_type': 'LIHC',
#                            'source': 'TCGA',
#                            'tissue': None,
#                            'type': 'Correlation'},
#  'TCGA_LIHC_Pvalue': {'cancer_type': 'LIHC',
#                       'source': 'TCGA',
#                       'tissue': None,
#                       'type': 'Pvalue'},
#  'TCGA_LUAD_Correlation': {'cancer_type': 'LUAD',
#                            'source': 'TCGA',
#                            'tissue': None,
#                            'type': 'Correlation'},
#  'TCGA_LUAD_Pvalue': {'cancer_type': 'LUAD',
#                       'source': 'TCGA',
#                       'tissue': None,
#                       'type': 'Pvalue'},
#  'TCGA_LUSC_Correlation': {'cancer_type': 'LUSC',
#                            'source': 'TCGA',
#                            'tissue': None,
#                            'type': 'Correlation'},
#  'TCGA_LUSC_Pvalue': {'cancer_type': 'LUSC',
#                       'source': 'TCGA',
#                       'tissue': None,
#                       'type': 'Pvalue'},
#  'TCGA_MESO_Correlation': {'cancer_type': 'MESO',
#                            'source': 'TCGA',
#                            'tissue': None,
#                            'type': 'Correlation'},
#  'TCGA_MESO_Pvalue': {'cancer_type': 'MESO',
#                       'source': 'TCGA',
#                       'tissue': None,
#                       'type': 'Pvalue'},
#  'TCGA_OV_Correlation': {'cancer_type': 'OV',
#                          'source': 'TCGA',
#                          'tissue': None,
#                          'type': 'Correlation'},
#  'TCGA_OV_Pvalue': {'cancer_type': 'OV',
#                     'source': 'TCGA',
#                     'tissue': None,
#                     'type': 'Pvalue'},
#  'TCGA_PAAD_Correlation': {'cancer_type': 'PAAD',
#                            'source': 'TCGA',
#                            'tissue': None,
#                            'type': 'Correlation'},
#  'TCGA_PAAD_Pvalue': {'cancer_type': 'PAAD',
#                       'source': 'TCGA',
#                       'tissue': None,
#                       'type': 'Pvalue'},
#  'TCGA_PCPG_Correlation': {'cancer_type': 'PCPG',
#                            'source': 'TCGA',
#                            'tissue': None,
#                            'type': 'Correlation'},
#  'TCGA_PCPG_Pvalue': {'cancer_type': 'PCPG',
#                       'source': 'TCGA',
#                       'tissue': None,
#                       'type': 'Pvalue'},
#  'TCGA_PRAD_Correlation': {'cancer_type': 'PRAD',
#                            'source': 'TCGA',
#                            'tissue': None,
#                            'type': 'Correlation'},
#  'TCGA_PRAD_Pvalue': {'cancer_type': 'PRAD',
#                       'source': 'TCGA',
#                       'tissue': None,
#                       'type': 'Pvalue'},
#  'TCGA_READ_Correlation': {'cancer_type': 'READ',
#                            'source': 'TCGA',
#                            'tissue': None,
#                            'type': 'Correlation'},
#  'TCGA_READ_Pvalue': {'cancer_type': 'READ',
#                       'source': 'TCGA',
#                       'tissue': None,
#                       'type': 'Pvalue'},
#  'TCGA_SARC_Correlation': {'cancer_type': 'SARC',
#                            'source': 'TCGA',
#                            'tissue': None,
#                            'type': 'Correlation'},
#  'TCGA_SARC_Pvalue': {'cancer_type': 'SARC',
#                       'source': 'TCGA',
#                       'tissue': None,
#                       'type': 'Pvalue'},
#  'TCGA_SKCM_Correlation': {'cancer_type': 'SKCM',
#                            'source': 'TCGA',
#                            'tissue': None,
#                            'type': 'Correlation'},
#  'TCGA_SKCM_Pvalue': {'cancer_type': 'SKCM',
#                       'source': 'TCGA',
#                       'tissue': None,
#                       'type': 'Pvalue'},
#  'TCGA_STAD_Correlation': {'cancer_type': 'STAD',
#                            'source': 'TCGA',
#                            'tissue': None,
#                            'type': 'Correlation'},
#  'TCGA_STAD_Pvalue': {'cancer_type': 'STAD',
#                       'source': 'TCGA',
#                       'tissue': None,
#                       'type': 'Pvalue'},
#  'TCGA_TGCT_Correlation': {'cancer_type': 'TGCT',
#                            'source': 'TCGA',
#                            'tissue': None,
#                            'type': 'Correlation'},
#  'TCGA_TGCT_Pvalue': {'cancer_type': 'TGCT',
#                       'source': 'TCGA',
#                       'tissue': None,
#                       'type': 'Pvalue'},
#  'TCGA_THCA_Correlation': {'cancer_type': 'THCA',
#                            'source': 'TCGA',
#                            'tissue': None,
#                            'type': 'Correlation'},
#  'TCGA_THCA_Pvalue': {'cancer_type': 'THCA',
#                       'source': 'TCGA',
#                       'tissue': None,
#                       'type': 'Pvalue'},
#  'TCGA_THYM_Correlation': {'cancer_type': 'THYM',
#                            'source': 'TCGA',
#                            'tissue': None,
#                            'type': 'Correlation'},
#  'TCGA_THYM_Pvalue': {'cancer_type': 'THYM',
#                       'source': 'TCGA',
#                       'tissue': None,
#                       'type': 'Pvalue'},
#  'TCGA_UCEC_Correlation': {'cancer_type': 'UCEC',
#                            'source': 'TCGA',
#                            'tissue': None,
#                            'type': 'Correlation'},
#  'TCGA_UCEC_Pvalue': {'cancer_type': 'UCEC',
#                       'source': 'TCGA',
#                       'tissue': None,
#                       'type': 'Pvalue'},
#  'TCGA_UCS_Correlation': {'cancer_type': 'UCS',
#                           'source': 'TCGA',
#                           'tissue': None,
#                           'type': 'Correlation'},
#  'TCGA_UCS_Pvalue': {'cancer_type': 'UCS',
#                      'source': 'TCGA',
#                      'tissue': None,
#                      'type': 'Pvalue'},
#  'TCGA_UVM_Correlation': {'cancer_type': 'UVM',
#                           'source': 'TCGA',
#                           'tissue': None,
#                           'type': 'Correlation'},
#  'TCGA_UVM_Pvalue': {'cancer_type': 'UVM',
#                      'source': 'TCGA',
#                      'tissue': None,
#                      'type': 'Pvalue'}}

# %%
with open('bg_column_map.json', 'w') as outfile:
    json.dump(column_map, outfile)

# %%
# map of columns to metadata objects
meta_columns = json.loads(open ('bg_column_map.json').read())

# %%
r1 = requests.get('http://biggim.ncats.io/api/interactions/query?columns=GTEx_Testis_Correlation,GTEx_Testis_Pvalue,TCGA_GBM_Correlation,TCGA_GBM_Pvalue,GTEx_Brain_Correlation,GTEx_Brain_Pvalue&ids1=5111,6996,57697,6815,889,7112,2176,1019,5888,5706,5722,1111,112,3333&ids2=5111,6996,57697,6815,889,7112,2176,1019,5888,5706,3333,1111,112,3333&limit=10000&restriction_gt=TCGA_GBM_Correlation,.2,%20GTEx_Brain_Correlation,.2&restriction_join=union&restriction_lt=TCGA_GBM_Pvalue,.05,%20GTEx_Brain_Pvalue,.01&table=BigGIM_70_v1')
r1 = r1.json()

# %%
r2 = requests.get('http://biggim.ncats.io/api/interactions/query/status/{}'.format(r1['request_id']))
r2 = r2.json()
r2
# Out:
# {'processed_data': '0B',
#  'request_id': '2b009ac2-4e56-4db7-ae27-9473a82cac92',
#  'request_uri': ['https://storage.googleapis.com/ncats_bigquery_results/2b009ac2-4e56-4db7-ae27-9473a82cac92000000000000.csv'],
#  'rows': 54,
#  'size': '3.3 KB',
#  'status': 'complete'}

# %%
ex_q1 ='http://biggim.ncats.io/api/interactions/query?columns=BioGRID_Interaction,BioGRID_Experimental_System_Type,BioGRID_Throughput,BioGRID_Experimental_System&ids1=5111,6996,57697,6815,889,7112,2176,1019,5888,5706,5722,1111,112,3333&ids2=5111,6996,57697,6815,889,7112,2176,1019,5888,5706,3333,1111,112,3333&limit=10000&restriction_gt=TCGA_GBM_Correlation,.2,%20GTEx_Brain_Correlation,.2&restriction_join=union&restriction_lt=TCGA_GBM_Pvalue,.05,%20GTEx_Brain_Pvalue,.01&table=BigGIM_70_v1'
r3 = requests.get(ex_q1)
r3 = r3.json()
r3
# Out:
# {'request_id': '514592d5-f6e9-4dc3-8ff9-a39b1b0ef1ff', 'status': 'submitted'}

# %%
r4 = requests.get('http://biggim.ncats.io/api/interactions/query/status/{}'.format(r3['request_id']))
r4 = r4.json()
r4
# Out:
# {'processed_data': '0B',
#  'request_id': '514592d5-f6e9-4dc3-8ff9-a39b1b0ef1ff',
#  'request_uri': ['https://storage.googleapis.com/ncats_bigquery_results/514592d5-f6e9-4dc3-8ff9-a39b1b0ef1ff000000000000.csv'],
#  'rows': 54,
#  'size': '2.3 KB',
#  'status': 'complete'}

# %%
r3_pd = pd.read_csv(r4['request_uri'][0])

# %%
r3_pd
# Out:
#               GPID  Gene1  Gene2 BioGRID_Interaction  \
# 0   58880000007112   7112   5888                 NaN
# 1   58880000057697  57697   5888                 NaN
# 2   57060000006815   6815   5706                 NaN
# 3   57060000007112   7112   5706                 NaN
# 4   57060000057697  57697   5706                 NaN
# 5   57060000006996   6996   5706                 NaN
# 6   69960000007112   7112   6996                 NaN
# 7   69960000057697  57697   6996                 NaN
# 8   11110000002176   2176   1111                 NaN
# 9   11110000006815   6815   1111                 NaN
# 10  11110000057697  57697   1111                 NaN
# 11  11110000007112   7112   1111                 NaN
# 12   1120000002176   2176    112                 NaN
# 13   1120000000889    889    112                 NaN
# 14   1120000005888   5888    112                 NaN
# 15   1120000005111   5111    112                 NaN
# 16   1120000001111   1111    112                 NaN
# 17   1120000007112   7112    112                 NaN
# 18   1120000001019   1019    112                 NaN
# 19   8890000006996   6996    889                 NaN
# 20   8890000005111   5111    889                 NaN
# 21   8890000007112   7112    889                 NaN
# 22   8890000001019   1019    889                 NaN
# 23   8890000057697  57697    889                 NaN
# 24   8890000005706   5706    889                 NaN
# 25   8890000002176   2176    889                 NaN
# 26   8890000006815   6815    889                 NaN
# 27  21760000005888   5888   2176                 NaN
# 28  21760000007112   7112   2176                 NaN
# 29  21760000006815   6815   2176                 NaN
# 30  21760000005111   5111   2176                 NaN
# 31  21760000006996   6996   2176                 NaN
# 32  68150000006996   6996   6815                 NaN
# 33  68150000057697  57697   6815                 NaN
# 34  68150000007112   7112   6815                 NaN
# 35  71120000057697  57697   7112                 NaN
# 36  51110000006815   6815   5111                 NaN
# 37  51110000007112   7112   5111                 NaN
# 38  51110000005706   5706   5111                 NaN
# 39  10190000006996   6996   1019                 NaN
# 40  10190000005706   5706   1019                 NaN
# 41  10190000005888   5888   1019                 NaN
# 42  10190000002176   2176   1019                 NaN
# 43  10190000006815   6815   1019                 NaN
# 44  10190000001111   1111   1019                 NaN
# 45  10190000007112   7112   1019                 NaN
# 46  10190000057697  57697   1019                 NaN
# 47  51110000057697  57697   5111                True
# 48  11110000005111   5111   1111                True
# 49  51110000005888   5888   5111                True
# 50  51110000006996   6996   5111                True
# 51  11110000005888   5888   1111                True
# 52  10190000005111   5111   1019                True
# 53  21760000057697  57697   2176                True
#
#        BioGRID_Experimental_System_Type  \
# 0                                   NaN
# 1                                   NaN
# 2                                   NaN
# 3                                   NaN
# 4                                   NaN
# 5                                   NaN
# 6                                   NaN
# 7                                   NaN
# 8                                   NaN
# 9                                   NaN
# 10                                  NaN
# 11                                  NaN
# 12                                  NaN
# 13                                  NaN
# 14                                  NaN
# 15                                  NaN
# 16                                  NaN
# 17                                  NaN
# 18                                  NaN
# 19                                  NaN
# 20                                  NaN
# 21                                  NaN
# 22                                  NaN
# 23                                  NaN
# 24                                  NaN
# 25                                  NaN
# 26                                  NaN
# 27                                  NaN
# 28                                  NaN
# 29                                  NaN
# 30                                  NaN
# 31                                  NaN
# 32                                  NaN
# 33                                  NaN
# 34                                  NaN
# 35                                  NaN
# 36                                  NaN
# 37                                  NaN
# 38                                  NaN
# 39                                  NaN
# 40                                  NaN
# 41                                  NaN
# 42                                  NaN
# 43                                  NaN
# 44                                  NaN
# 45                                  NaN
# 46                                  NaN
# 47                             physical
# 48                             physical
# 49                             physical
# 50                    physical,physical
# 51                    physical,physical
# 52           physical,physical,physical
# 53  physical,physical,physical,physical
#
#                                    BioGRID_Throughput  \
# 0                                                 NaN
# 1                                                 NaN
# 2                                                 NaN
# 3                                                 NaN
# 4                                                 NaN
# 5                                                 NaN
# 6                                                 NaN
# 7                                                 NaN
# 8                                                 NaN
# 9                                                 NaN
# 10                                                NaN
# 11                                                NaN
# 12                                                NaN
# 13                                                NaN
# 14                                                NaN
# 15                                                NaN
# 16                                                NaN
# 17                                                NaN
# 18                                                NaN
# 19                                                NaN
# 20                                                NaN
# 21                                                NaN
# 22                                                NaN
# 23                                                NaN
# 24                                                NaN
# 25                                                NaN
# 26                                                NaN
# 27                                                NaN
# 28                                                NaN
# 29                                                NaN
# 30                                                NaN
# 31                                                NaN
# 32                                                NaN
# 33                                                NaN
# 34                                                NaN
# 35                                                NaN
# 36                                                NaN
# 37                                                NaN
# 38                                                NaN
# 39                                                NaN
# 40                                                NaN
# 41                                                NaN
# 42                                                NaN
# 43                                                NaN
# 44                                                NaN
# 45                                                NaN
# 46                                                NaN
# 47                                    High Throughput
# 48                                     Low Throughput
# 49                                     Low Throughput
# 50                      Low Throughput,Low Throughput
# 51                      Low Throughput,Low Throughput
# 52       Low Throughput,Low Throughput,Low Throughput
# 53  Low Throughput,Low Throughput,Low Throughput,L...
#
#                           BioGRID_Experimental_System
# 0                                                 NaN
# 1                                                 NaN
# 2                                                 NaN
# 3                                                 NaN
# 4                                                 NaN
# 5                                                 NaN
# 6                                                 NaN
# 7                                                 NaN
# 8                                                 NaN
# 9                                                 NaN
# 10                                                NaN
# 11                                                NaN
# 12                                                NaN
# 13                                                NaN
# 14                                                NaN
# 15                                                NaN
# 16                                                NaN
# 17                                                NaN
# 18                                                NaN
# 19                                                NaN
# 20                                                NaN
# 21                                                NaN
# 22                                                NaN
# 23                                                NaN
# 24                                                NaN
# 25                                                NaN
# 26                                                NaN
# 27                                                NaN
# 28                                                NaN
# 29                                                NaN
# 30                                                NaN
# 31                                                NaN
# 32                                                NaN
# 33                                                NaN
# 34                                                NaN
# 35                                                NaN
# 36                                                NaN
# 37                                                NaN
# 38                                                NaN
# 39                                                NaN
# 40                                                NaN
# 41                                                NaN
# 42                                                NaN
# 43                                                NaN
# 44                                                NaN
# 45                                                NaN
# 46                                                NaN
# 47                                Affinity Capture-MS
# 48                           Affinity Capture-Western
# 49                           Affinity Capture-Western
# 50     Affinity Capture-Western,Reconstituted Complex
# 51  Affinity Capture-Western,Affinity Capture-Western
# 52  Affinity Capture-Western,Affinity Capture-West...
# 53  Affinity Capture-MS,Affinity Capture-MS,Affini...

# %%
def remove_kv_pair(obj, key):
    obj1 = obj.copy()
    obj1.pop(key)
    return obj1

def pandas2json(request_uri):
    # use pandas to get csv with request uri and serialize into json for return
    pd_df = pd.read_csv(request_uri)
    out_json = json.loads(pd_df.to_json(orient='records'))
    final_json = list()
    for record in out_json:
        d = defaultdict(list)
        new_record = {
            'Gene1': record['Gene1'],
            'Gene2': record['Gene2'],
            'GPID': record['GPID'],
            'interactions': []
        }
        sources = {
            'BioGRID': defaultdict(list),
            'TCGA': defaultdict(list),
            'GTEx': defaultdict(list),
            'GIANT': defaultdict(list)
        }
        for k, v in record.items():
            if k in meta_columns.keys() and v is not None:
                col = meta_columns[k]
                int_source = col['source']
                if int_source == 'BioGRID' and isinstance(v, str):
                    v = v.split(',')
                    v = ",".join(set(v))
                if col['tissue'] is not None:
                    col[col['type']] = v
                    new_col = remove_kv_pair(col, 'type')
                    sources[int_source][col['tissue']['bg_label']].append(new_col)
                if col['cancer_type'] is not None:
                    col[col['type']] = v
                    new_col = remove_kv_pair(col, 'type')
                    sources[int_source][col['cancer_type']].append(new_col)
        for skey in sources.keys():
            for k,v in sources[skey].items():
                for vobj in v[1:]:
                    v[0].update(vobj)
                new_record['interactions'].append(v[0])
        final_json.append(new_record)
    return final_json

# %%
pandas2json(request_uri=r2['request_uri'][0])
# Out:
# [{'GPID': 21760000005888,
#   'Gene1': 5888,
#   'Gene2': 2176,
#   'interactions': [{'Correlation': 0.543,
#     'Pvalue': 9.83,
#     'cancer_type': 'GBM',
#     'source': 'TCGA',
#     'tissue': None},
#    {'Correlation': 0.4106,
#     'Pvalue': 7.65,
#     'bg_term': 'testis',
#     'cancer_type': None,
#     'source': 'GTEx',
#     'tissue': {'bg_label': 'testis',
#      'bto': 'BTO:0001363',
#      'uberon': 'UBERON:0000473'}},
#    {'Correlation': 0.5403,
#     'Pvalue': 95.62,
#     'bg_term': 'brain',
#     'cancer_type': None,
#     'source': 'GTEx',
#     'tissue': {'bg_label': 'brain',
#      'bto': 'BTO:0000142',
#      'uberon': 'UBERON:0000955'}}]},
#  {'GPID': 11110000005888,
#   'Gene1': 5888,
#   'Gene2': 1111,
#   'interactions': [{'Correlation': 0.653,
#     'Pvalue': 15.2,
#     'cancer_type': 'GBM',
#     'source': 'TCGA',
#     'tissue': None},
#    {'Correlation': 0.2869,
#     'Pvalue': 3.87,
#     'bg_term': 'testis',
#     'cancer_type': None,
#     'source': 'GTEx',
#     'tissue': {'bg_label': 'testis',
#      'bto': 'BTO:0001363',
#      'uberon': 'UBERON:0000473'}},
#    {'Correlation': -0.0131,
#     'Pvalue': 0.19,
#     'bg_term': 'brain',
#     'cancer_type': None,
#     'source': 'GTEx',
#     'tissue': {'bg_label': 'brain',
#      'bto': 'BTO:0000142',
#      'uberon': 'UBERON:0000955'}}]},
#  {'GPID': 10190000005888,
#   'Gene1': 5888,
#   'Gene2': 1019,
#   'interactions': [{'Correlation': 0.5021,
#     'Pvalue': 8.29,
#     'cancer_type': 'GBM',
#     'source': 'TCGA',
#     'tissue': None},
#    {'Correlation': -0.4646,
#     'Pvalue': 9.86,
#     'bg_term': 'testis',
#     'cancer_type': None,
#     'source': 'GTEx',
#     'tissue': {'bg_label': 'testis',
#      'bto': 'BTO:0001363',
#      'uberon': 'UBERON:0000473'}},
#    {'Correlation': 0.3958,
#     'Pvalue': 47.76,
#     'bg_term': 'brain',
#     'cancer_type': None,
#     'source': 'GTEx',
#     'tissue': {'bg_label': 'brain',
#      'bto': 'BTO:0000142',
#      'uberon': 'UBERON:0000955'}}]},
#  {'GPID': 1120000005888,
#   'Gene1': 5888,
#   'Gene2': 112,
#   'interactions': [{'Correlation': 0.0019,
#     'Pvalue': 0.01,
#     'cancer_type': 'GBM',
#     'source': 'TCGA',
#     'tissue': None},
#    {'Correlation': -0.5449,
#     'Pvalue': 13.96,
#     'bg_term': 'testis',
#     'cancer_type': None,
#     'source': 'GTEx',
#     'tissue': {'bg_label': 'testis',
#      'bto': 'BTO:0001363',
#      'uberon': 'UBERON:0000473'}},
#    {'Correlation': 0.556,
#     'Pvalue': 102.35,
#     'bg_term': 'brain',
#     'cancer_type': None,
#     'source': 'GTEx',
#     'tissue': {'bg_label': 'brain',
#      'bto': 'BTO:0000142',
#      'uberon': 'UBERON:0000955'}}]},
#  {'GPID': 51110000005888,
#   'Gene1': 5888,
#   'Gene2': 5111,
#   'interactions': [{'Correlation': 0.5431,
#     'Pvalue': 9.83,
#     'cancer_type': 'GBM',
#     'source': 'TCGA',
#     'tissue': None},
#    {'Correlation': 0.551,
#     'Pvalue': 100.17,
#     'bg_term': 'brain',
#     'cancer_type': None,
#     'source': 'GTEx',
#     'tissue': {'bg_label': 'brain',
#      'bto': 'BTO:0000142',
#      'uberon': 'UBERON:0000955'}}]},
#  {'GPID': 10190000005706,
#   'Gene1': 5706,
#   'Gene2': 1019,
#   'interactions': [{'Correlation': 0.22,
#     'Pvalue': 1.8,
#     'cancer_type': 'GBM',
#     'source': 'TCGA',
#     'tissue': None},
#    {'Correlation': 0.7475,
#     'Pvalue': 31.29,
#     'bg_term': 'testis',
#     'cancer_type': None,
#     'source': 'GTEx',
#     'tissue': {'bg_label': 'testis',
#      'bto': 'BTO:0001363',
#      'uberon': 'UBERON:0000473'}},
#    {'Correlation': 0.4353,
#     'Pvalue': 58.63,
#     'bg_term': 'brain',
#     'cancer_type': None,
#     'source': 'GTEx',
#     'tissue': {'bg_label': 'brain',
#      'bto': 'BTO:0000142',
#      'uberon': 'UBERON:0000955'}}]},
#  {'GPID': 51110000005706,
#   'Gene1': 5706,
#   'Gene2': 5111,
#   'interactions': [{'Correlation': 0.3278,
#     'Pvalue': 3.59,
#     'cancer_type': 'GBM',
#     'source': 'TCGA',
#     'tissue': None},
#    {'Correlation': 0.7406,
#     'Pvalue': 218.54,
#     'bg_term': 'brain',
#     'cancer_type': None,
#     'source': 'GTEx',
#     'tissue': {'bg_label': 'brain',
#      'bto': 'BTO:0000142',
#      'uberon': 'UBERON:0000955'}}]},
#  {'GPID': 8890000005706,
#   'Gene1': 5706,
#   'Gene2': 889,
#   'interactions': [{'Correlation': -0.0382,
#     'Pvalue': 0.17,
#     'cancer_type': 'GBM',
#     'source': 'TCGA',
#     'tissue': None},
#    {'Correlation': 0.3445,
#     'Pvalue': 5.43,
#     'bg_term': 'testis',
#     'cancer_type': None,
#     'source': 'GTEx',
#     'tissue': {'bg_label': 'testis',
#      'bto': 'BTO:0001363',
#      'uberon': 'UBERON:0000473'}},
#    {'Correlation': 0.8163,
#     'Pvalue': 301.2,
#     'bg_term': 'brain',
#     'cancer_type': None,
#     'source': 'GTEx',
#     'tissue': {'bg_label': 'brain',
#      'bto': 'BTO:0000142',
#      'uberon': 'UBERON:0000955'}}]},
#  {'GPID': 10190000006996,
#   'Gene1': 6996,
#   'Gene2': 1019,
#   'interactions': [{'Correlation': 0.3294,
#     'Pvalue': 3.62,
#     'cancer_type': 'GBM',
#     'source': 'TCGA',
#     'tissue': None},
#    {'Correlation': 0.6306,
#     'Pvalue': 19.73,
#     'bg_term': 'testis',
#     'cancer_type': None,
#     'source': 'GTEx',
#     'tissue': {'bg_label': 'testis',
#      'bto': 'BTO:0001363',
#      'uberon': 'UBERON:0000473'}},
#    {'Correlation': 0.4184,
#     'Pvalue': 53.8,
#     'bg_term': 'brain',
#     'cancer_type': None,
#     'source': 'GTEx',
#     'tissue': {'bg_label': 'brain',
#      'bto': 'BTO:0000142',
#      'uberon': 'UBERON:0000955'}}]},
#  {'GPID': 8890000006996,
#   'Gene1': 6996,
#   'Gene2': 889,
#   'interactions': [{'Correlation': 0.036,
#     'Pvalue': 0.16,
#     'cancer_type': 'GBM',
#     'source': 'TCGA',
#     'tissue': None},
#    {'Correlation': 0.1051,
#     'Pvalue': 0.77,
#     'bg_term': 'testis',
#     'cancer_type': None,
#     'source': 'GTEx',
#     'tissue': {'bg_label': 'testis',
#      'bto': 'BTO:0001363',
#      'uberon': 'UBERON:0000473'}},
#    {'Correlation': 0.808,
#     'Pvalue': 290.39,
#     'bg_term': 'brain',
#     'cancer_type': None,
#     'source': 'GTEx',
#     'tissue': {'bg_label': 'brain',
#      'bto': 'BTO:0000142',
#      'uberon': 'UBERON:0000955'}}]},
#  {'GPID': 57060000006996,
#   'Gene1': 6996,
#   'Gene2': 5706,
#   'interactions': [{'Correlation': 0.4229,
#     'Pvalue': 5.83,
#     'cancer_type': 'GBM',
#     'source': 'TCGA',
#     'tissue': None},
#    {'Correlation': 0.7844,
#     'Pvalue': 36.38,
#     'bg_term': 'testis',
#     'cancer_type': None,
#     'source': 'GTEx',
#     'tissue': {'bg_label': 'testis',
#      'bto': 'BTO:0001363',
#      'uberon': 'UBERON:0000473'}},
#    {'Correlation': 0.6719,
#     'Pvalue': 165.37,
#     'bg_term': 'brain',
#     'cancer_type': None,
#     'source': 'GTEx',
#     'tissue': {'bg_label': 'brain',
#      'bto': 'BTO:0000142',
#      'uberon': 'UBERON:0000955'}}]},
#  {'GPID': 51110000006996,
#   'Gene1': 6996,
#   'Gene2': 5111,
#   'interactions': [{'Correlation': 0.2376,
#     'Pvalue': 2.05,
#     'cancer_type': 'GBM',
#     'source': 'TCGA',
#     'tissue': None},
#    {'Correlation': 0.6761,
#     'Pvalue': 168.19,
#     'bg_term': 'brain',
#     'cancer_type': None,
#     'source': 'GTEx',
#     'tissue': {'bg_label': 'brain',
#      'bto': 'BTO:0000142',
#      'uberon': 'UBERON:0000955'}}]},
#  {'GPID': 21760000006996,
#   'Gene1': 6996,
#   'Gene2': 2176,
#   'interactions': [{'Correlation': 0.0334,
#     'Pvalue': 0.14,
#     'cancer_type': 'GBM',
#     'source': 'TCGA',
#     'tissue': None},
#    {'Correlation': -0.4581,
#     'Pvalue': 9.58,
#     'bg_term': 'testis',
#     'cancer_type': None,
#     'source': 'GTEx',
#     'tissue': {'bg_label': 'testis',
#      'bto': 'BTO:0001363',
#      'uberon': 'UBERON:0000473'}},
#    {'Correlation': 0.6541,
#     'Pvalue': 153.85,
#     'bg_term': 'brain',
#     'cancer_type': None,
#     'source': 'GTEx',
#     'tissue': {'bg_label': 'brain',
#      'bto': 'BTO:0000142',
#      'uberon': 'UBERON:0000955'}}]},
#  {'GPID': 68150000006996,
#   'Gene1': 6996,
#   'Gene2': 6815,
#   'interactions': [{'Correlation': 0.0446,
#     'Pvalue': 0.2,
#     'cancer_type': 'GBM',
#     'source': 'TCGA',
#     'tissue': None},
#    {'Correlation': -0.0986,
#     'Pvalue': 0.7,
#     'bg_term': 'testis',
#     'cancer_type': None,
#     'source': 'GTEx',
#     'tissue': {'bg_label': 'testis',
#      'bto': 'BTO:0001363',
#      'uberon': 'UBERON:0000473'}},
#    {'Correlation': 0.5802,
#     'Pvalue': 113.44,
#     'bg_term': 'brain',
#     'cancer_type': None,
#     'source': 'GTEx',
#     'tissue': {'bg_label': 'brain',
#      'bto': 'BTO:0000142',
#      'uberon': 'UBERON:0000955'}}]},
#  {'GPID': 1120000001111,
#   'Gene1': 1111,
#   'Gene2': 112,
#   'interactions': [{'Correlation': -0.0028,
#     'Pvalue': 0.01,
#     'cancer_type': 'GBM',
#     'source': 'TCGA',
#     'tissue': None},
#    {'Correlation': 0.0592,
#     'Pvalue': 0.36,
#     'bg_term': 'testis',
#     'cancer_type': None,
#     'source': 'GTEx',
#     'tissue': {'bg_label': 'testis',
#      'bto': 'BTO:0001363',
#      'uberon': 'UBERON:0000473'}},
#    {'Correlation': -0.2528,
#     'Pvalue': 19.09,
#     'bg_term': 'brain',
#     'cancer_type': None,
#     'source': 'GTEx',
#     'tissue': {'bg_label': 'brain',
#      'bto': 'BTO:0000142',
#      'uberon': 'UBERON:0000955'}}]},
#  {'GPID': 10190000001111,
#   'Gene1': 1111,
#   'Gene2': 1019,
#   'interactions': [{'Correlation': 0.405,
#     'Pvalue': 5.35,
#     'cancer_type': 'GBM',
#     'source': 'TCGA',
#     'tissue': None},
#    {'Correlation': 0.2597,
#     'Pvalue': 3.24,
#     'bg_term': 'testis',
#     'cancer_type': None,
#     'source': 'GTEx',
#     'tissue': {'bg_label': 'testis',
#      'bto': 'BTO:0001363',
#      'uberon': 'UBERON:0000473'}},
#    {'Correlation': 0.2117,
#     'Pvalue': 13.49,
#     'bg_term': 'brain',
#     'cancer_type': None,
#     'source': 'GTEx',
#     'tissue': {'bg_label': 'brain',
#      'bto': 'BTO:0000142',
#      'uberon': 'UBERON:0000955'}}]},
#  {'GPID': 68150000057697,
#   'Gene1': 57697,
#   'Gene2': 6815,
#   'interactions': [{'Correlation': 0.2524,
#     'Pvalue': 2.27,
#     'cancer_type': 'GBM',
#     'source': 'TCGA',
#     'tissue': None},
#    {'Correlation': 0.3284,
#     'Pvalue': 4.96,
#     'bg_term': 'testis',
#     'cancer_type': None,
#     'source': 'GTEx',
#     'tissue': {'bg_label': 'testis',
#      'bto': 'BTO:0001363',
#      'uberon': 'UBERON:0000473'}},
#    {'Correlation': 0.5279,
#     'Pvalue': 90.55,
#     'bg_term': 'brain',
#     'cancer_type': None,
#     'source': 'GTEx',
#     'tissue': {'bg_label': 'brain',
#      'bto': 'BTO:0000142',
#      'uberon': 'UBERON:0000955'}}]},
#  {'GPID': 21760000057697,
#   'Gene1': 57697,
#   'Gene2': 2176,
#   'interactions': [{'Correlation': 0.5478,
#     'Pvalue': 10.02,
#     'cancer_type': 'GBM',
#     'source': 'TCGA',
#     'tissue': None},
#    {'Correlation': 0.4057,
#     'Pvalue': 7.47,
#     'bg_term': 'testis',
#     'cancer_type': None,
#     'source': 'GTEx',
#     'tissue': {'bg_label': 'testis',
#      'bto': 'BTO:0001363',
#      'uberon': 'UBERON:0000473'}},
#    {'Correlation': 0.5941,
#     'Pvalue': 120.24,
#     'bg_term': 'brain',
#     'cancer_type': None,
#     'source': 'GTEx',
#     'tissue': {'bg_label': 'brain',
#      'bto': 'BTO:0000142',
#      'uberon': 'UBERON:0000955'}}]},
#  {'GPID': 71120000057697,
#   'Gene1': 57697,
#   'Gene2': 7112,
#   'interactions': [{'Correlation': 0.6052,
#     'Pvalue': 12.61,
#     'cancer_type': 'GBM',
#     'source': 'TCGA',
#     'tissue': None},
#    {'Correlation': 0.2892,
#     'Pvalue': 3.92,
#     'bg_term': 'testis',
#     'cancer_type': None,
#     'source': 'GTEx',
#     'tissue': {'bg_label': 'testis',
#      'bto': 'BTO:0001363',
#      'uberon': 'UBERON:0000473'}},
#    {'Correlation': 0.6201,
#     'Pvalue': 133.93,
#     'bg_term': 'brain',
#     'cancer_type': None,
#     'source': 'GTEx',
#     'tissue': {'bg_label': 'brain',
#      'bto': 'BTO:0000142',
#      'uberon': 'UBERON:0000955'}}]},
#  {'GPID': 69960000057697,
#   'Gene1': 57697,
#   'Gene2': 6996,
#   'interactions': [{'Correlation': 0.3473,
#     'Pvalue': 3.99,
#     'cancer_type': 'GBM',
#     'source': 'TCGA',
#     'tissue': None},
#    {'Correlation': -0.4429,
#     'Pvalue': 8.93,
#     'bg_term': 'testis',
#     'cancer_type': None,
#     'source': 'GTEx',
#     'tissue': {'bg_label': 'testis',
#      'bto': 'BTO:0001363',
#      'uberon': 'UBERON:0000473'}},
#    {'Correlation': 0.8152,
#     'Pvalue': 299.7,
#     'bg_term': 'brain',
#     'cancer_type': None,
#     'source': 'GTEx',
#     'tissue': {'bg_label': 'brain',
#      'bto': 'BTO:0000142',
#      'uberon': 'UBERON:0000955'}}]},
#  {'GPID': 10190000057697,
#   'Gene1': 57697,
#   'Gene2': 1019,
#   'interactions': [{'Correlation': 0.2391,
#     'Pvalue': 2.07,
#     'cancer_type': 'GBM',
#     'source': 'TCGA',
#     'tissue': None},
#    {'Correlation': -0.4481,
#     'Pvalue': 9.15,
#     'bg_term': 'testis',
#     'cancer_type': None,
#     'source': 'GTEx',
#     'tissue': {'bg_label': 'testis',
#      'bto': 'BTO:0001363',
#      'uberon': 'UBERON:0000473'}},
#    {'Correlation': 0.3888,
#     'Pvalue': 45.98,
#     'bg_term': 'brain',
#     'cancer_type': None,
#     'source': 'GTEx',
#     'tissue': {'bg_label': 'brain',
#      'bto': 'BTO:0000142',
#      'uberon': 'UBERON:0000955'}}]},
#  {'GPID': 58880000057697,
#   'Gene1': 57697,
#   'Gene2': 5888,
#   'interactions': [{'Correlation': 0.4545,
#     'Pvalue': 6.74,
#     'cancer_type': 'GBM',
#     'source': 'TCGA',
#     'tissue': None},
#    {'Correlation': 0.3614,
#     'Pvalue': 5.95,
#     'bg_term': 'testis',
#     'cancer_type': None,
#     'source': 'GTEx',
#     'tissue': {'bg_label': 'testis',
#      'bto': 'BTO:0001363',
#      'uberon': 'UBERON:0000473'}},
#    {'Correlation': 0.6227,
#     'Pvalue': 135.34,
#     'bg_term': 'brain',
#     'cancer_type': None,
#     'source': 'GTEx',
#     'tissue': {'bg_label': 'brain',
#      'bto': 'BTO:0000142',
#      'uberon': 'UBERON:0000955'}}]},
#  {'GPID': 8890000057697,
#   'Gene1': 57697,
#   'Gene2': 889,
#   'interactions': [{'Correlation': 0.2489,
#     'Pvalue': 2.21,
#     'cancer_type': 'GBM',
#     'source': 'TCGA',
#     'tissue': None},
#    {'Correlation': 0.2223,
#     'Pvalue': 2.47,
#     'bg_term': 'testis',
#     'cancer_type': None,
#     'source': 'GTEx',
#     'tissue': {'bg_label': 'testis',
#      'bto': 'BTO:0001363',
#      'uberon': 'UBERON:0000473'}},
#    {'Correlation': 0.8262,
#     'Pvalue': 314.88,
#     'bg_term': 'brain',
#     'cancer_type': None,
#     'source': 'GTEx',
#     'tissue': {'bg_label': 'brain',
#      'bto': 'BTO:0000142',
#      'uberon': 'UBERON:0000955'}}]},
#  {'GPID': 11110000057697,
#   'Gene1': 57697,
#   'Gene2': 1111,
#   'interactions': [{'Correlation': 0.5158,
#     'Pvalue': 8.78,
#     'cancer_type': 'GBM',
#     'source': 'TCGA',
#     'tissue': None},
#    {'Correlation': 0.1979,
#     'Pvalue': 2.03,
#     'bg_term': 'testis',
#     'cancer_type': None,
#     'source': 'GTEx',
#     'tissue': {'bg_label': 'testis',
#      'bto': 'BTO:0001363',
#      'uberon': 'UBERON:0000473'}},
#    {'Correlation': 0.1124,
#     'Pvalue': 4.19,
#     'bg_term': 'brain',
#     'cancer_type': None,
#     'source': 'GTEx',
#     'tissue': {'bg_label': 'brain',
#      'bto': 'BTO:0000142',
#      'uberon': 'UBERON:0000955'}}]},
#  {'GPID': 51110000057697,
#   'Gene1': 57697,
#   'Gene2': 5111,
#   'interactions': [{'Correlation': 0.3341,
#     'Pvalue': 3.72,
#     'cancer_type': 'GBM',
#     'source': 'TCGA',
#     'tissue': None},
#    {'Correlation': 0.6808,
#     'Pvalue': 171.41,
#     'bg_term': 'brain',
#     'cancer_type': None,
#     'source': 'GTEx',
#     'tissue': {'bg_label': 'brain',
#      'bto': 'BTO:0000142',
#      'uberon': 'UBERON:0000955'}}]},
#  {'GPID': 57060000057697,
#   'Gene1': 57697,
#   'Gene2': 5706,
#   'interactions': [{'Correlation': 0.288,
#     'Pvalue': 2.85,
#     'cancer_type': 'GBM',
#     'source': 'TCGA',
#     'tissue': None},
#    {'Correlation': -0.4341,
#     'Pvalue': 8.57,
#     'bg_term': 'testis',
#     'cancer_type': None,
#     'source': 'GTEx',
#     'tissue': {'bg_label': 'testis',
#      'bto': 'BTO:0001363',
#      'uberon': 'UBERON:0000473'}},
#    {'Correlation': 0.7209,
#     'Pvalue': 201.65,
#     'bg_term': 'brain',
#     'cancer_type': None,
#     'source': 'GTEx',
#     'tissue': {'bg_label': 'brain',
#      'bto': 'BTO:0000142',
#      'uberon': 'UBERON:0000955'}}]},
#  {'GPID': 1120000000889,
#   'Gene1': 889,
#   'Gene2': 112,
#   'interactions': [{'Correlation': 0.13,
#     'Pvalue': 0.8,
#     'cancer_type': 'GBM',
#     'source': 'TCGA',
#     'tissue': None},
#    {'Correlation': 0.1848,
#     'Pvalue': 1.82,
#     'bg_term': 'testis',
#     'cancer_type': None,
#     'source': 'GTEx',
#     'tissue': {'bg_label': 'testis',
#      'bto': 'BTO:0001363',
#      'uberon': 'UBERON:0000473'}},
#    {'Correlation': 0.7565,
#     'Pvalue': 233.37,
#     'bg_term': 'brain',
#     'cancer_type': None,
#     'source': 'GTEx',
#     'tissue': {'bg_label': 'brain',
#      'bto': 'BTO:0000142',
#      'uberon': 'UBERON:0000955'}}]},
#  {'GPID': 1120000002176,
#   'Gene1': 2176,
#   'Gene2': 112,
#   'interactions': [{'Correlation': 0.2329,
#     'Pvalue': 1.98,
#     'cancer_type': 'GBM',
#     'source': 'TCGA',
#     'tissue': None},
#    {'Correlation': -0.3672,
#     'Pvalue': 6.14,
#     'bg_term': 'testis',
#     'cancer_type': None,
#     'source': 'GTEx',
#     'tissue': {'bg_label': 'testis',
#      'bto': 'BTO:0001363',
#      'uberon': 'UBERON:0000473'}},
#    {'Correlation': 0.6387,
#     'Pvalue': 144.51,
#     'bg_term': 'brain',
#     'cancer_type': None,
#     'source': 'GTEx',
#     'tissue': {'bg_label': 'brain',
#      'bto': 'BTO:0000142',
#      'uberon': 'UBERON:0000955'}}]},
#  {'GPID': 10190000002176,
#   'Gene1': 2176,
#   'Gene2': 1019,
#   'interactions': [{'Correlation': 0.3024,
#     'Pvalue': 3.1,
#     'cancer_type': 'GBM',
#     'source': 'TCGA',
#     'tissue': None},
#    {'Correlation': -0.4806,
#     'Pvalue': 10.6,
#     'bg_term': 'testis',
#     'cancer_type': None,
#     'source': 'GTEx',
#     'tissue': {'bg_label': 'testis',
#      'bto': 'BTO:0001363',
#      'uberon': 'UBERON:0000473'}},
#    {'Correlation': 0.5253,
#     'Pvalue': 89.52,
#     'bg_term': 'brain',
#     'cancer_type': None,
#     'source': 'GTEx',
#     'tissue': {'bg_label': 'brain',
#      'bto': 'BTO:0000142',
#      'uberon': 'UBERON:0000955'}}]},
#  {'GPID': 8890000002176,
#   'Gene1': 2176,
#   'Gene2': 889,
#   'interactions': [{'Correlation': 0.1706,
#     'Pvalue': 1.2,
#     'cancer_type': 'GBM',
#     'source': 'TCGA',
#     'tissue': None},
#    {'Correlation': -0.1358,
#     'Pvalue': 1.12,
#     'bg_term': 'testis',
#     'cancer_type': None,
#     'source': 'GTEx',
#     'tissue': {'bg_label': 'testis',
#      'bto': 'BTO:0001363',
#      'uberon': 'UBERON:0000473'}},
#    {'Correlation': 0.7029,
#     'Pvalue': 187.5,
#     'bg_term': 'brain',
#     'cancer_type': None,
#     'source': 'GTEx',
#     'tissue': {'bg_label': 'brain',
#      'bto': 'BTO:0000142',
#      'uberon': 'UBERON:0000955'}}]},
#  {'GPID': 11110000002176,
#   'Gene1': 2176,
#   'Gene2': 1111,
#   'interactions': [{'Correlation': 0.7111,
#     'Pvalue': 19.04,
#     'cancer_type': 'GBM',
#     'source': 'TCGA',
#     'tissue': None},
#    {'Correlation': 0.0824,
#     'Pvalue': 0.55,
#     'bg_term': 'testis',
#     'cancer_type': None,
#     'source': 'GTEx',
#     'tissue': {'bg_label': 'testis',
#      'bto': 'BTO:0001363',
#      'uberon': 'UBERON:0000473'}},
#    {'Correlation': -0.0246,
#     'Pvalue': 0.42,
#     'bg_term': 'brain',
#     'cancer_type': None,
#     'source': 'GTEx',
#     'tissue': {'bg_label': 'brain',
#      'bto': 'BTO:0000142',
#      'uberon': 'UBERON:0000955'}}]},
#  {'GPID': 11110000006815,
#   'Gene1': 6815,
#   'Gene2': 1111,
#   'interactions': [{'Correlation': -0.1197,
#     'Pvalue': 0.72,
#     'cancer_type': 'GBM',
#     'source': 'TCGA',
#     'tissue': None},
#    {'Correlation': 0.0127,
#     'Pvalue': 0.06,
#     'bg_term': 'testis',
#     'cancer_type': None,
#     'source': 'GTEx',
#     'tissue': {'bg_label': 'testis',
#      'bto': 'BTO:0001363',
#      'uberon': 'UBERON:0000473'}},
#    {'Correlation': 0.2608,
#     'Pvalue': 20.3,
#     'bg_term': 'brain',
#     'cancer_type': None,
#     'source': 'GTEx',
#     'tissue': {'bg_label': 'brain',
#      'bto': 'BTO:0000142',
#      'uberon': 'UBERON:0000955'}}]},
#  {'GPID': 21760000006815,
#   'Gene1': 6815,
#   'Gene2': 2176,
#   'interactions': [{'Correlation': -0.2341,
#     'Pvalue': 2.0,
#     'cancer_type': 'GBM',
#     'source': 'TCGA',
#     'tissue': None},
#    {'Correlation': 0.1425,
#     'Pvalue': 1.21,
#     'bg_term': 'testis',
#     'cancer_type': None,
#     'source': 'GTEx',
#     'tissue': {'bg_label': 'testis',
#      'bto': 'BTO:0001363',
#      'uberon': 'UBERON:0000473'}},
#    {'Correlation': 0.5937,
#     'Pvalue': 120.03,
#     'bg_term': 'brain',
#     'cancer_type': None,
#     'source': 'GTEx',
#     'tissue': {'bg_label': 'brain',
#      'bto': 'BTO:0000142',
#      'uberon': 'UBERON:0000955'}}]},
#  {'GPID': 8890000006815,
#   'Gene1': 6815,
#   'Gene2': 889,
#   'interactions': [{'Correlation': 0.0928,
#     'Pvalue': 0.5,
#     'cancer_type': 'GBM',
#     'source': 'TCGA',
#     'tissue': None},
#    {'Correlation': 0.2832,
#     'Pvalue': 3.78,
#     'bg_term': 'testis',
#     'cancer_type': None,
#     'source': 'GTEx',
#     'tissue': {'bg_label': 'testis',
#      'bto': 'BTO:0001363',
#      'uberon': 'UBERON:0000473'}},
#    {'Correlation': 0.601,
#     'Pvalue': 123.74,
#     'bg_term': 'brain',
#     'cancer_type': None,
#     'source': 'GTEx',
#     'tissue': {'bg_label': 'brain',
#      'bto': 'BTO:0000142',
#      'uberon': 'UBERON:0000955'}}]},
#  {'GPID': 51110000006815,
#   'Gene1': 6815,
#   'Gene2': 5111,
#   'interactions': [{'Correlation': 0.0325,
#     'Pvalue': 0.14,
#     'cancer_type': 'GBM',
#     'source': 'TCGA',
#     'tissue': None},
#    {'Correlation': 0.7579,
#     'Pvalue': 234.72,
#     'bg_term': 'brain',
#     'cancer_type': None,
#     'source': 'GTEx',
#     'tissue': {'bg_label': 'brain',
#      'bto': 'BTO:0000142',
#      'uberon': 'UBERON:0000955'}}]},
#  {'GPID': 57060000006815,
#   'Gene1': 6815,
#   'Gene2': 5706,
#   'interactions': [{'Correlation': 0.4009,
#     'Pvalue': 5.24,
#     'cancer_type': 'GBM',
#     'source': 'TCGA',
#     'tissue': None},
#    {'Correlation': -0.1492,
#     'Pvalue': 1.29,
#     'bg_term': 'testis',
#     'cancer_type': None,
#     'source': 'GTEx',
#     'tissue': {'bg_label': 'testis',
#      'bto': 'BTO:0001363',
#      'uberon': 'UBERON:0000473'}},
#    {'Correlation': 0.4885,
#     'Pvalue': 75.74,
#     'bg_term': 'brain',
#     'cancer_type': None,
#     'source': 'GTEx',
#     'tissue': {'bg_label': 'brain',
#      'bto': 'BTO:0000142',
#      'uberon': 'UBERON:0000955'}}]},
#  {'GPID': 10190000006815,
#   'Gene1': 6815,
#   'Gene2': 1019,
#   'interactions': [{'Correlation': -0.1305,
#     'Pvalue': 0.81,
#     'cancer_type': 'GBM',
#     'source': 'TCGA',
#     'tissue': None},
#    {'Correlation': -0.2679,
#     'Pvalue': 3.42,
#     'bg_term': 'testis',
#     'cancer_type': None,
#     'source': 'GTEx',
#     'tissue': {'bg_label': 'testis',
#      'bto': 'BTO:0001363',
#      'uberon': 'UBERON:0000473'}},
#    {'Correlation': 0.5813,
#     'Pvalue': 113.97,
#     'bg_term': 'brain',
#     'cancer_type': None,
#     'source': 'GTEx',
#     'tissue': {'bg_label': 'brain',
#      'bto': 'BTO:0000142',
#      'uberon': 'UBERON:0000955'}}]},
#  {'GPID': 21760000007112,
#   'Gene1': 7112,
#   'Gene2': 2176,
#   'interactions': [{'Correlation': 0.5989,
#     'Pvalue': 12.3,
#     'cancer_type': 'GBM',
#     'source': 'TCGA',
#     'tissue': None},
#    {'Correlation': -0.0113,
#     'Pvalue': 0.05,
#     'bg_term': 'testis',
#     'cancer_type': None,
#     'source': 'GTEx',
#     'tissue': {'bg_label': 'testis',
#      'bto': 'BTO:0001363',
#      'uberon': 'UBERON:0000473'}},
#    {'Correlation': 0.7369,
#     'Pvalue': 215.25,
#     'bg_term': 'brain',
#     'cancer_type': None,
#     'source': 'GTEx',
#     'tissue': {'bg_label': 'brain',
#      'bto': 'BTO:0000142',
#      'uberon': 'UBERON:0000955'}}]},
#  {'GPID': 69960000007112,
#   'Gene1': 7112,
#   'Gene2': 6996,
#   'interactions': [{'Correlation': 0.4991,
#     'Pvalue': 8.18,
#     'cancer_type': 'GBM',
#     'source': 'TCGA',
#     'tissue': None},
#    {'Correlation': 0.06,
#     'Pvalue': 0.36,
#     'bg_term': 'testis',
#     'cancer_type': None,
#     'source': 'GTEx',
#     'tissue': {'bg_label': 'testis',
#      'bto': 'BTO:0001363',
#      'uberon': 'UBERON:0000473'}},
#    {'Correlation': 0.6653,
#     'Pvalue': 161.01,
#     'bg_term': 'brain',
#     'cancer_type': None,
#     'source': 'GTEx',
#     'tissue': {'bg_label': 'brain',
#      'bto': 'BTO:0000142',
#      'uberon': 'UBERON:0000955'}}]},
#  {'GPID': 11110000007112,
#   'Gene1': 7112,
#   'Gene2': 1111,
#   'interactions': [{'Correlation': 0.7026,
#     'Pvalue': 18.42,
#     'cancer_type': 'GBM',
#     'source': 'TCGA',
#     'tissue': None},
#    {'Correlation': 0.4657,
#     'Pvalue': 9.92,
#     'bg_term': 'testis',
#     'cancer_type': None,
#     'source': 'GTEx',
#     'tissue': {'bg_label': 'testis',
#      'bto': 'BTO:0001363',
#      'uberon': 'UBERON:0000473'}},
#    {'Correlation': -0.0678,
#     'Pvalue': 1.79,
#     'bg_term': 'brain',
#     'cancer_type': None,
#     'source': 'GTEx',
#     'tissue': {'bg_label': 'brain',
#      'bto': 'BTO:0000142',
#      'uberon': 'UBERON:0000955'}}]},
#  {'GPID': 1120000007112,
#   'Gene1': 7112,
#   'Gene2': 112,
#   'interactions': [{'Correlation': -0.0171,
#     'Pvalue': 0.07,
#     'cancer_type': 'GBM',
#     'source': 'TCGA',
#     'tissue': None},
#    {'Correlation': 0.1289,
#     'Pvalue': 1.04,
#     'bg_term': 'testis',
#     'cancer_type': None,
#     'source': 'GTEx',
#     'tissue': {'bg_label': 'testis',
#      'bto': 'BTO:0001363',
#      'uberon': 'UBERON:0000473'}},
#    {'Correlation': 0.7397,
#     'Pvalue': 217.76,
#     'bg_term': 'brain',
#     'cancer_type': None,
#     'source': 'GTEx',
#     'tissue': {'bg_label': 'brain',
#      'bto': 'BTO:0000142',
#      'uberon': 'UBERON:0000955'}}]},
#  {'GPID': 58880000007112,
#   'Gene1': 7112,
#   'Gene2': 5888,
#   'interactions': [{'Correlation': 0.7331,
#     'Pvalue': 20.76,
#     'cancer_type': 'GBM',
#     'source': 'TCGA',
#     'tissue': None},
#    {'Correlation': 0.144,
#     'Pvalue': 1.23,
#     'bg_term': 'testis',
#     'cancer_type': None,
#     'source': 'GTEx',
#     'tissue': {'bg_label': 'testis',
#      'bto': 'BTO:0001363',
#      'uberon': 'UBERON:0000473'}},
#    {'Correlation': 0.5651,
#     'Pvalue': 106.4,
#     'bg_term': 'brain',
#     'cancer_type': None,
#     'source': 'GTEx',
#     'tissue': {'bg_label': 'brain',
#      'bto': 'BTO:0000142',
#      'uberon': 'UBERON:0000955'}}]},
#  {'GPID': 51110000007112,
#   'Gene1': 7112,
#   'Gene2': 5111,
#   'interactions': [{'Correlation': 0.6164,
#     'Pvalue': 13.18,
#     'cancer_type': 'GBM',
#     'source': 'TCGA',
#     'tissue': None},
#    {'Correlation': 0.7789,
#     'Pvalue': 256.21,
#     'bg_term': 'brain',
#     'cancer_type': None,
#     'source': 'GTEx',
#     'tissue': {'bg_label': 'brain',
#      'bto': 'BTO:0000142',
#      'uberon': 'UBERON:0000955'}}]},
#  {'GPID': 57060000007112,
#   'Gene1': 7112,
#   'Gene2': 5706,
#   'interactions': [{'Correlation': 0.1942,
#     'Pvalue': 1.47,
#     'cancer_type': 'GBM',
#     'source': 'TCGA',
#     'tissue': None},
#    {'Correlation': 0.2679,
#     'Pvalue': 3.42,
#     'bg_term': 'testis',
#     'cancer_type': None,
#     'source': 'GTEx',
#     'tissue': {'bg_label': 'testis',
#      'bto': 'BTO:0001363',
#      'uberon': 'UBERON:0000473'}},
#    {'Correlation': 0.7647,
#     'Pvalue': 241.41,
#     'bg_term': 'brain',
#     'cancer_type': None,
#     'source': 'GTEx',
#     'tissue': {'bg_label': 'brain',
#      'bto': 'BTO:0000142',
#      'uberon': 'UBERON:0000955'}}]},
#  {'GPID': 8890000007112,
#   'Gene1': 7112,
#   'Gene2': 889,
#   'interactions': [{'Correlation': 0.0584,
#     'Pvalue': 0.28,
#     'cancer_type': 'GBM',
#     'source': 'TCGA',
#     'tissue': None},
#    {'Correlation': 0.6888,
#     'Pvalue': 24.8,
#     'bg_term': 'testis',
#     'cancer_type': None,
#     'source': 'GTEx',
#     'tissue': {'bg_label': 'testis',
#      'bto': 'BTO:0001363',
#      'uberon': 'UBERON:0000473'}},
#    {'Correlation': 0.8263,
#     'Pvalue': 315.0,
#     'bg_term': 'brain',
#     'cancer_type': None,
#     'source': 'GTEx',
#     'tissue': {'bg_label': 'brain',
#      'bto': 'BTO:0000142',
#      'uberon': 'UBERON:0000955'}}]},
#  {'GPID': 10190000007112,
#   'Gene1': 7112,
#   'Gene2': 1019,
#   'interactions': [{'Correlation': 0.5341,
#     'Pvalue': 9.48,
#     'cancer_type': 'GBM',
#     'source': 'TCGA',
#     'tissue': None},
#    {'Correlation': 0.1443,
#     'Pvalue': 1.23,
#     'bg_term': 'testis',
#     'cancer_type': None,
#     'source': 'GTEx',
#     'tissue': {'bg_label': 'testis',
#      'bto': 'BTO:0001363',
#      'uberon': 'UBERON:0000473'}},
#    {'Correlation': 0.4414,
#     'Pvalue': 60.44,
#     'bg_term': 'brain',
#     'cancer_type': None,
#     'source': 'GTEx',
#     'tissue': {'bg_label': 'brain',
#      'bto': 'BTO:0000142',
#      'uberon': 'UBERON:0000955'}}]},
#  {'GPID': 68150000007112,
#   'Gene1': 7112,
#   'Gene2': 6815,
#   'interactions': [{'Correlation': -0.1275,
#     'Pvalue': 0.78,
#     'cancer_type': 'GBM',
#     'source': 'TCGA',
#     'tissue': None},
#    {'Correlation': 0.4313,
#     'Pvalue': 8.46,
#     'bg_term': 'testis',
#     'cancer_type': None,
#     'source': 'GTEx',
#     'tissue': {'bg_label': 'testis',
#      'bto': 'BTO:0001363',
#      'uberon': 'UBERON:0000473'}},
#    {'Correlation': 0.6142,
#     'Pvalue': 130.73,
#     'bg_term': 'brain',
#     'cancer_type': None,
#     'source': 'GTEx',
#     'tissue': {'bg_label': 'brain',
#      'bto': 'BTO:0000142',
#      'uberon': 'UBERON:0000955'}}]},
#  {'GPID': 8890000005111,
#   'Gene1': 5111,
#   'Gene2': 889,
#   'interactions': [{'Correlation': 0.0933,
#     'Pvalue': 0.51,
#     'cancer_type': 'GBM',
#     'source': 'TCGA',
#     'tissue': None},
#    {'Correlation': 0.7489,
#     'Pvalue': 226.12,
#     'bg_term': 'brain',
#     'cancer_type': None,
#     'source': 'GTEx',
#     'tissue': {'bg_label': 'brain',
#      'bto': 'BTO:0000142',
#      'uberon': 'UBERON:0000955'}}]},
#  {'GPID': 21760000005111,
#   'Gene1': 5111,
#   'Gene2': 2176,
#   'interactions': [{'Correlation': 0.3506,
#     'Pvalue': 4.06,
#     'cancer_type': 'GBM',
#     'source': 'TCGA',
#     'tissue': None},
#    {'Correlation': 0.7075,
#     'Pvalue': 191.0,
#     'bg_term': 'brain',
#     'cancer_type': None,
#     'source': 'GTEx',
#     'tissue': {'bg_label': 'brain',
#      'bto': 'BTO:0000142',
#      'uberon': 'UBERON:0000955'}}]},
#  {'GPID': 10190000005111,
#   'Gene1': 5111,
#   'Gene2': 1019,
#   'interactions': [{'Correlation': 0.4983,
#     'Pvalue': 8.16,
#     'cancer_type': 'GBM',
#     'source': 'TCGA',
#     'tissue': None},
#    {'Correlation': 0.6435,
#     'Pvalue': 147.39,
#     'bg_term': 'brain',
#     'cancer_type': None,
#     'source': 'GTEx',
#     'tissue': {'bg_label': 'brain',
#      'bto': 'BTO:0000142',
#      'uberon': 'UBERON:0000955'}}]},
#  {'GPID': 11110000005111,
#   'Gene1': 5111,
#   'Gene2': 1111,
#   'interactions': [{'Correlation': 0.6174,
#     'Pvalue': 13.23,
#     'cancer_type': 'GBM',
#     'source': 'TCGA',
#     'tissue': None},
#    {'Correlation': 0.1711,
#     'Pvalue': 9.0,
#     'bg_term': 'brain',
#     'cancer_type': None,
#     'source': 'GTEx',
#     'tissue': {'bg_label': 'brain',
#      'bto': 'BTO:0000142',
#      'uberon': 'UBERON:0000955'}}]},
#  {'GPID': 1120000005111,
#   'Gene1': 5111,
#   'Gene2': 112,
#   'interactions': [{'Correlation': -0.2945,
#     'Pvalue': 2.96,
#     'cancer_type': 'GBM',
#     'source': 'TCGA',
#     'tissue': None},
#    {'Correlation': 0.5295,
#     'Pvalue': 91.17,
#     'bg_term': 'brain',
#     'cancer_type': None,
#     'source': 'GTEx',
#     'tissue': {'bg_label': 'brain',
#      'bto': 'BTO:0000142',
#      'uberon': 'UBERON:0000955'}}]},
#  {'GPID': 1120000001019,
#   'Gene1': 1019,
#   'Gene2': 112,
#   'interactions': [{'Correlation': -0.2191,
#     'Pvalue': 1.79,
#     'cancer_type': 'GBM',
#     'source': 'TCGA',
#     'tissue': None},
#    {'Correlation': 0.7295,
#     'Pvalue': 29.12,
#     'bg_term': 'testis',
#     'cancer_type': None,
#     'source': 'GTEx',
#     'tissue': {'bg_label': 'testis',
#      'bto': 'BTO:0001363',
#      'uberon': 'UBERON:0000473'}},
#    {'Correlation': 0.4109,
#     'Pvalue': 51.74,
#     'bg_term': 'brain',
#     'cancer_type': None,
#     'source': 'GTEx',
#     'tissue': {'bg_label': 'brain',
#      'bto': 'BTO:0000142',
#      'uberon': 'UBERON:0000955'}}]},
#  {'GPID': 8890000001019,
#   'Gene1': 1019,
#   'Gene2': 889,
#   'interactions': [{'Correlation': -0.0116,
#     'Pvalue': 0.05,
#     'cancer_type': 'GBM',
#     'source': 'TCGA',
#     'tissue': None},
#    {'Correlation': 0.2144,
#     'Pvalue': 2.32,
#     'bg_term': 'testis',
#     'cancer_type': None,
#     'source': 'GTEx',
#     'tissue': {'bg_label': 'testis',
#      'bto': 'BTO:0001363',
#      'uberon': 'UBERON:0000473'}},
#    {'Correlation': 0.4816,
#     'Pvalue': 73.38,
#     'bg_term': 'brain',
#     'cancer_type': None,
#     'source': 'GTEx',
#     'tissue': {'bg_label': 'brain',
#      'bto': 'BTO:0000142',
#      'uberon': 'UBERON:0000955'}}]}]

# %%
meta_columns
# Out:
# {'BioGRID_Experimental_System': {'cancer_type': None,
#   'source': 'BioGRID',
#   'tissue': None,
#   'type': 'Experimental_System'},
#  'BioGRID_Experimental_System_Type': {'cancer_type': None,
#   'source': 'BioGRID',
#   'tissue': None,
#   'type': 'Experimental_System_Type'},
#  'BioGRID_Interaction': {'cancer_type': None,
#   'source': 'BioGRID',
#   'tissue': None,
#   'type': 'Interaction'},
#  'BioGRID_Throughput': {'cancer_type': None,
#   'source': 'BioGRID',
#   'tissue': None,
#   'type': 'Throughput'},
#  'GIANT_adipose_tissue_KnownFunctionalInteraction': {'bg_term': 'adipose_tissue',
#   'cancer_type': None,
#   'source': 'GIANT',
#   'tissue': {'bg_label': 'adipose_tissue',
#    'bto': 'BTO:0001487',
#    'uberon': 'UBERON:0001013'},
#   'type': 'KnownFunctionalInteraction'},
#  'GIANT_adipose_tissue_ProbabilityOfFunctionalInteraction': {'bg_term': 'adipose_tissue',
#   'cancer_type': None,
#   'source': 'GIANT',
#   'tissue': {'bg_label': 'adipose_tissue',
#    'bto': 'BTO:0001487',
#    'uberon': 'UBERON:0001013'},
#   'type': 'ProbabilityOfFunctionalInteraction'},
#  'GIANT_adrenal_cortex_KnownFunctionalInteraction': {'bg_term': 'adrenal_cortex',
#   'cancer_type': None,
#   'source': 'GIANT',
#   'tissue': {'bg_label': 'adrenal_cortex',
#    'bto': 'BTO:0000045',
#    'uberon': 'UBERON:0001235'},
#   'type': 'KnownFunctionalInteraction'},
#  'GIANT_adrenal_cortex_ProbabilityOfFunctionalInteraction': {'bg_term': 'adrenal_cortex',
#   'cancer_type': None,
#   'source': 'GIANT',
#   'tissue': {'bg_label': 'adrenal_cortex',
#    'bto': 'BTO:0000045',
#    'uberon': 'UBERON:0001235'},
#   'type': 'ProbabilityOfFunctionalInteraction'},
#  'GIANT_adrenal_gland_KnownFunctionalInteraction': {'bg_term': 'adrenal_gland',
#   'cancer_type': None,
#   'source': 'GIANT',
#   'tissue': {'bg_label': 'adrenal_gland',
#    'bto': 'BTO:0000047',
#    'uberon': 'UBERON:0002369'},
#   'type': 'KnownFunctionalInteraction'},
#  'GIANT_adrenal_gland_ProbabilityOfFunctionalInteraction': {'bg_term': 'adrenal_gland',
#   'cancer_type': None,
#   'source': 'GIANT',
#   'tissue': {'bg_label': 'adrenal_gland',
#    'bto': 'BTO:0000047',
#    'uberon': 'UBERON:0002369'},
#   'type': 'ProbabilityOfFunctionalInteraction'},
#  'GIANT_all_tissues_KnownFunctionalInteraction': {'bg_term': 'all_tissues',
#   'cancer_type': None,
#   'source': 'GIANT',
#   'tissue': {'bg_label': 'all_tissues', 'bto': None, 'uberon': None},
#   'type': 'KnownFunctionalInteraction'},
#  'GIANT_all_tissues_ProbabilityOfFunctionalInteraction': {'bg_term': 'all_tissues',
#   'cancer_type': None,
#   'source': 'GIANT',
#   'tissue': {'bg_label': 'all_tissues', 'bto': None, 'uberon': None},
#   'type': 'ProbabilityOfFunctionalInteraction'},
#  'GIANT_amygdala_KnownFunctionalInteraction': {'bg_term': 'amygdala',
#   'cancer_type': None,
#   'source': 'GIANT',
#   'tissue': {'bg_label': 'amygdala',
#    'bto': 'BTO:0001042',
#    'uberon': 'UBERON:0001876'},
#   'type': 'KnownFunctionalInteraction'},
#  'GIANT_amygdala_ProbabilityOfFunctionalInteraction': {'bg_term': 'amygdala',
#   'cancer_type': None,
#   'source': 'GIANT',
#   'tissue': {'bg_label': 'amygdala',
#    'bto': 'BTO:0001042',
#    'uberon': 'UBERON:0001876'},
#   'type': 'ProbabilityOfFunctionalInteraction'},
#  'GIANT_aorta_KnownFunctionalInteraction': {'bg_term': 'aorta',
#   'cancer_type': None,
#   'source': 'GIANT',
#   'tissue': {'bg_label': 'aorta',
#    'bto': 'BTO:0000135',
#    'uberon': 'UBERON:0000947'},
#   'type': 'KnownFunctionalInteraction'},
#  'GIANT_aorta_ProbabilityOfFunctionalInteraction': {'bg_term': 'aorta',
#   'cancer_type': None,
#   'source': 'GIANT',
#   'tissue': {'bg_label': 'aorta',
#    'bto': 'BTO:0000135',
#    'uberon': 'UBERON:0000947'},
#   'type': 'ProbabilityOfFunctionalInteraction'},
#  'GIANT_artery_KnownFunctionalInteraction': {'bg_term': 'artery',
#   'cancer_type': None,
#   'source': 'GIANT',
#   'tissue': {'bg_label': 'artery',
#    'bto': 'BTO:0000573',
#    'uberon': 'UBERON:0001637'},
#   'type': 'KnownFunctionalInteraction'},
#  'GIANT_artery_ProbabilityOfFunctionalInteraction': {'bg_term': 'artery',
#   'cancer_type': None,
#   'source': 'GIANT',
#   'tissue': {'bg_label': 'artery',
#    'bto': 'BTO:0000573',
#    'uberon': 'UBERON:0001637'},
#   'type': 'ProbabilityOfFunctionalInteraction'},
#  'GIANT_astrocyte_KnownFunctionalInteraction': {'bg_term': 'astrocyte',
#   'cancer_type': None,
#   'source': 'GIANT',
#   'tissue': {'bg_label': 'astrocyte', 'bto': 'BTO:0000099', 'uberon': None},
#   'type': 'KnownFunctionalInteraction'},
#  'GIANT_astrocyte_ProbabilityOfFunctionalInteraction': {'bg_term': 'astrocyte',
#   'cancer_type': None,
#   'source': 'GIANT',
#   'tissue': {'bg_label': 'astrocyte', 'bto': 'BTO:0000099', 'uberon': None},
#   'type': 'ProbabilityOfFunctionalInteraction'},
#  'GIANT_b_lymphocyte_KnownFunctionalInteraction': {'bg_term': 'b_lymphocyte',
#   'cancer_type': None,
#   'source': 'GIANT',
#   'tissue': {'bg_label': 'b_lymphocyte', 'bto': None, 'uberon': None},
#   'type': 'KnownFunctionalInteraction'},
#  'GIANT_b_lymphocyte_ProbabilityOfFunctionalInteraction': {'bg_term': 'b_lymphocyte',
#   'cancer_type': None,
#   'source': 'GIANT',
#   'tissue': {'bg_label': 'b_lymphocyte', 'bto': None, 'uberon': None},
#   'type': 'ProbabilityOfFunctionalInteraction'},
#  'GIANT_basal_ganglion_KnownFunctionalInteraction': {'bg_term': 'basal_ganglion',
#   'cancer_type': None,
#   'source': 'GIANT',
#   'tissue': {'bg_label': 'basal_ganglion',
#    'bto': 'BTO:0000235',
#    'uberon': 'UBERON:0002420'},
#   'type': 'KnownFunctionalInteraction'},
#  'GIANT_basal_ganglion_ProbabilityOfFunctionalInteraction': {'bg_term': 'basal_ganglion',
#   'cancer_type': None,
#   'source': 'GIANT',
#   'tissue': {'bg_label': 'basal_ganglion',
#    'bto': 'BTO:0000235',
#    'uberon': 'UBERON:0002420'},
#   'type': 'ProbabilityOfFunctionalInteraction'},
#  'GIANT_basophil_KnownFunctionalInteraction': {'bg_term': 'basophil',
#   'cancer_type': None,
#   'source': 'GIANT',
#   'tissue': {'bg_label': 'basophil', 'bto': 'BTO:0000129', 'uberon': None},
#   'type': 'KnownFunctionalInteraction'},
#  'GIANT_basophil_ProbabilityOfFunctionalInteraction': {'bg_term': 'basophil',
#   'cancer_type': None,
#   'source': 'GIANT',
#   'tissue': {'bg_label': 'basophil', 'bto': 'BTO:0000129', 'uberon': None},
#   'type': 'ProbabilityOfFunctionalInteraction'},
#  'GIANT_blood_KnownFunctionalInteraction': {'bg_term': 'blood',
#   'cancer_type': None,
#   'source': 'GIANT',
#   'tissue': {'bg_label': 'blood',
#    'bto': 'BTO:0000089',
#    'uberon': 'UBERON:0000178'},
#   'type': 'KnownFunctionalInteraction'},
#  'GIANT_blood_ProbabilityOfFunctionalInteraction': {'bg_term': 'blood',
#   'cancer_type': None,
#   'source': 'GIANT',
#   'tissue': {'bg_label': 'blood',
#    'bto': 'BTO:0000089',
#    'uberon': 'UBERON:0000178'},
#   'type': 'ProbabilityOfFunctionalInteraction'},
#  'GIANT_blood_plasma_KnownFunctionalInteraction': {'bg_term': 'blood_plasma',
#   'cancer_type': None,
#   'source': 'GIANT',
#   'tissue': {'bg_label': 'blood_plasma',
#    'bto': 'BTO:0000131',
#    'uberon': 'UBERON:0001969'},
#   'type': 'KnownFunctionalInteraction'},
#  'GIANT_blood_plasma_ProbabilityOfFunctionalInteraction': {'bg_term': 'blood_plasma',
#   'cancer_type': None,
#   'source': 'GIANT',
#   'tissue': {'bg_label': 'blood_plasma',
#    'bto': 'BTO:0000131',
#    'uberon': 'UBERON:0001969'},
#   'type': 'ProbabilityOfFunctionalInteraction'},
#  'GIANT_blood_platelet_KnownFunctionalInteraction': {'bg_term': 'blood_platelet',
#   'cancer_type': None,
#   'source': 'GIANT',
#   'tissue': {'bg_label': 'blood_platelet',
#    'bto': 'BTO:0000132',
#    'uberon': None},
#   'type': 'KnownFunctionalInteraction'},
#  'GIANT_blood_platelet_ProbabilityOfFunctionalInteraction': {'bg_term': 'blood_platelet',
#   'cancer_type': None,
#   'source': 'GIANT',
#   'tissue': {'bg_label': 'blood_platelet',
#    'bto': 'BTO:0000132',
#    'uberon': None},
#   'type': 'ProbabilityOfFunctionalInteraction'},
#  'GIANT_blood_vessel_KnownFunctionalInteraction': {'bg_term': 'blood_vessel',
#   'cancer_type': None,
#   'source': 'GIANT',
#   'tissue': {'bg_label': 'blood_vessel',
#    'bto': 'BTO:0001102',
#    'uberon': 'UBERON:0001981'},
#   'type': 'KnownFunctionalInteraction'},
#  'GIANT_blood_vessel_ProbabilityOfFunctionalInteraction': {'bg_term': 'blood_vessel',
#   'cancer_type': None,
#   'source': 'GIANT',
#   'tissue': {'bg_label': 'blood_vessel',
#    'bto': 'BTO:0001102',
#    'uberon': 'UBERON:0001981'},
#   'type': 'ProbabilityOfFunctionalInteraction'},
#  'GIANT_bone_KnownFunctionalInteraction': {'bg_term': 'bone',
#   'cancer_type': None,
#   'source': 'GIANT',
#   'tissue': {'bg_label': 'bone',
#    'bto': 'BTO:0000140',
#    'uberon': 'UBERON:0001474'},
#   'type': 'KnownFunctionalInteraction'},
#  'GIANT_bone_ProbabilityOfFunctionalInteraction': {'bg_term': 'bone',
#   'cancer_type': None,
#   'source': 'GIANT',
#   'tissue': {'bg_label': 'bone',
#    'bto': 'BTO:0000140',
#    'uberon': 'UBERON:0001474'},
#   'type': 'ProbabilityOfFunctionalInteraction'},
#  'GIANT_bone_marrow_KnownFunctionalInteraction': {'bg_term': 'bone_marrow',
#   'cancer_type': None,
#   'source': 'GIANT',
#   'tissue': {'bg_label': 'bone_marrow',
#    'bto': 'BTO:0000141',
#    'uberon': 'UBERON:0002371'},
#   'type': 'KnownFunctionalInteraction'},
#  'GIANT_bone_marrow_ProbabilityOfFunctionalInteraction': {'bg_term': 'bone_marrow',
#   'cancer_type': None,
#   'source': 'GIANT',
#   'tissue': {'bg_label': 'bone_marrow',
#    'bto': 'BTO:0000141',
#    'uberon': 'UBERON:0002371'},
#   'type': 'ProbabilityOfFunctionalInteraction'},
#  'GIANT_brain_KnownFunctionalInteraction': {'bg_term': 'brain',
#   'cancer_type': None,
#   'source': 'GIANT',
#   'tissue': {'bg_label': 'brain',
#    'bto': 'BTO:0000142',
#    'uberon': 'UBERON:0000955'},
#   'type': 'KnownFunctionalInteraction'},
#  'GIANT_brain_ProbabilityOfFunctionalInteraction': {'bg_term': 'brain',
#   'cancer_type': None,
#   'source': 'GIANT',
#   'tissue': {'bg_label': 'brain',
#    'bto': 'BTO:0000142',
#    'uberon': 'UBERON:0000955'},
#   'type': 'ProbabilityOfFunctionalInteraction'},
#  'GIANT_bronchial_epithelial_cell_KnownFunctionalInteraction': {'bg_term': 'bronchial_epithelial_cell',
#   'cancer_type': None,
#   'source': 'GIANT',
#   'tissue': {'bg_label': 'bronchial_epithelial_cell',
#    'bto': 'BTO:0002922',
#    'uberon': None},
#   'type': 'KnownFunctionalInteraction'},
#  'GIANT_bronchial_epithelial_cell_ProbabilityOfFunctionalInteraction': {'bg_term': 'bronchial_epithelial_cell',
#   'cancer_type': None,
#   'source': 'GIANT',
#   'tissue': {'bg_label': 'bronchial_epithelial_cell',
#    'bto': 'BTO:0002922',
#    'uberon': None},
#   'type': 'ProbabilityOfFunctionalInteraction'},
#  'GIANT_bronchus_KnownFunctionalInteraction': {'bg_term': 'bronchus',
#   'cancer_type': None,
#   'source': 'GIANT',
#   'tissue': {'bg_label': 'bronchus',
#    'bto': 'BTO:0001340',
#    'uberon': 'UBERON:0002185'},
#   'type': 'KnownFunctionalInteraction'},
#  'GIANT_bronchus_ProbabilityOfFunctionalInteraction': {'bg_term': 'bronchus',
#   'cancer_type': None,
#   'source': 'GIANT',
#   'tissue': {'bg_label': 'bronchus',
#    'bto': 'BTO:0001340',
#    'uberon': 'UBERON:0002185'},
#   'type': 'ProbabilityOfFunctionalInteraction'},
#  'GIANT_cardiac_muscle_KnownFunctionalInteraction': {'bg_term': 'cardiac_muscle',
#   'cancer_type': None,
#   'source': 'GIANT',
#   'tissue': {'bg_label': 'cardiac_muscle',
#    'bto': 'BTO:0000199',
#    'uberon': 'UBERON:0001133'},
#   'type': 'KnownFunctionalInteraction'},
#  'GIANT_cardiac_muscle_ProbabilityOfFunctionalInteraction': {'bg_term': 'cardiac_muscle',
#   'cancer_type': None,
#   'source': 'GIANT',
#   'tissue': {'bg_label': 'cardiac_muscle',
#    'bto': 'BTO:0000199',
#    'uberon': 'UBERON:0001133'},
#   'type': 'ProbabilityOfFunctionalInteraction'},
#  'GIANT_cartilage_KnownFunctionalInteraction': {'bg_term': 'cartilage',
#   'cancer_type': None,
#   'source': 'GIANT',
#   'tissue': {'bg_label': 'cartilage',
#    'bto': 'BTO:0000206',
#    'uberon': 'UBERON:0002418'},
#   'type': 'KnownFunctionalInteraction'},
#  'GIANT_cartilage_ProbabilityOfFunctionalInteraction': {'bg_term': 'cartilage',
#   'cancer_type': None,
#   'source': 'GIANT',
#   'tissue': {'bg_label': 'cartilage',
#    'bto': 'BTO:0000206',
#    'uberon': 'UBERON:0002418'},
#   'type': 'ProbabilityOfFunctionalInteraction'},
#  'GIANT_caudate_nucleus_KnownFunctionalInteraction': {'bg_term': 'caudate_nucleus',
#   'cancer_type': None,
#   'source': 'GIANT',
#   'tissue': {'bg_label': 'caudate_nucleus',
#    'bto': 'BTO:0000211',
#    'uberon': 'UBERON:0001873'},
#   'type': 'KnownFunctionalInteraction'},
#  'GIANT_caudate_nucleus_ProbabilityOfFunctionalInteraction': {'bg_term': 'caudate_nucleus',
#   'cancer_type': None,
#   'source': 'GIANT',
#   'tissue': {'bg_label': 'caudate_nucleus',
#    'bto': 'BTO:0000211',
#    'uberon': 'UBERON:0001873'},
#   'type': 'ProbabilityOfFunctionalInteraction'},
#  'GIANT_caudate_putamen_KnownFunctionalInteraction': {'bg_term': 'caudate_putamen',
#   'cancer_type': None,
#   'source': 'GIANT',
#   'tissue': {'bg_label': 'caudate_putamen',
#    'bto': 'BTO:0000212',
#    'uberon': 'UBERON:0005383'},
#   'type': 'KnownFunctionalInteraction'},
#  'GIANT_caudate_putamen_ProbabilityOfFunctionalInteraction': {'bg_term': 'caudate_putamen',
#   'cancer_type': None,
#   'source': 'GIANT',
#   'tissue': {'bg_label': 'caudate_putamen',
#    'bto': 'BTO:0000212',
#    'uberon': 'UBERON:0005383'},
#   'type': 'ProbabilityOfFunctionalInteraction'},
#  'GIANT_cecum_KnownFunctionalInteraction': {'bg_term': 'cecum',
#   'cancer_type': None,
#   'source': 'GIANT',
#   'tissue': {'bg_label': 'cecum',
#    'bto': 'BTO:0000166',
#    'uberon': 'UBERON:0001153'},
#   'type': 'KnownFunctionalInteraction'},
#  'GIANT_cecum_ProbabilityOfFunctionalInteraction': {'bg_term': 'cecum',
#   'cancer_type': None,
#   'source': 'GIANT',
#   'tissue': {'bg_label': 'cecum',
#    'bto': 'BTO:0000166',
#    'uberon': 'UBERON:0001153'},
#   'type': 'ProbabilityOfFunctionalInteraction'},
#  'GIANT_central_nervous_system_KnownFunctionalInteraction': {'bg_term': 'central_nervous_system',
#   'cancer_type': None,
#   'source': 'GIANT',
#   'tissue': {'bg_label': 'central_nervous_system',
#    'bto': 'BTO:0000227',
#    'uberon': 'UBERON:0001017'},
#   'type': 'KnownFunctionalInteraction'},
#  'GIANT_central_nervous_system_ProbabilityOfFunctionalInteraction': {'bg_term': 'central_nervous_system',
#   'cancer_type': None,
#   'source': 'GIANT',
#   'tissue': {'bg_label': 'central_nervous_system',
#    'bto': 'BTO:0000227',
#    'uberon': 'UBERON:0001017'},
#   'type': 'ProbabilityOfFunctionalInteraction'},
#  'GIANT_cerebellar_cortex_KnownFunctionalInteraction': {'bg_term': 'cerebellar_cortex',
#   'cancer_type': None,
#   'source': 'GIANT',
#   'tissue': {'bg_label': 'cerebellar_cortex',
#    'bto': 'BTO:0000043',
#    'uberon': 'UBERON:0002129'},
#   'type': 'KnownFunctionalInteraction'},
#  'GIANT_cerebellar_cortex_ProbabilityOfFunctionalInteraction': {'bg_term': 'cerebellar_cortex',
#   'cancer_type': None,
#   'source': 'GIANT',
#   'tissue': {'bg_label': 'cerebellar_cortex',
#    'bto': 'BTO:0000043',
#    'uberon': 'UBERON:0002129'},
#   'type': 'ProbabilityOfFunctionalInteraction'},
#  'GIANT_cerebellum_KnownFunctionalInteraction': {'bg_term': 'cerebellum',
#   'cancer_type': None,
#   'source': 'GIANT',
#   'tissue': {'bg_label': 'cerebellum',
#    'bto': 'BTO:0000232',
#    'uberon': 'UBERON:0002037'},
#   'type': 'KnownFunctionalInteraction'},
#  'GIANT_cerebellum_ProbabilityOfFunctionalInteraction': {'bg_term': 'cerebellum',
#   'cancer_type': None,
#   'source': 'GIANT',
#   'tissue': {'bg_label': 'cerebellum',
#    'bto': 'BTO:0000232',
#    'uberon': 'UBERON:0002037'},
#   'type': 'ProbabilityOfFunctionalInteraction'},
#  'GIANT_cerebral_cortex_KnownFunctionalInteraction': {'bg_term': 'cerebral_cortex',
#   'cancer_type': None,
#   'source': 'GIANT',
#   'tissue': {'bg_label': 'cerebral_cortex',
#    'bto': 'BTO:0000233',
#    'uberon': 'UBERON:0000956'},
#   'type': 'KnownFunctionalInteraction'},
#  'GIANT_cerebral_cortex_ProbabilityOfFunctionalInteraction': {'bg_term': 'cerebral_cortex',
#   'cancer_type': None,
#   'source': 'GIANT',
#   'tissue': {'bg_label': 'cerebral_cortex',
#    'bto': 'BTO:0000233',
#    'uberon': 'UBERON:0000956'},
#   'type': 'ProbabilityOfFunctionalInteraction'},
#  'GIANT_chondrocyte_KnownFunctionalInteraction': {'bg_term': 'chondrocyte',
#   'cancer_type': None,
#   'source': 'GIANT',
#   'tissue': {'bg_label': 'chondrocyte', 'bto': 'BTO:0000249', 'uberon': None},
#   'type': 'KnownFunctionalInteraction'},
#  'GIANT_chondrocyte_ProbabilityOfFunctionalInteraction': {'bg_term': 'chondrocyte',
#   'cancer_type': None,
#   'source': 'GIANT',
#   'tissue': {'bg_label': 'chondrocyte', 'bto': 'BTO:0000249', 'uberon': None},
#   'type': 'ProbabilityOfFunctionalInteraction'},
#  'GIANT_choroid_KnownFunctionalInteraction': {'bg_term': 'choroid',
#   'cancer_type': None,
#   'source': 'GIANT',
#   'tissue': {'bg_label': 'choroid',
#    'bto': 'BTO:0001829',
#    'uberon': 'UBERON:0001776'},
#   'type': 'KnownFunctionalInteraction'},
#  'GIANT_choroid_ProbabilityOfFunctionalInteraction': {'bg_term': 'choroid',
#   'cancer_type': None,
#   'source': 'GIANT',
#   'tissue': {'bg_label': 'choroid',
#    'bto': 'BTO:0001829',
#    'uberon': 'UBERON:0001776'},
#   'type': 'ProbabilityOfFunctionalInteraction'},
#  'GIANT_cochlea_KnownFunctionalInteraction': {'bg_term': 'cochlea',
#   'cancer_type': None,
#   'source': 'GIANT',
#   'tissue': {'bg_label': 'cochlea',
#    'bto': 'BTO:0000267',
#    'uberon': 'UBERON:0001844'},
#   'type': 'KnownFunctionalInteraction'},
#  'GIANT_cochlea_ProbabilityOfFunctionalInteraction': {'bg_term': 'cochlea',
#   'cancer_type': None,
#   'source': 'GIANT',
#   'tissue': {'bg_label': 'cochlea',
#    'bto': 'BTO:0000267',
#    'uberon': 'UBERON:0001844'},
#   'type': 'ProbabilityOfFunctionalInteraction'},
#  'GIANT_colon_KnownFunctionalInteraction': {'bg_term': 'colon',
#   'cancer_type': None,
#   'source': 'GIANT',
#   'tissue': {'bg_label': 'colon',
#    'bto': 'BTO:0000269',
#    'uberon': 'UBERON:0001155'},
#   'type': 'KnownFunctionalInteraction'},
#  'GIANT_colon_ProbabilityOfFunctionalInteraction': {'bg_term': 'colon',
#   'cancer_type': None,
#   'source': 'GIANT',
#   'tissue': {'bg_label': 'colon',
#    'bto': 'BTO:0000269',
#    'uberon': 'UBERON:0001155'},
#   'type': 'ProbabilityOfFunctionalInteraction'},
#  'GIANT_cornea_KnownFunctionalInteraction': {'bg_term': 'cornea',
#   'cancer_type': None,
#   'source': 'GIANT',
#   'tissue': {'bg_label': 'cornea',
#    'bto': 'BTO:0000286',
#    'uberon': 'UBERON:0000964'},
#   'type': 'KnownFunctionalInteraction'},
#  'GIANT_cornea_ProbabilityOfFunctionalInteraction': {'bg_term': 'cornea',
#   'cancer_type': None,
#   'source': 'GIANT',
#   'tissue': {'bg_label': 'cornea',
#    'bto': 'BTO:0000286',
#    'uberon': 'UBERON:0000964'},
#   'type': 'ProbabilityOfFunctionalInteraction'},
#  'GIANT_corpus_callosum_KnownFunctionalInteraction': {'bg_term': 'corpus_callosum',
#   'cancer_type': None,
#   'source': 'GIANT',
#   'tissue': {'bg_label': 'corpus_callosum',
#    'bto': 'BTO:0000615',
#    'uberon': 'UBERON:0002336'},
#   'type': 'KnownFunctionalInteraction'},
#  'GIANT_corpus_callosum_ProbabilityOfFunctionalInteraction': {'bg_term': 'corpus_callosum',
#   'cancer_type': None,
#   'source': 'GIANT',
#   'tissue': {'bg_label': 'corpus_callosum',
#    'bto': 'BTO:0000615',
#    'uberon': 'UBERON:0002336'},
#   'type': 'ProbabilityOfFunctionalInteraction'},
#  'GIANT_corpus_luteum_KnownFunctionalInteraction': {'bg_term': 'corpus_luteum',
#   'cancer_type': None,
#   'source': 'GIANT',
#   'tissue': {'bg_label': 'corpus_luteum',
#    'bto': 'BTO:0000292',
#    'uberon': 'UBERON:0002512'},
#   'type': 'KnownFunctionalInteraction'},
#  'GIANT_corpus_luteum_ProbabilityOfFunctionalInteraction': {'bg_term': 'corpus_luteum',
#   'cancer_type': None,
#   'source': 'GIANT',
#   'tissue': {'bg_label': 'corpus_luteum',
#    'bto': 'BTO:0000292',
#    'uberon': 'UBERON:0002512'},
#   'type': 'ProbabilityOfFunctionalInteraction'},
#  'GIANT_corpus_striatum_KnownFunctionalInteraction': {'bg_term': 'corpus_striatum',
#   'cancer_type': None,
#   'source': 'GIANT',
#   'tissue': {'bg_label': 'corpus_striatum',
#    'bto': 'BTO:0001311',
#    'uberon': 'UBERON:0000369'},
#   'type': 'KnownFunctionalInteraction'},
#  'GIANT_corpus_striatum_ProbabilityOfFunctionalInteraction': {'bg_term': 'corpus_striatum',
#   'cancer_type': None,
#   'source': 'GIANT',
#   'tissue': {'bg_label': 'corpus_striatum',
#    'bto': 'BTO:0001311',
#    'uberon': 'UBERON:0000369'},
#   'type': 'ProbabilityOfFunctionalInteraction'},
#  'GIANT_culture_condition_cd8_cell_KnownFunctionalInteraction': {'bg_term': 'culture_condition_cd8_cell',
#   'cancer_type': None,
#   'source': 'GIANT',
#   'tissue': {'bg_label': 'culture_condition_cd8_cell',
#    'bto': None,
#    'uberon': None},
#   'type': 'KnownFunctionalInteraction'},
#  'GIANT_culture_condition_cd8_cell_ProbabilityOfFunctionalInteraction': {'bg_term': 'culture_condition_cd8_cell',
#   'cancer_type': None,
#   'source': 'GIANT',
#   'tissue': {'bg_label': 'culture_condition_cd8_cell',
#    'bto': None,
#    'uberon': None},
#   'type': 'ProbabilityOfFunctionalInteraction'},
#  'GIANT_dendritic_cell_KnownFunctionalInteraction': {'bg_term': 'dendritic_cell',
#   'cancer_type': None,
#   'source': 'GIANT',
#   'tissue': {'bg_label': 'dendritic_cell',
#    'bto': 'BTO:0002042',
#    'uberon': None},
#   'type': 'KnownFunctionalInteraction'},
#  'GIANT_dendritic_cell_ProbabilityOfFunctionalInteraction': {'bg_term': 'dendritic_cell',
#   'cancer_type': None,
#   'source': 'GIANT',
#   'tissue': {'bg_label': 'dendritic_cell',
#    'bto': 'BTO:0002042',
#    'uberon': None},
#   'type': 'ProbabilityOfFunctionalInteraction'},
#  'GIANT_dentate_gyrus_KnownFunctionalInteraction': {'bg_term': 'dentate_gyrus',
#   'cancer_type': None,
#   'source': 'GIANT',
#   'tissue': {'bg_label': 'dentate_gyrus',
#    'bto': 'BTO:0002496',
#    'uberon': 'UBERON:0001885'},
#   'type': 'KnownFunctionalInteraction'},
#  'GIANT_dentate_gyrus_ProbabilityOfFunctionalInteraction': {'bg_term': 'dentate_gyrus',
#   'cancer_type': None,
#   'source': 'GIANT',
#   'tissue': {'bg_label': 'dentate_gyrus',
#    'bto': 'BTO:0002496',
#    'uberon': 'UBERON:0001885'},
#   'type': 'ProbabilityOfFunctionalInteraction'},
#  'GIANT_diencephalon_KnownFunctionalInteraction': {'bg_term': 'diencephalon',
#   'cancer_type': None,
#   'source': 'GIANT',
#   'tissue': {'bg_label': 'diencephalon',
#    'bto': 'BTO:0000342',
#    'uberon': 'UBERON:0001894'},
#   'type': 'KnownFunctionalInteraction'},
#  'GIANT_diencephalon_ProbabilityOfFunctionalInteraction': {'bg_term': 'diencephalon',
#   'cancer_type': None,
#   'source': 'GIANT',
#   'tissue': {'bg_label': 'diencephalon',
#    'bto': 'BTO:0000342',
#    'uberon': 'UBERON:0001894'},
#   'type': 'ProbabilityOfFunctionalInteraction'},
#  'GIANT_duodenum_KnownFunctionalInteraction': {'bg_term': 'duodenum',
#   'cancer_type': None,
#   'source': 'GIANT',
#   'tissue': {'bg_label': 'duodenum',
#    'bto': 'BTO:0000365',
#    'uberon': 'UBERON:0002114'},
#   'type': 'KnownFunctionalInteraction'},
#  'GIANT_duodenum_ProbabilityOfFunctionalInteraction': {'bg_term': 'duodenum',
#   'cancer_type': None,
#   'source': 'GIANT',
#   'tissue': {'bg_label': 'duodenum',
#    'bto': 'BTO:0000365',
#    'uberon': 'UBERON:0002114'},
#   'type': 'ProbabilityOfFunctionalInteraction'},
#  'GIANT_ear_KnownFunctionalInteraction': {'bg_term': 'ear',
#   'cancer_type': None,
#   'source': 'GIANT',
#   'tissue': {'bg_label': 'ear',
#    'bto': 'BTO:0000368',
#    'uberon': 'UBERON:0001690'},
#   'type': 'KnownFunctionalInteraction'},
#  'GIANT_ear_ProbabilityOfFunctionalInteraction': {'bg_term': 'ear',
#   'cancer_type': None,
#   'source': 'GIANT',
#   'tissue': {'bg_label': 'ear',
#    'bto': 'BTO:0000368',
#    'uberon': 'UBERON:0001690'},
#   'type': 'ProbabilityOfFunctionalInteraction'},
#  'GIANT_embryo_KnownFunctionalInteraction': {'bg_term': 'embryo',
#   'cancer_type': None,
#   'source': 'GIANT',
#   'tissue': {'bg_label': 'embryo',
#    'bto': 'BTO:0000379',
#    'uberon': 'UBERON:0000922'},
#   'type': 'KnownFunctionalInteraction'},
#  'GIANT_embryo_ProbabilityOfFunctionalInteraction': {'bg_term': 'embryo',
#   'cancer_type': None,
#   'source': 'GIANT',
#   'tissue': {'bg_label': 'embryo',
#    'bto': 'BTO:0000379',
#    'uberon': 'UBERON:0000922'},
#   'type': 'ProbabilityOfFunctionalInteraction'},
#  'GIANT_eosinophil_KnownFunctionalInteraction': {'bg_term': 'eosinophil',
#   'cancer_type': None,
#   'source': 'GIANT',
#   'tissue': {'bg_label': 'eosinophil', 'bto': 'BTO:0000399', 'uberon': None},
#   'type': 'KnownFunctionalInteraction'},
#  'GIANT_eosinophil_ProbabilityOfFunctionalInteraction': {'bg_term': 'eosinophil',
#   'cancer_type': None,
#   'source': 'GIANT',
#   'tissue': {'bg_label': 'eosinophil', 'bto': 'BTO:0000399', 'uberon': None},
#   'type': 'ProbabilityOfFunctionalInteraction'},
#  'GIANT_epidermis_KnownFunctionalInteraction': {'bg_term': 'epidermis',
#   'cancer_type': None,
#   'source': 'GIANT',
#   'tissue': {'bg_label': 'epidermis',
#    'bto': 'BTO:0000404',
#    'uberon': 'UBERON:0001003'},
#   'type': 'KnownFunctionalInteraction'},
#  'GIANT_epidermis_ProbabilityOfFunctionalInteraction': {'bg_term': 'epidermis',
#   'cancer_type': None,
#   'source': 'GIANT',
#   'tissue': {'bg_label': 'epidermis',
#    'bto': 'BTO:0000404',
#    'uberon': 'UBERON:0001003'},
#   'type': 'ProbabilityOfFunctionalInteraction'},
#  'GIANT_esophagus_KnownFunctionalInteraction': {'bg_term': 'esophagus',
#   'cancer_type': None,
#   'source': 'GIANT',
#   'tissue': {'bg_label': 'esophagus',
#    'bto': 'BTO:0000959',
#    'uberon': 'UBERON:0001043'},
#   'type': 'KnownFunctionalInteraction'},
#  'GIANT_esophagus_ProbabilityOfFunctionalInteraction': {'bg_term': 'esophagus',
#   'cancer_type': None,
#   'source': 'GIANT',
#   'tissue': {'bg_label': 'esophagus',
#    'bto': 'BTO:0000959',
#    'uberon': 'UBERON:0001043'},
#   'type': 'ProbabilityOfFunctionalInteraction'},
#  'GIANT_eye_KnownFunctionalInteraction': {'bg_term': 'eye',
#   'cancer_type': None,
#   'source': 'GIANT',
#   'tissue': {'bg_label': 'eye',
#    'bto': 'BTO:0000439',
#    'uberon': 'UBERON:0000970'},
#   'type': 'KnownFunctionalInteraction'},
#  'GIANT_eye_ProbabilityOfFunctionalInteraction': {'bg_term': 'eye',
#   'cancer_type': None,
#   'source': 'GIANT',
#   'tissue': {'bg_label': 'eye',
#    'bto': 'BTO:0000439',
#    'uberon': 'UBERON:0000970'},
#   'type': 'ProbabilityOfFunctionalInteraction'},
#  'GIANT_fetus_KnownFunctionalInteraction': {'bg_term': 'fetus',
#   'cancer_type': None,
#   'source': 'GIANT',
#   'tissue': {'bg_label': 'fetus',
#    'bto': 'BTO:0000449',
#    'uberon': 'UBERON:0000323'},
#   'type': 'KnownFunctionalInteraction'},
#  'GIANT_fetus_ProbabilityOfFunctionalInteraction': {'bg_term': 'fetus',
#   'cancer_type': None,
#   'source': 'GIANT',
#   'tissue': {'bg_label': 'fetus',
#    'bto': 'BTO:0000449',
#    'uberon': 'UBERON:0000323'},
#   'type': 'ProbabilityOfFunctionalInteraction'},
#  'GIANT_forebrain_KnownFunctionalInteraction': {'bg_term': 'forebrain',
#   'cancer_type': None,
#   'source': 'GIANT',
#   'tissue': {'bg_label': 'forebrain',
#    'bto': 'BTO:0000478',
#    'uberon': 'UBERON:0001890'},
#   'type': 'KnownFunctionalInteraction'},
#  'GIANT_forebrain_ProbabilityOfFunctionalInteraction': {'bg_term': 'forebrain',
#   'cancer_type': None,
#   'source': 'GIANT',
#   'tissue': {'bg_label': 'forebrain',
#    'bto': 'BTO:0000478',
#    'uberon': 'UBERON:0001890'},
#   'type': 'ProbabilityOfFunctionalInteraction'},
#  'GIANT_frontal_lobe_KnownFunctionalInteraction': {'bg_term': 'frontal_lobe',
#   'cancer_type': None,
#   'source': 'GIANT',
#   'tissue': {'bg_label': 'frontal_lobe',
#    'bto': 'BTO:0000484',
#    'uberon': 'UBERON:0001870'},
#   'type': 'KnownFunctionalInteraction'},
#  'GIANT_frontal_lobe_ProbabilityOfFunctionalInteraction': {'bg_term': 'frontal_lobe',
#   'cancer_type': None,
#   'source': 'GIANT',
#   'tissue': {'bg_label': 'frontal_lobe',
#    'bto': 'BTO:0000484',
#    'uberon': 'UBERON:0001870'},
#   'type': 'ProbabilityOfFunctionalInteraction'},
#  'GIANT_gastrointestinal_tract_KnownFunctionalInteraction': {'bg_term': 'gastrointestinal_tract',
#   'cancer_type': None,
#   'source': 'GIANT',
#   'tissue': {'bg_label': 'gastrointestinal_tract',
#    'bto': 'BTO:0000511',
#    'uberon': 'UBERON:0001555'},
#   'type': 'KnownFunctionalInteraction'},
#  'GIANT_gastrointestinal_tract_ProbabilityOfFunctionalInteraction': {'bg_term': 'gastrointestinal_tract',
#   'cancer_type': None,
#   'source': 'GIANT',
#   'tissue': {'bg_label': 'gastrointestinal_tract',
#    'bto': 'BTO:0000511',
#    'uberon': 'UBERON:0001555'},
#   'type': 'ProbabilityOfFunctionalInteraction'},
#  'GIANT_glia_KnownFunctionalInteraction': {'bg_term': 'glia',
#   'cancer_type': None,
#   'source': 'GIANT',
#   'tissue': {'bg_label': 'glia', 'bto': 'BTO:0000524', 'uberon': None},
#   'type': 'KnownFunctionalInteraction'},
#  'GIANT_glia_ProbabilityOfFunctionalInteraction': {'bg_term': 'glia',
#   'cancer_type': None,
#   'source': 'GIANT',
#   'tissue': {'bg_label': 'glia', 'bto': 'BTO:0000524', 'uberon': None},
#   'type': 'ProbabilityOfFunctionalInteraction'},
#  'GIANT_granulocyte_KnownFunctionalInteraction': {'bg_term': 'granulocyte',
#   'cancer_type': None,
#   'source': 'GIANT',
#   'tissue': {'bg_label': 'granulocyte', 'bto': 'BTO:0000539', 'uberon': None},
#   'type': 'KnownFunctionalInteraction'},
#  'GIANT_granulocyte_ProbabilityOfFunctionalInteraction': {'bg_term': 'granulocyte',
#   'cancer_type': None,
#   'source': 'GIANT',
#   'tissue': {'bg_label': 'granulocyte', 'bto': 'BTO:0000539', 'uberon': None},
#   'type': 'ProbabilityOfFunctionalInteraction'},
#  'GIANT_hair_follicle_KnownFunctionalInteraction': {'bg_term': 'hair_follicle',
#   'cancer_type': None,
#   'source': 'GIANT',
#   'tissue': {'bg_label': 'hair_follicle',
#    'bto': 'BTO:0000554',
#    'uberon': 'UBERON:0002073'},
#   'type': 'KnownFunctionalInteraction'},
#  'GIANT_hair_follicle_ProbabilityOfFunctionalInteraction': {'bg_term': 'hair_follicle',
#   'cancer_type': None,
#   'source': 'GIANT',
#   'tissue': {'bg_label': 'hair_follicle',
#    'bto': 'BTO:0000554',
#    'uberon': 'UBERON:0002073'},
#   'type': 'ProbabilityOfFunctionalInteraction'},
#  'GIANT_heart_KnownFunctionalInteraction': {'bg_term': 'heart',
#   'cancer_type': None,
#   'source': 'GIANT',
#   'tissue': {'bg_label': 'heart',
#    'bto': 'BTO:0000562',
#    'uberon': 'UBERON:0000948'},
#   'type': 'KnownFunctionalInteraction'},
#  'GIANT_heart_ProbabilityOfFunctionalInteraction': {'bg_term': 'heart',
#   'cancer_type': None,
#   'source': 'GIANT',
#   'tissue': {'bg_label': 'heart',
#    'bto': 'BTO:0000562',
#    'uberon': 'UBERON:0000948'},
#   'type': 'ProbabilityOfFunctionalInteraction'},
#  'GIANT_hematopoietic_stem_cell_KnownFunctionalInteraction': {'bg_term': 'hematopoietic_stem_cell',
#   'cancer_type': None,
#   'source': 'GIANT',
#   'tissue': {'bg_label': 'hematopoietic_stem_cell',
#    'bto': 'BTO:0000725',
#    'uberon': None},
#   'type': 'KnownFunctionalInteraction'},
#  'GIANT_hematopoietic_stem_cell_ProbabilityOfFunctionalInteraction': {'bg_term': 'hematopoietic_stem_cell',
#   'cancer_type': None,
#   'source': 'GIANT',
#   'tissue': {'bg_label': 'hematopoietic_stem_cell',
#    'bto': 'BTO:0000725',
#    'uberon': None},
#   'type': 'ProbabilityOfFunctionalInteraction'},
#  'GIANT_hepatocyte_KnownFunctionalInteraction': {'bg_term': 'hepatocyte',
#   'cancer_type': None,
#   'source': 'GIANT',
#   'tissue': {'bg_label': 'hepatocyte', 'bto': 'BTO:0000575', 'uberon': None},
#   'type': 'KnownFunctionalInteraction'},
#  'GIANT_hepatocyte_ProbabilityOfFunctionalInteraction': {'bg_term': 'hepatocyte',
#   'cancer_type': None,
#   'source': 'GIANT',
#   'tissue': {'bg_label': 'hepatocyte', 'bto': 'BTO:0000575', 'uberon': None},
#   'type': 'ProbabilityOfFunctionalInteraction'},
#  'GIANT_hippocampus_KnownFunctionalInteraction': {'bg_term': 'hippocampus',
#   'cancer_type': None,
#   'source': 'GIANT',
#   'tissue': {'bg_label': 'hippocampus',
#    'bto': 'BTO:0000601',
#    'uberon': 'UBERON:0002421'},
#   'type': 'KnownFunctionalInteraction'},
#  'GIANT_hippocampus_ProbabilityOfFunctionalInteraction': {'bg_term': 'hippocampus',
#   'cancer_type': None,
#   'source': 'GIANT',
#   'tissue': {'bg_label': 'hippocampus',
#    'bto': 'BTO:0000601',
#    'uberon': 'UBERON:0002421'},
#   'type': 'ProbabilityOfFunctionalInteraction'},
#  'GIANT_hypophysis_KnownFunctionalInteraction': {'bg_term': 'hypophysis',
#   'cancer_type': None,
#   'source': 'GIANT',
#   'tissue': {'bg_label': 'hypophysis',
#    'bto': 'BTO:0001073',
#    'uberon': 'UBERON:0000007'},
#   'type': 'KnownFunctionalInteraction'},
#  'GIANT_hypophysis_ProbabilityOfFunctionalInteraction': {'bg_term': 'hypophysis',
#   'cancer_type': None,
#   'source': 'GIANT',
#   'tissue': {'bg_label': 'hypophysis',
#    'bto': 'BTO:0001073',
#    'uberon': 'UBERON:0000007'},
#   'type': 'ProbabilityOfFunctionalInteraction'},
#  'GIANT_hypothalamus_KnownFunctionalInteraction': {'bg_term': 'hypothalamus',
#   'cancer_type': None,
#   'source': 'GIANT',
#   'tissue': {'bg_label': 'hypothalamus',
#    'bto': 'BTO:0000614',
#    'uberon': 'UBERON:0001898'},
#   'type': 'KnownFunctionalInteraction'},
#  'GIANT_hypothalamus_ProbabilityOfFunctionalInteraction': {'bg_term': 'hypothalamus',
#   'cancer_type': None,
#   'source': 'GIANT',
#   'tissue': {'bg_label': 'hypothalamus',
#    'bto': 'BTO:0000614',
#    'uberon': 'UBERON:0001898'},
#   'type': 'ProbabilityOfFunctionalInteraction'},
#  'GIANT_ileum_KnownFunctionalInteraction': {'bg_term': 'ileum',
#   'cancer_type': None,
#   'source': 'GIANT',
#   'tissue': {'bg_label': 'ileum',
#    'bto': 'BTO:0000620',
#    'uberon': 'UBERON:0002116'},
#   'type': 'KnownFunctionalInteraction'},
#  'GIANT_ileum_ProbabilityOfFunctionalInteraction': {'bg_term': 'ileum',
#   'cancer_type': None,
#   'source': 'GIANT',
#   'tissue': {'bg_label': 'ileum',
#    'bto': 'BTO:0000620',
#    'uberon': 'UBERON:0002116'},
#   'type': 'ProbabilityOfFunctionalInteraction'},
#  'GIANT_intestine_KnownFunctionalInteraction': {'bg_term': 'intestine',
#   'cancer_type': None,
#   'source': 'GIANT',
#   'tissue': {'bg_label': 'intestine',
#    'bto': 'BTO:0000648',
#    'uberon': 'UBERON:0000160'},
#   'type': 'KnownFunctionalInteraction'},
#  'GIANT_intestine_ProbabilityOfFunctionalInteraction': {'bg_term': 'intestine',
#   'cancer_type': None,
#   'source': 'GIANT',
#   'tissue': {'bg_label': 'intestine',
#    'bto': 'BTO:0000648',
#    'uberon': 'UBERON:0000160'},
#   'type': 'ProbabilityOfFunctionalInteraction'},
#  'GIANT_jejunum_KnownFunctionalInteraction': {'bg_term': 'jejunum',
#   'cancer_type': None,
#   'source': 'GIANT',
#   'tissue': {'bg_label': 'jejunum',
#    'bto': 'BTO:0000657',
#    'uberon': 'UBERON:0002115'},
#   'type': 'KnownFunctionalInteraction'},
#  'GIANT_jejunum_ProbabilityOfFunctionalInteraction': {'bg_term': 'jejunum',
#   'cancer_type': None,
#   'source': 'GIANT',
#   'tissue': {'bg_label': 'jejunum',
#    'bto': 'BTO:0000657',
#    'uberon': 'UBERON:0002115'},
#   'type': 'ProbabilityOfFunctionalInteraction'},
#  'GIANT_keratinocyte_KnownFunctionalInteraction': {'bg_term': 'keratinocyte',
#   'cancer_type': None,
#   'source': 'GIANT',
#   'tissue': {'bg_label': 'keratinocyte', 'bto': 'BTO:0000667', 'uberon': None},
#   'type': 'KnownFunctionalInteraction'},
#  'GIANT_keratinocyte_ProbabilityOfFunctionalInteraction': {'bg_term': 'keratinocyte',
#   'cancer_type': None,
#   'source': 'GIANT',
#   'tissue': {'bg_label': 'keratinocyte', 'bto': 'BTO:0000667', 'uberon': None},
#   'type': 'ProbabilityOfFunctionalInteraction'},
#  'GIANT_kidney_KnownFunctionalInteraction': {'bg_term': 'kidney',
#   'cancer_type': None,
#   'source': 'GIANT',
#   'tissue': {'bg_label': 'kidney',
#    'bto': 'BTO:0000671',
#    'uberon': 'UBERON:0000082'},
#   'type': 'KnownFunctionalInteraction'},
#  'GIANT_kidney_ProbabilityOfFunctionalInteraction': {'bg_term': 'kidney',
#   'cancer_type': None,
#   'source': 'GIANT',
#   'tissue': {'bg_label': 'kidney',
#    'bto': 'BTO:0000671',
#    'uberon': 'UBERON:0000082'},
#   'type': 'ProbabilityOfFunctionalInteraction'},
#  'GIANT_large_intestine_KnownFunctionalInteraction': {'bg_term': 'large_intestine',
#   'cancer_type': None,
#   'source': 'GIANT',
#   'tissue': {'bg_label': 'large_intestine',
#    'bto': 'BTO:0000706',
#    'uberon': 'UBERON:0000059'},
#   'type': 'KnownFunctionalInteraction'},
#  'GIANT_large_intestine_ProbabilityOfFunctionalInteraction': {'bg_term': 'large_intestine',
#   'cancer_type': None,
#   'source': 'GIANT',
#   'tissue': {'bg_label': 'large_intestine',
#    'bto': 'BTO:0000706',
#    'uberon': 'UBERON:0000059'},
#   'type': 'ProbabilityOfFunctionalInteraction'},
#  'GIANT_lens_KnownFunctionalInteraction': {'bg_term': 'lens',
#   'cancer_type': None,
#   'source': 'GIANT',
#   'tissue': {'bg_label': 'lens',
#    'bto': 'BTO:0000723',
#    'uberon': 'UBERON:0000965'},
#   'type': 'KnownFunctionalInteraction'},
#  'GIANT_lens_ProbabilityOfFunctionalInteraction': {'bg_term': 'lens',
#   'cancer_type': None,
#   'source': 'GIANT',
#   'tissue': {'bg_label': 'lens',
#    'bto': 'BTO:0000723',
#    'uberon': 'UBERON:0000965'},
#   'type': 'ProbabilityOfFunctionalInteraction'},
#  'GIANT_leukocyte_KnownFunctionalInteraction': {'bg_term': 'leukocyte',
#   'cancer_type': None,
#   'source': 'GIANT',
#   'tissue': {'bg_label': 'leukocyte', 'bto': 'BTO:0000751', 'uberon': None},
#   'type': 'KnownFunctionalInteraction'},
#  'GIANT_leukocyte_ProbabilityOfFunctionalInteraction': {'bg_term': 'leukocyte',
#   'cancer_type': None,
#   'source': 'GIANT',
#   'tissue': {'bg_label': 'leukocyte', 'bto': 'BTO:0000751', 'uberon': None},
#   'type': 'ProbabilityOfFunctionalInteraction'},
#  'GIANT_liver_KnownFunctionalInteraction': {'bg_term': 'liver',
#   'cancer_type': None,
#   'source': 'GIANT',
#   'tissue': {'bg_label': 'liver',
#    'bto': 'BTO:0000759',
#    'uberon': 'UBERON:0002107'},
#   'type': 'KnownFunctionalInteraction'},
#  'GIANT_liver_ProbabilityOfFunctionalInteraction': {'bg_term': 'liver',
#   'cancer_type': None,
#   'source': 'GIANT',
#   'tissue': {'bg_label': 'liver',
#    'bto': 'BTO:0000759',
#    'uberon': 'UBERON:0002107'},
#   'type': 'ProbabilityOfFunctionalInteraction'},
#  'GIANT_locus_ceruleus_KnownFunctionalInteraction': {'bg_term': 'locus_ceruleus',
#   'cancer_type': None,
#   'source': 'GIANT',
#   'tissue': {'bg_label': 'locus_ceruleus',
#    'bto': 'BTO:0001408',
#    'uberon': 'UBERON:0002148'},
#   'type': 'KnownFunctionalInteraction'},
#  'GIANT_locus_ceruleus_ProbabilityOfFunctionalInteraction': {'bg_term': 'locus_ceruleus',
#   'cancer_type': None,
#   'source': 'GIANT',
#   'tissue': {'bg_label': 'locus_ceruleus',
#    'bto': 'BTO:0001408',
#    'uberon': 'UBERON:0002148'},
#   'type': 'ProbabilityOfFunctionalInteraction'},
#  'GIANT_lung_KnownFunctionalInteraction': {'bg_term': 'lung',
#   'cancer_type': None,
#   'source': 'GIANT',
#   'tissue': {'bg_label': 'lung',
#    'bto': 'BTO:0000763',
#    'uberon': 'UBERON:0002048'},
#   'type': 'KnownFunctionalInteraction'},
#  'GIANT_lung_ProbabilityOfFunctionalInteraction': {'bg_term': 'lung',
#   'cancer_type': None,
#   'source': 'GIANT',
#   'tissue': {'bg_label': 'lung',
#    'bto': 'BTO:0000763',
#    'uberon': 'UBERON:0002048'},
#   'type': 'ProbabilityOfFunctionalInteraction'},
#  'GIANT_lymph_node_KnownFunctionalInteraction': {'bg_term': 'lymph_node',
#   'cancer_type': None,
#   'source': 'GIANT',
#   'tissue': {'bg_label': 'lymph_node',
#    'bto': 'BTO:0000784',
#    'uberon': 'UBERON:0000029'},
#   'type': 'KnownFunctionalInteraction'},
#  'GIANT_lymph_node_ProbabilityOfFunctionalInteraction': {'bg_term': 'lymph_node',
#   'cancer_type': None,
#   'source': 'GIANT',
#   'tissue': {'bg_label': 'lymph_node',
#    'bto': 'BTO:0000784',
#    'uberon': 'UBERON:0000029'},
#   'type': 'ProbabilityOfFunctionalInteraction'},
#  'GIANT_lymphocyte_KnownFunctionalInteraction': {'bg_term': 'lymphocyte',
#   'cancer_type': None,
#   'source': 'GIANT',
#   'tissue': {'bg_label': 'lymphocyte', 'bto': 'BTO:0000775', 'uberon': None},
#   'type': 'KnownFunctionalInteraction'},
#  'GIANT_lymphocyte_ProbabilityOfFunctionalInteraction': {'bg_term': 'lymphocyte',
#   'cancer_type': None,
#   'source': 'GIANT',
#   'tissue': {'bg_label': 'lymphocyte', 'bto': 'BTO:0000775', 'uberon': None},
#   'type': 'ProbabilityOfFunctionalInteraction'},
#  'GIANT_macrophage_KnownFunctionalInteraction': {'bg_term': 'macrophage',
#   'cancer_type': None,
#   'source': 'GIANT',
#   'tissue': {'bg_label': 'macrophage', 'bto': 'BTO:0000801', 'uberon': None},
#   'type': 'KnownFunctionalInteraction'},
#  'GIANT_macrophage_ProbabilityOfFunctionalInteraction': {'bg_term': 'macrophage',
#   'cancer_type': None,
#   'source': 'GIANT',
#   'tissue': {'bg_label': 'macrophage', 'bto': 'BTO:0000801', 'uberon': None},
#   'type': 'ProbabilityOfFunctionalInteraction'},
#  'GIANT_mammary_epithelium_KnownFunctionalInteraction': {'bg_term': 'mammary_epithelium',
#   'cancer_type': None,
#   'source': 'GIANT',
#   'tissue': {'bg_label': 'mammary_epithelium',
#    'bto': 'BTO:0001430',
#    'uberon': 'UBERON:0003244'},
#   'type': 'KnownFunctionalInteraction'},
#  'GIANT_mammary_epithelium_ProbabilityOfFunctionalInteraction': {'bg_term': 'mammary_epithelium',
#   'cancer_type': None,
#   'source': 'GIANT',
#   'tissue': {'bg_label': 'mammary_epithelium',
#    'bto': 'BTO:0001430',
#    'uberon': 'UBERON:0003244'},
#   'type': 'ProbabilityOfFunctionalInteraction'},
#  'GIANT_mammary_gland_KnownFunctionalInteraction': {'bg_term': 'mammary_gland',
#   'cancer_type': None,
#   'source': 'GIANT',
#   'tissue': {'bg_label': 'mammary_gland',
#    'bto': 'BTO:0000817',
#    'uberon': 'UBERON:0001911'},
#   'type': 'KnownFunctionalInteraction'},
#  'GIANT_mammary_gland_ProbabilityOfFunctionalInteraction': {'bg_term': 'mammary_gland',
#   'cancer_type': None,
#   'source': 'GIANT',
#   'tissue': {'bg_label': 'mammary_gland',
#    'bto': 'BTO:0000817',
#    'uberon': 'UBERON:0001911'},
#   'type': 'ProbabilityOfFunctionalInteraction'},
#  'GIANT_mast_cell_KnownFunctionalInteraction': {'bg_term': 'mast_cell',
#   'cancer_type': None,
#   'source': 'GIANT',
#   'tissue': {'bg_label': 'mast_cell', 'bto': 'BTO:0000830', 'uberon': None},
#   'type': 'KnownFunctionalInteraction'},
#  'GIANT_mast_cell_ProbabilityOfFunctionalInteraction': {'bg_term': 'mast_cell',
#   'cancer_type': None,
#   'source': 'GIANT',
#   'tissue': {'bg_label': 'mast_cell', 'bto': 'BTO:0000830', 'uberon': None},
#   'type': 'ProbabilityOfFunctionalInteraction'},
#  'GIANT_medulla_oblongata_KnownFunctionalInteraction': {'bg_term': 'medulla_oblongata',
#   'cancer_type': None,
#   'source': 'GIANT',
#   'tissue': {'bg_label': 'medulla_oblongata',
#    'bto': 'BTO:0000041',
#    'uberon': 'UBERON:0001896'},
#   'type': 'KnownFunctionalInteraction'},
#  'GIANT_medulla_oblongata_ProbabilityOfFunctionalInteraction': {'bg_term': 'medulla_oblongata',
#   'cancer_type': None,
#   'source': 'GIANT',
#   'tissue': {'bg_label': 'medulla_oblongata',
#    'bto': 'BTO:0000041',
#    'uberon': 'UBERON:0001896'},
#   'type': 'ProbabilityOfFunctionalInteraction'},
#  'GIANT_megakaryocyte_KnownFunctionalInteraction': {'bg_term': 'megakaryocyte',
#   'cancer_type': None,
#   'source': 'GIANT',
#   'tissue': {'bg_label': 'megakaryocyte',
#    'bto': 'BTO:0000843',
#    'uberon': None},
#   'type': 'KnownFunctionalInteraction'},
#  'GIANT_megakaryocyte_ProbabilityOfFunctionalInteraction': {'bg_term': 'megakaryocyte',
#   'cancer_type': None,
#   'source': 'GIANT',
#   'tissue': {'bg_label': 'megakaryocyte',
#    'bto': 'BTO:0000843',
#    'uberon': None},
#   'type': 'ProbabilityOfFunctionalInteraction'},
#  'GIANT_midbrain_KnownFunctionalInteraction': {'bg_term': 'midbrain',
#   'cancer_type': None,
#   'source': 'GIANT',
#   'tissue': {'bg_label': 'midbrain',
#    'bto': 'BTO:0000138',
#    'uberon': 'UBERON:0001891'},
#   'type': 'KnownFunctionalInteraction'},
#  'GIANT_midbrain_ProbabilityOfFunctionalInteraction': {'bg_term': 'midbrain',
#   'cancer_type': None,
#   'source': 'GIANT',
#   'tissue': {'bg_label': 'midbrain',
#    'bto': 'BTO:0000138',
#    'uberon': 'UBERON:0001891'},
#   'type': 'ProbabilityOfFunctionalInteraction'},
#  'GIANT_monocyte_KnownFunctionalInteraction': {'bg_term': 'monocyte',
#   'cancer_type': None,
#   'source': 'GIANT',
#   'tissue': {'bg_label': 'monocyte', 'bto': 'BTO:0000876', 'uberon': None},
#   'type': 'KnownFunctionalInteraction'},
#  'GIANT_monocyte_ProbabilityOfFunctionalInteraction': {'bg_term': 'monocyte',
#   'cancer_type': None,
#   'source': 'GIANT',
#   'tissue': {'bg_label': 'monocyte', 'bto': 'BTO:0000876', 'uberon': None},
#   'type': 'ProbabilityOfFunctionalInteraction'},
#  'GIANT_mononuclear_phagocyte_KnownFunctionalInteraction': {'bg_term': 'mononuclear_phagocyte',
#   'cancer_type': None,
#   'source': 'GIANT',
#   'tissue': {'bg_label': 'mononuclear_phagocyte',
#    'bto': 'BTO:0001433',
#    'uberon': None},
#   'type': 'KnownFunctionalInteraction'},
#  'GIANT_mononuclear_phagocyte_ProbabilityOfFunctionalInteraction': {'bg_term': 'mononuclear_phagocyte',
#   'cancer_type': None,
#   'source': 'GIANT',
#   'tissue': {'bg_label': 'mononuclear_phagocyte',
#    'bto': 'BTO:0001433',
#    'uberon': None},
#   'type': 'ProbabilityOfFunctionalInteraction'},
#  'GIANT_muscle_KnownFunctionalInteraction': {'bg_term': 'muscle',
#   'cancer_type': None,
#   'source': 'GIANT',
#   'tissue': {'bg_label': 'muscle',
#    'bto': 'BTO:0000887',
#    'uberon': 'UBERON:0001015'},
#   'type': 'KnownFunctionalInteraction'},
#  'GIANT_muscle_ProbabilityOfFunctionalInteraction': {'bg_term': 'muscle',
#   'cancer_type': None,
#   'source': 'GIANT',
#   'tissue': {'bg_label': 'muscle',
#    'bto': 'BTO:0000887',
#    'uberon': 'UBERON:0001015'},
#   'type': 'ProbabilityOfFunctionalInteraction'},
#  'GIANT_myometrium_KnownFunctionalInteraction': {'bg_term': 'myometrium',
#   'cancer_type': None,
#   'source': 'GIANT',
#   'tissue': {'bg_label': 'myometrium',
#    'bto': 'BTO:0000907',
#    'uberon': 'UBERON:0001296'},
#   'type': 'KnownFunctionalInteraction'},
#  'GIANT_myometrium_ProbabilityOfFunctionalInteraction': {'bg_term': 'myometrium',
#   'cancer_type': None,
#   'source': 'GIANT',
#   'tissue': {'bg_label': 'myometrium',
#    'bto': 'BTO:0000907',
#    'uberon': 'UBERON:0001296'},
#   'type': 'ProbabilityOfFunctionalInteraction'},
#  'GIANT_natural_killer_cell_KnownFunctionalInteraction': {'bg_term': 'natural_killer_cell',
#   'cancer_type': None,
#   'source': 'GIANT',
#   'tissue': {'bg_label': 'natural_killer_cell',
#    'bto': 'BTO:0000914',
#    'uberon': None},
#   'type': 'KnownFunctionalInteraction'},
#  'GIANT_natural_killer_cell_ProbabilityOfFunctionalInteraction': {'bg_term': 'natural_killer_cell',
#   'cancer_type': None,
#   'source': 'GIANT',
#   'tissue': {'bg_label': 'natural_killer_cell',
#    'bto': 'BTO:0000914',
#    'uberon': None},
#   'type': 'ProbabilityOfFunctionalInteraction'},
#  'GIANT_nephron_KnownFunctionalInteraction': {'bg_term': 'nephron',
#   'cancer_type': None,
#   'source': 'GIANT',
#   'tissue': {'bg_label': 'nephron',
#    'bto': 'BTO:0000924',
#    'uberon': 'UBERON:0001285'},
#   'type': 'KnownFunctionalInteraction'},
#  'GIANT_nephron_ProbabilityOfFunctionalInteraction': {'bg_term': 'nephron',
#   'cancer_type': None,
#   'source': 'GIANT',
#   'tissue': {'bg_label': 'nephron',
#    'bto': 'BTO:0000924',
#    'uberon': 'UBERON:0001285'},
#   'type': 'ProbabilityOfFunctionalInteraction'},
#  'GIANT_nervous_system_KnownFunctionalInteraction': {'bg_term': 'nervous_system',
#   'cancer_type': None,
#   'source': 'GIANT',
#   'tissue': {'bg_label': 'nervous_system',
#    'bto': 'BTO:0001484',
#    'uberon': 'UBERON:0001016'},
#   'type': 'KnownFunctionalInteraction'},
#  'GIANT_nervous_system_ProbabilityOfFunctionalInteraction': {'bg_term': 'nervous_system',
#   'cancer_type': None,
#   'source': 'GIANT',
#   'tissue': {'bg_label': 'nervous_system',
#    'bto': 'BTO:0001484',
#    'uberon': 'UBERON:0001016'},
#   'type': 'ProbabilityOfFunctionalInteraction'},
#  'GIANT_neuron_KnownFunctionalInteraction': {'bg_term': 'neuron',
#   'cancer_type': None,
#   'source': 'GIANT',
#   'tissue': {'bg_label': 'neuron', 'bto': 'BTO:0000938', 'uberon': None},
#   'type': 'KnownFunctionalInteraction'},
#  'GIANT_neuron_ProbabilityOfFunctionalInteraction': {'bg_term': 'neuron',
#   'cancer_type': None,
#   'source': 'GIANT',
#   'tissue': {'bg_label': 'neuron', 'bto': 'BTO:0000938', 'uberon': None},
#   'type': 'ProbabilityOfFunctionalInteraction'},
#  'GIANT_neutrophil_KnownFunctionalInteraction': {'bg_term': 'neutrophil',
#   'cancer_type': None,
#   'source': 'GIANT',
#   'tissue': {'bg_label': 'neutrophil', 'bto': 'BTO:0000130', 'uberon': None},
#   'type': 'KnownFunctionalInteraction'},
#  'GIANT_neutrophil_ProbabilityOfFunctionalInteraction': {'bg_term': 'neutrophil',
#   'cancer_type': None,
#   'source': 'GIANT',
#   'tissue': {'bg_label': 'neutrophil', 'bto': 'BTO:0000130', 'uberon': None},
#   'type': 'ProbabilityOfFunctionalInteraction'},
#  'GIANT_nucleus_accumbens_KnownFunctionalInteraction': {'bg_term': 'nucleus_accumbens',
#   'cancer_type': None,
#   'source': 'GIANT',
#   'tissue': {'bg_label': 'nucleus_accumbens',
#    'bto': 'BTO:0001862',
#    'uberon': 'UBERON:0001882'},
#   'type': 'KnownFunctionalInteraction'},
#  'GIANT_nucleus_accumbens_ProbabilityOfFunctionalInteraction': {'bg_term': 'nucleus_accumbens',
#   'cancer_type': None,
#   'source': 'GIANT',
#   'tissue': {'bg_label': 'nucleus_accumbens',
#    'bto': 'BTO:0001862',
#    'uberon': 'UBERON:0001882'},
#   'type': 'ProbabilityOfFunctionalInteraction'},
# ...
#   'cancer_type': None,
#   'source': 'GIANT',
#   'tissue': {'bg_label': 'vermiform_appendix',
#    'bto': 'BTO:0000084',
#    'uberon': 'UBERON:0001154'},
#   'type': 'ProbabilityOfFunctionalInteraction'},
#  'GTEx_Adipose_Tissue_Correlation': {'bg_term': 'adipose_tissue',
#   'cancer_type': None,
#   'source': 'GTEx',
#   'tissue': {'bg_label': 'adipose_tissue',
#    'bto': 'BTO:0001487',
#    'uberon': 'UBERON:0001013'},
#   'type': 'Correlation'},
#  'GTEx_Adipose_Tissue_Pvalue': {'bg_term': 'adipose_tissue',
#   'cancer_type': None,
#   'source': 'GTEx',
#   'tissue': {'bg_label': 'adipose_tissue',
#    'bto': 'BTO:0001487',
#    'uberon': 'UBERON:0001013'},
#   'type': 'Pvalue'},
#  'GTEx_Adrenal_Gland_Correlation': {'bg_term': 'adrenal_gland',
#   'cancer_type': None,
#   'source': 'GTEx',
#   'tissue': {'bg_label': 'adrenal_gland',
#    'bto': 'BTO:0000047',
#    'uberon': 'UBERON:0002369'},
#   'type': 'Correlation'},
#  'GTEx_Adrenal_Gland_Pvalue': {'bg_term': 'adrenal_gland',
#   'cancer_type': None,
#   'source': 'GTEx',
#   'tissue': {'bg_label': 'adrenal_gland',
#    'bto': 'BTO:0000047',
#    'uberon': 'UBERON:0002369'},
#   'type': 'Pvalue'},
#  'GTEx_Blood_Correlation': {'bg_term': 'blood',
#   'cancer_type': None,
#   'source': 'GTEx',
#   'tissue': {'bg_label': 'blood',
#    'bto': 'BTO:0000089',
#    'uberon': 'UBERON:0000178'},
#   'type': 'Correlation'},
#  'GTEx_Blood_Pvalue': {'bg_term': 'blood',
#   'cancer_type': None,
#   'source': 'GTEx',
#   'tissue': {'bg_label': 'blood',
#    'bto': 'BTO:0000089',
#    'uberon': 'UBERON:0000178'},
#   'type': 'Pvalue'},
#  'GTEx_Blood_Vessel_Correlation': {'bg_term': 'blood_vessel',
#   'cancer_type': None,
#   'source': 'GTEx',
#   'tissue': {'bg_label': 'blood_vessel',
#    'bto': 'BTO:0001102',
#    'uberon': 'UBERON:0001981'},
#   'type': 'Correlation'},
#  'GTEx_Blood_Vessel_Pvalue': {'bg_term': 'blood_vessel',
#   'cancer_type': None,
#   'source': 'GTEx',
#   'tissue': {'bg_label': 'blood_vessel',
#    'bto': 'BTO:0001102',
#    'uberon': 'UBERON:0001981'},
#   'type': 'Pvalue'},
#  'GTEx_Brain_Correlation': {'bg_term': 'brain',
#   'cancer_type': None,
#   'source': 'GTEx',
#   'tissue': {'bg_label': 'brain',
#    'bto': 'BTO:0000142',
#    'uberon': 'UBERON:0000955'},
#   'type': 'Correlation'},
#  'GTEx_Brain_Pvalue': {'bg_term': 'brain',
#   'cancer_type': None,
#   'source': 'GTEx',
#   'tissue': {'bg_label': 'brain',
#    'bto': 'BTO:0000142',
#    'uberon': 'UBERON:0000955'},
#   'type': 'Pvalue'},
#  'GTEx_Breast_Correlation': {'bg_term': 'breast',
#   'cancer_type': None,
#   'source': 'GTEx',
#   'tissue': {'bg_label': 'breast',
#    'bto': 'BTO:0000149',
#    'uberon': 'UBERON:0000310'},
#   'type': 'Correlation'},
#  'GTEx_Breast_Pvalue': {'bg_term': 'breast',
#   'cancer_type': None,
#   'source': 'GTEx',
#   'tissue': {'bg_label': 'breast',
#    'bto': 'BTO:0000149',
#    'uberon': 'UBERON:0000310'},
#   'type': 'Pvalue'},
#  'GTEx_Colon_Correlation': {'bg_term': 'colon',
#   'cancer_type': None,
#   'source': 'GTEx',
#   'tissue': {'bg_label': 'colon',
#    'bto': 'BTO:0000269',
#    'uberon': 'UBERON:0001155'},
#   'type': 'Correlation'},
#  'GTEx_Colon_Pvalue': {'bg_term': 'colon',
#   'cancer_type': None,
#   'source': 'GTEx',
#   'tissue': {'bg_label': 'colon',
#    'bto': 'BTO:0000269',
#    'uberon': 'UBERON:0001155'},
#   'type': 'Pvalue'},
#  'GTEx_Esophagus_Correlation': {'bg_term': 'esophagus',
#   'cancer_type': None,
#   'source': 'GTEx',
#   'tissue': {'bg_label': 'esophagus',
#    'bto': 'BTO:0000959',
#    'uberon': 'UBERON:0001043'},
#   'type': 'Correlation'},
#  'GTEx_Esophagus_Pvalue': {'bg_term': 'esophagus',
#   'cancer_type': None,
#   'source': 'GTEx',
#   'tissue': {'bg_label': 'esophagus',
#    'bto': 'BTO:0000959',
#    'uberon': 'UBERON:0001043'},
#   'type': 'Pvalue'},
#  'GTEx_Heart_Correlation': {'bg_term': 'heart',
#   'cancer_type': None,
#   'source': 'GTEx',
#   'tissue': {'bg_label': 'heart',
#    'bto': 'BTO:0000562',
#    'uberon': 'UBERON:0000948'},
#   'type': 'Correlation'},
#  'GTEx_Heart_Pvalue': {'bg_term': 'heart',
#   'cancer_type': None,
#   'source': 'GTEx',
#   'tissue': {'bg_label': 'heart',
#    'bto': 'BTO:0000562',
#    'uberon': 'UBERON:0000948'},
#   'type': 'Pvalue'},
#  'GTEx_Liver_Correlation': {'bg_term': 'liver',
#   'cancer_type': None,
#   'source': 'GTEx',
#   'tissue': {'bg_label': 'liver',
#    'bto': 'BTO:0000759',
#    'uberon': 'UBERON:0002107'},
#   'type': 'Correlation'},
#  'GTEx_Liver_Pvalue': {'bg_term': 'liver',
#   'cancer_type': None,
#   'source': 'GTEx',
#   'tissue': {'bg_label': 'liver',
#    'bto': 'BTO:0000759',
#    'uberon': 'UBERON:0002107'},
#   'type': 'Pvalue'},
#  'GTEx_Lung_Correlation': {'bg_term': 'lung',
#   'cancer_type': None,
#   'source': 'GTEx',
#   'tissue': {'bg_label': 'lung',
#    'bto': 'BTO:0000763',
#    'uberon': 'UBERON:0002048'},
#   'type': 'Correlation'},
#  'GTEx_Lung_Pvalue': {'bg_term': 'lung',
#   'cancer_type': None,
#   'source': 'GTEx',
#   'tissue': {'bg_label': 'lung',
#    'bto': 'BTO:0000763',
#    'uberon': 'UBERON:0002048'},
#   'type': 'Pvalue'},
#  'GTEx_Muscle_Correlation': {'bg_term': 'muscle',
#   'cancer_type': None,
#   'source': 'GTEx',
#   'tissue': {'bg_label': 'muscle',
#    'bto': 'BTO:0000887',
#    'uberon': 'UBERON:0001015'},
#   'type': 'Correlation'},
#  'GTEx_Muscle_Pvalue': {'bg_term': 'muscle',
#   'cancer_type': None,
#   'source': 'GTEx',
#   'tissue': {'bg_label': 'muscle',
#    'bto': 'BTO:0000887',
#    'uberon': 'UBERON:0001015'},
#   'type': 'Pvalue'},
#  'GTEx_Nerve_Correlation': {'bg_term': 'nerve',
#   'cancer_type': None,
#   'source': 'GTEx',
#   'tissue': {'bg_label': 'nerve',
#    'bto': 'BTO:0000925',
#    'uberon': 'UBERON:0001021'},
#   'type': 'Correlation'},
#  'GTEx_Nerve_Pvalue': {'bg_term': 'nerve',
#   'cancer_type': None,
#   'source': 'GTEx',
#   'tissue': {'bg_label': 'nerve',
#    'bto': 'BTO:0000925',
#    'uberon': 'UBERON:0001021'},
#   'type': 'Pvalue'},
#  'GTEx_Pancreas_Correlation': {'bg_term': 'pancreas',
#   'cancer_type': None,
#   'source': 'GTEx',
#   'tissue': {'bg_label': 'pancreas',
#    'bto': 'BTO:0000988',
#    'uberon': 'UBERON:0001264'},
#   'type': 'Correlation'},
#  'GTEx_Pancreas_Pvalue': {'bg_term': 'pancreas',
#   'cancer_type': None,
#   'source': 'GTEx',
#   'tissue': {'bg_label': 'pancreas',
#    'bto': 'BTO:0000988',
#    'uberon': 'UBERON:0001264'},
#   'type': 'Pvalue'},
#  'GTEx_Pituitary_Correlation': {'bg_term': 'pituitary',
#   'cancer_type': None,
#   'source': 'GTEx',
#   'tissue': {'bg_label': 'pituitary', 'bto': None, 'uberon': None},
#   'type': 'Correlation'},
#  'GTEx_Pituitary_Pvalue': {'bg_term': 'pituitary',
#   'cancer_type': None,
#   'source': 'GTEx',
#   'tissue': {'bg_label': 'pituitary', 'bto': None, 'uberon': None},
#   'type': 'Pvalue'},
#  'GTEx_Prostate_Correlation': {'bg_term': 'prostate',
#   'cancer_type': None,
#   'source': 'GTEx',
#   'tissue': {'bg_label': 'prostate', 'bto': None, 'uberon': None},
#   'type': 'Correlation'},
#  'GTEx_Prostate_Pvalue': {'bg_term': 'prostate',
#   'cancer_type': None,
#   'source': 'GTEx',
#   'tissue': {'bg_label': 'prostate', 'bto': None, 'uberon': None},
#   'type': 'Pvalue'},
#  'GTEx_Skin_Correlation': {'bg_term': 'skin',
#   'cancer_type': None,
#   'source': 'GTEx',
#   'tissue': {'bg_label': 'skin',
#    'bto': 'BTO:0001253',
#    'uberon': 'UBERON:0002097'},
#   'type': 'Correlation'},
#  'GTEx_Skin_Pvalue': {'bg_term': 'skin',
#   'cancer_type': None,
#   'source': 'GTEx',
#   'tissue': {'bg_label': 'skin',
#    'bto': 'BTO:0001253',
#    'uberon': 'UBERON:0002097'},
#   'type': 'Pvalue'},
#  'GTEx_Spleen_Correlation': {'bg_term': 'spleen',
#   'cancer_type': None,
#   'source': 'GTEx',
#   'tissue': {'bg_label': 'spleen',
#    'bto': 'BTO:0001281',
#    'uberon': 'UBERON:0002106'},
#   'type': 'Correlation'},
#  'GTEx_Spleen_Pvalue': {'bg_term': 'spleen',
#   'cancer_type': None,
#   'source': 'GTEx',
#   'tissue': {'bg_label': 'spleen',
#    'bto': 'BTO:0001281',
#    'uberon': 'UBERON:0002106'},
#   'type': 'Pvalue'},
#  'GTEx_Stomach_Correlation': {'bg_term': 'stomach',
#   'cancer_type': None,
#   'source': 'GTEx',
#   'tissue': {'bg_label': 'stomach',
#    'bto': 'BTO:0001307',
#    'uberon': 'UBERON:0000945'},
#   'type': 'Correlation'},
#  'GTEx_Stomach_Pvalue': {'bg_term': 'stomach',
#   'cancer_type': None,
#   'source': 'GTEx',
#   'tissue': {'bg_label': 'stomach',
#    'bto': 'BTO:0001307',
#    'uberon': 'UBERON:0000945'},
#   'type': 'Pvalue'},
#  'GTEx_Testis_Correlation': {'bg_term': 'testis',
#   'cancer_type': None,
#   'source': 'GTEx',
#   'tissue': {'bg_label': 'testis',
#    'bto': 'BTO:0001363',
#    'uberon': 'UBERON:0000473'},
#   'type': 'Correlation'},
#  'GTEx_Testis_Pvalue': {'bg_term': 'testis',
#   'cancer_type': None,
#   'source': 'GTEx',
#   'tissue': {'bg_label': 'testis',
#    'bto': 'BTO:0001363',
#    'uberon': 'UBERON:0000473'},
#   'type': 'Pvalue'},
#  'GTEx_Thyroid_Correlation': {'bg_term': 'thyroid',
#   'cancer_type': None,
#   'source': 'GTEx',
#   'tissue': {'bg_label': 'thyroid', 'bto': None, 'uberon': None},
#   'type': 'Correlation'},
#  'GTEx_Thyroid_Pvalue': {'bg_term': 'thyroid',
#   'cancer_type': None,
#   'source': 'GTEx',
#   'tissue': {'bg_label': 'thyroid', 'bto': None, 'uberon': None},
#   'type': 'Pvalue'},
#  'TCGA_ACC_Correlation': {'cancer_type': 'ACC',
#   'source': 'TCGA',
#   'tissue': None,
#   'type': 'Correlation'},
#  'TCGA_ACC_Pvalue': {'cancer_type': 'ACC',
#   'source': 'TCGA',
#   'tissue': None,
#   'type': 'Pvalue'},
#  'TCGA_BLCA_Correlation': {'cancer_type': 'BLCA',
#   'source': 'TCGA',
#   'tissue': None,
#   'type': 'Correlation'},
#  'TCGA_BLCA_Pvalue': {'cancer_type': 'BLCA',
#   'source': 'TCGA',
#   'tissue': None,
#   'type': 'Pvalue'},
#  'TCGA_BRCA_Correlation': {'cancer_type': 'BRCA',
#   'source': 'TCGA',
#   'tissue': None,
#   'type': 'Correlation'},
#  'TCGA_BRCA_Pvalue': {'cancer_type': 'BRCA',
#   'source': 'TCGA',
#   'tissue': None,
#   'type': 'Pvalue'},
#  'TCGA_CESC_Correlation': {'cancer_type': 'CESC',
#   'source': 'TCGA',
#   'tissue': None,
#   'type': 'Correlation'},
#  'TCGA_CESC_Pvalue': {'cancer_type': 'CESC',
#   'source': 'TCGA',
#   'tissue': None,
#   'type': 'Pvalue'},
#  'TCGA_CHOL_Correlation': {'cancer_type': 'CHOL',
#   'source': 'TCGA',
#   'tissue': None,
#   'type': 'Correlation'},
#  'TCGA_CHOL_Pvalue': {'cancer_type': 'CHOL',
#   'source': 'TCGA',
#   'tissue': None,
#   'type': 'Pvalue'},
#  'TCGA_COAD_Correlation': {'cancer_type': 'COAD',
#   'source': 'TCGA',
#   'tissue': None,
#   'type': 'Correlation'},
#  'TCGA_COAD_Pvalue': {'cancer_type': 'COAD',
#   'source': 'TCGA',
#   'tissue': None,
#   'type': 'Pvalue'},
#  'TCGA_DLBC_Correlation': {'cancer_type': 'DLBC',
#   'source': 'TCGA',
#   'tissue': None,
#   'type': 'Correlation'},
#  'TCGA_DLBC_Pvalue': {'cancer_type': 'DLBC',
#   'source': 'TCGA',
#   'tissue': None,
#   'type': 'Pvalue'},
#  'TCGA_ESCA_Correlation': {'cancer_type': 'ESCA',
#   'source': 'TCGA',
#   'tissue': None,
#   'type': 'Correlation'},
#  'TCGA_ESCA_Pvalue': {'cancer_type': 'ESCA',
#   'source': 'TCGA',
#   'tissue': None,
#   'type': 'Pvalue'},
#  'TCGA_GBM_Correlation': {'cancer_type': 'GBM',
#   'source': 'TCGA',
#   'tissue': None,
#   'type': 'Correlation'},
#  'TCGA_GBM_Pvalue': {'cancer_type': 'GBM',
#   'source': 'TCGA',
#   'tissue': None,
#   'type': 'Pvalue'},
#  'TCGA_HNSC_Correlation': {'cancer_type': 'HNSC',
#   'source': 'TCGA',
#   'tissue': None,
#   'type': 'Correlation'},
#  'TCGA_HNSC_Pvalue': {'cancer_type': 'HNSC',
#   'source': 'TCGA',
#   'tissue': None,
#   'type': 'Pvalue'},
#  'TCGA_KICH_Correlation': {'cancer_type': 'KICH',
#   'source': 'TCGA',
#   'tissue': None,
#   'type': 'Correlation'},
#  'TCGA_KICH_Pvalue': {'cancer_type': 'KICH',
#   'source': 'TCGA',
#   'tissue': None,
#   'type': 'Pvalue'},
#  'TCGA_KIRC_Correlation': {'cancer_type': 'KIRC',
#   'source': 'TCGA',
#   'tissue': None,
#   'type': 'Correlation'},
#  'TCGA_KIRC_Pvalue': {'cancer_type': 'KIRC',
#   'source': 'TCGA',
#   'tissue': None,
#   'type': 'Pvalue'},
#  'TCGA_KIRP_Correlation': {'cancer_type': 'KIRP',
#   'source': 'TCGA',
#   'tissue': None,
#   'type': 'Correlation'},
#  'TCGA_KIRP_Pvalue': {'cancer_type': 'KIRP',
#   'source': 'TCGA',
#   'tissue': None,
#   'type': 'Pvalue'},
#  'TCGA_LAML_Correlation': {'cancer_type': 'LAML',
#   'source': 'TCGA',
#   'tissue': None,
#   'type': 'Correlation'},
#  'TCGA_LAML_Pvalue': {'cancer_type': 'LAML',
#   'source': 'TCGA',
#   'tissue': None,
#   'type': 'Pvalue'},
#  'TCGA_LGG_Correlation': {'cancer_type': 'LGG',
#   'source': 'TCGA',
#   'tissue': None,
#   'type': 'Correlation'},
#  'TCGA_LGG_Pvalue': {'cancer_type': 'LGG',
#   'source': 'TCGA',
#   'tissue': None,
#   'type': 'Pvalue'},
#  'TCGA_LIHC_Correlation': {'cancer_type': 'LIHC',
#   'source': 'TCGA',
#   'tissue': None,
#   'type': 'Correlation'},
#  'TCGA_LIHC_Pvalue': {'cancer_type': 'LIHC',
#   'source': 'TCGA',
#   'tissue': None,
#   'type': 'Pvalue'},
#  'TCGA_LUAD_Correlation': {'cancer_type': 'LUAD',
#   'source': 'TCGA',
#   'tissue': None,
#   'type': 'Correlation'},
#  'TCGA_LUAD_Pvalue': {'cancer_type': 'LUAD',
#   'source': 'TCGA',
#   'tissue': None,
#   'type': 'Pvalue'},
#  'TCGA_LUSC_Correlation': {'cancer_type': 'LUSC',
#   'source': 'TCGA',
#   'tissue': None,
#   'type': 'Correlation'},
#  'TCGA_LUSC_Pvalue': {'cancer_type': 'LUSC',
#   'source': 'TCGA',
#   'tissue': None,
#   'type': 'Pvalue'},
#  'TCGA_MESO_Correlation': {'cancer_type': 'MESO',
#   'source': 'TCGA',
#   'tissue': None,
#   'type': 'Correlation'},
#  'TCGA_MESO_Pvalue': {'cancer_type': 'MESO',
#   'source': 'TCGA',
#   'tissue': None,
#   'type': 'Pvalue'},
#  'TCGA_OV_Correlation': {'cancer_type': 'OV',
#   'source': 'TCGA',
#   'tissue': None,
#   'type': 'Correlation'},
#  'TCGA_OV_Pvalue': {'cancer_type': 'OV',
#   'source': 'TCGA',
#   'tissue': None,
#   'type': 'Pvalue'},
#  'TCGA_PAAD_Correlation': {'cancer_type': 'PAAD',
#   'source': 'TCGA',
#   'tissue': None,
#   'type': 'Correlation'},
#  'TCGA_PAAD_Pvalue': {'cancer_type': 'PAAD',
#   'source': 'TCGA',
#   'tissue': None,
#   'type': 'Pvalue'},
#  'TCGA_PCPG_Correlation': {'cancer_type': 'PCPG',
#   'source': 'TCGA',
#   'tissue': None,
#   'type': 'Correlation'},
#  'TCGA_PCPG_Pvalue': {'cancer_type': 'PCPG',
#   'source': 'TCGA',
#   'tissue': None,
#   'type': 'Pvalue'},
#  'TCGA_PRAD_Correlation': {'cancer_type': 'PRAD',
#   'source': 'TCGA',
#   'tissue': None,
#   'type': 'Correlation'},
#  'TCGA_PRAD_Pvalue': {'cancer_type': 'PRAD',
#   'source': 'TCGA',
#   'tissue': None,
#   'type': 'Pvalue'},
#  'TCGA_READ_Correlation': {'cancer_type': 'READ',
#   'source': 'TCGA',
#   'tissue': None,
#   'type': 'Correlation'},
#  'TCGA_READ_Pvalue': {'cancer_type': 'READ',
#   'source': 'TCGA',
#   'tissue': None,
#   'type': 'Pvalue'},
#  'TCGA_SARC_Correlation': {'cancer_type': 'SARC',
#   'source': 'TCGA',
#   'tissue': None,
#   'type': 'Correlation'},
#  'TCGA_SARC_Pvalue': {'cancer_type': 'SARC',
#   'source': 'TCGA',
#   'tissue': None,
#   'type': 'Pvalue'},
#  'TCGA_SKCM_Correlation': {'cancer_type': 'SKCM',
#   'source': 'TCGA',
#   'tissue': None,
#   'type': 'Correlation'},
#  'TCGA_SKCM_Pvalue': {'cancer_type': 'SKCM',
#   'source': 'TCGA',
#   'tissue': None,
#   'type': 'Pvalue'},
#  'TCGA_STAD_Correlation': {'cancer_type': 'STAD',
#   'source': 'TCGA',
#   'tissue': None,
#   'type': 'Correlation'},
#  'TCGA_STAD_Pvalue': {'cancer_type': 'STAD',
#   'source': 'TCGA',
#   'tissue': None,
#   'type': 'Pvalue'},
#  'TCGA_TGCT_Correlation': {'cancer_type': 'TGCT',
#   'source': 'TCGA',
#   'tissue': None,
#   'type': 'Correlation'},
#  'TCGA_TGCT_Pvalue': {'cancer_type': 'TGCT',
#   'source': 'TCGA',
#   'tissue': None,
#   'type': 'Pvalue'},
#  'TCGA_THCA_Correlation': {'cancer_type': 'THCA',
#   'source': 'TCGA',
#   'tissue': None,
#   'type': 'Correlation'},
#  'TCGA_THCA_Pvalue': {'cancer_type': 'THCA',
#   'source': 'TCGA',
#   'tissue': None,
#   'type': 'Pvalue'},
#  'TCGA_THYM_Correlation': {'cancer_type': 'THYM',
#   'source': 'TCGA',
#   'tissue': None,
#   'type': 'Correlation'},
#  'TCGA_THYM_Pvalue': {'cancer_type': 'THYM',
#   'source': 'TCGA',
#   'tissue': None,
#   'type': 'Pvalue'},
#  'TCGA_UCEC_Correlation': {'cancer_type': 'UCEC',
#   'source': 'TCGA',
#   'tissue': None,
#   'type': 'Correlation'},
#  'TCGA_UCEC_Pvalue': {'cancer_type': 'UCEC',
#   'source': 'TCGA',
#   'tissue': None,
#   'type': 'Pvalue'},
#  'TCGA_UCS_Correlation': {'cancer_type': 'UCS',
#   'source': 'TCGA',
#   'tissue': None,
#   'type': 'Correlation'},
#  'TCGA_UCS_Pvalue': {'cancer_type': 'UCS',
#   'source': 'TCGA',
#   'tissue': None,
#   'type': 'Pvalue'},
#  'TCGA_UVM_Correlation': {'cancer_type': 'UVM',
#   'source': 'TCGA',
#   'tissue': None,
#   'type': 'Correlation'},
#  'TCGA_UVM_Pvalue': {'cancer_type': 'UVM',
#   'source': 'TCGA',
#   'tissue': None,
#   'type': 'Pvalue'}}

# %%
th = {
    'a': "itsa",
    'b': "itsb"
}

# %%
remove_kv_pair(th, 'a')
# Out:
# {'b': 'itsb'}

# %%
th
# Out:
# {'a': 'itsa', 'b': 'itsb'}
