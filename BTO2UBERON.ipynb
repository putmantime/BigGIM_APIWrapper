# %%
import requests
from pprint import pprint
import pandas as pd
from ontobio.ontol_factory import OntologyFactory

# %%
# retrieve tissues from BigGIM API (these are BTO Ontology terms with underscores inplace of ' ' and '-')
bg_tissues = requests.get('http://biggim.ncats.io/api/metadata/tissue').json()['tissues']
len(bg_tissues)
# Out:
# 350

# %%
# use ontobio to get mappings from bto and uberon ontologies
ofactory = OntologyFactory()
ub_ont = ofactory.create("uberon")
bto_ont = ofactory.create("bto")

# %%
# create dictionary of bto ids and labels ex: {'brain': BTO:0000142'}
bto_nodes = bto_ont.nodes()
bto_term_label = dict()
for bto in bto_nodes:
    bto_term_label[bto_ont.label(bto)] = bto

# %%
bto_term_label['brain']
# Out:
# 'BTO:0000142'

# %%
def get_ont_xref(xref_id, ont_factory):
    """
    search for xref in given ontology and return an object with the node id and label
    """
    ont_nodes = ont_factory.nodes()
    result = {'id': None, 'label': None}
    for node in ont_nodes:
        if xref_id in ont_factory.xrefs(node):
            result['id'] = node
            result['label'] = ont_factory.label(node)
    return result

# %%
# map bigGIM terms to bto terms/ids, then uberon terms/ids
bto2bg = list()
for tissue in bg_tissues:
    result = {
        'bg_label': tissue,
        'bto_label': None,
        'bto_id': None,
        'uberon_id': None,
        'uberon_label': None
    }
    # ex B_lymphocite -> B lymphocite
    tissue1 = tissue.replace('_', ' ')
    if tissue1 in bto_term_label.keys():
        result['bto_label'] = tissue1
        result['bto_id'] = bto_term_label[tissue1]
        uberon = get_ont_xref(xref_id=bto_term_label[tissue1], ont_factory=ub_ont)
        result['uberon_id'] = uberon['id']
        result['uberon_label'] = uberon['label']
    else:
        # ex: B lymphocite -> B-lymphocite
        tissue2 = tissue1.replace(' ', '-', 1)
        if tissue2 in bto_term_label.keys():
            result['bto_label'] = tissue2
            result['bto_id'] = bto_term_label[tissue2]
            uberon = get_ont_xref(xref_id=bto_term_label[tissue2], ont_factory=ub_ont)
            result['uberon_id'] = uberon['id']
            result['uberon_label'] = uberon['label']
    bto2bg.append(result)
with open('bto_uberon_bg.json', 'w') as outfile:
    json.dump(bto2bg, outfile)

# %%
bto_df
# Out:
#                            bto_label       bto_id  \
# 0                       B-lymphocyte  BTO:0000776
# 1               B-lymphoma cell line  BTO:0001518
# 2                       T-lymphocyte  BTO:0000782
# 3        acute myeloid leukemia cell  BTO:0001545
# 4                adenocarcinoma cell  BTO:0000604
# 5                     adipose tissue  BTO:0001487
# 6                     adrenal cortex  BTO:0000045
# 7                      adrenal gland  BTO:0000047
# 8          adrenal gland cancer cell  BTO:0000592
# 9      adrenocortical carcinoma cell  BTO:0002219
# 10                   adult stem cell  BTO:0002666
# 11                  alimentary canal  BTO:0000058
# 12                          amygdala  BTO:0001042
# 13                            animal  BTO:0000042
# 14                             aorta  BTO:0000135
# 15                            artery  BTO:0000573
# 16                        astroblast  BTO:0000098
# 17                         astrocyte  BTO:0000099
# 18                  astrocytoma cell  BTO:0000100
# 19                         astroglia  BTO:0003852
# 20                   astroglial cell  BTO:0002609
# 21                     avian pallium  BTO:0003399
# 22                    basal ganglion  BTO:0000235
# 23                          basophil  BTO:0000129
# 24                         bile duct  BTO:0000122
# 25              bile duct epithelium  BTO:0000417
# 26                biliary epithelium  BTO:0001513
# 27                           bladder  BTO:0000123
# 28                        blast cell  BTO:0000125
# 29                        blastomere  BTO:0001473
# ..                               ...          ...
# 320                            tooth  BTO:0000397
# 321                          trachea  BTO:0001388
# 322                      trophoblast  BTO:0001079
# 323                            trunk  BTO:0001493
# 324                   umbilical cord  BTO:0001415
# 325                   umbilical vein  BTO:0001509
# 326  umbilical vein endothelial cell  BTO:0004296
# 327       umbilical vein endothelium  BTO:0001416
# 328                  urinary bladder  BTO:0001418
# 329      urinary bladder cancer cell  BTO:0000362
# 330                   urinary system  BTO:0003092
# 331                    urinary tract  BTO:0001244
# 332                    uroepithelium  BTO:0003906
# 333                urogenital system  BTO:0003091
# 334              uterine cancer cell  BTO:0000257
# 335                   uterine cervix  BTO:0001421
# 336              uterine endometrium  BTO:0001422
# 337             uterine sarcoma cell  BTO:0003596
# 338                           uterus  BTO:0001424
# 339              uveal melanoma cell  BTO:0004980
# 340        vascular endothelial cell  BTO:0001854
# 341             vascular endothelium  BTO:0001853
# 342                  vascular system  BTO:0001085
# 343               vermiform appendix  BTO:0000084
# 344       vertebrate muscular system  BTO:0001369
# 345             vestibular labyrinth  BTO:0001856
# 346                vestibular system  BTO:0003381
# 347                           viscus  BTO:0001491
# 348                       whole body  BTO:0001489
# 349                           zygote  BTO:0000854
#
#                             bg_label       uberon_id  \
# 0                       B_lymphocyte            None
# 1               B_lymphoma_cell_line            None
# 2                       T_lymphocyte            None
# 3        acute_myeloid_leukemia_cell            None
# 4                adenocarcinoma_cell            None
# 5                     adipose_tissue  UBERON:0001013
# 6                     adrenal_cortex  UBERON:0001235
# 7                      adrenal_gland  UBERON:0002369
# 8          adrenal_gland_cancer_cell            None
# 9      adrenocortical_carcinoma_cell            None
# 10                   adult_stem_cell            None
# 11                  alimentary_canal  UBERON:0005409
# 12                          amygdala  UBERON:0001876
# 13                            animal  UBERON:0000468
# 14                             aorta  UBERON:0000947
# 15                            artery  UBERON:0001637
# 16                        astroblast            None
# 17                         astrocyte            None
# 18                  astrocytoma_cell            None
# 19                         astroglia            None
# 20                   astroglial_cell            None
# 21                     avian_pallium  UBERON:0000203
# 22                    basal_ganglion  UBERON:0002420
# 23                          basophil            None
# 24                         bile_duct  UBERON:0002394
# 25              bile_duct_epithelium  UBERON:0004820
# 26                biliary_epithelium  UBERON:0034932
# 27                           bladder  UBERON:0018707
# 28                        blast_cell            None
# 29                        blastomere            None
# ..                               ...             ...
# 320                            tooth  UBERON:0001091
# 321                          trachea  UBERON:0003126
# 322                      trophoblast  UBERON:0000088
# 323                            trunk  UBERON:0002100
# 324                   umbilical_cord  UBERON:0002331
# 325                   umbilical_vein  UBERON:0002066
# 326  umbilical_vein_endothelial_cell            None
# 327       umbilical_vein_endothelium  UBERON:0007777
# 328                  urinary_bladder  UBERON:0001255
# 329      urinary_bladder_cancer_cell            None
# 330                   urinary_system  UBERON:0001008
# 331                    urinary_tract  UBERON:0001008
# 332                    uroepithelium  UBERON:0000365
# 333                urogenital_system  UBERON:0004122
# 334              uterine_cancer_cell            None
# 335                   uterine_cervix  UBERON:0000002
# 336              uterine_endometrium  UBERON:0001295
# 337             uterine_sarcoma_cell            None
# 338                           uterus  UBERON:0000995
# 339              uveal_melanoma_cell            None
# 340        vascular_endothelial_cell            None
# 341             vascular_endothelium  UBERON:0004852
# 342                  vascular_system  UBERON:0007798
# 343               vermiform_appendix  UBERON:0001154
# 344       vertebrate_muscular_system  UBERON:0000383
# 345             vestibular_labyrinth  UBERON:0001862
# 346                vestibular_system  UBERON:0004681
# 347                           viscus  UBERON:0002075
# 348                       whole_body  UBERON:0013702
# 349                           zygote            None
#
#                                    uberon_label
# 0                                          None
# 1                                          None
# 2                                          None
# 3                                          None
# 4                                          None
# 5                                adipose tissue
# 6                                adrenal cortex
# 7                                 adrenal gland
# 8                                          None
# 9                                          None
# 10                                         None
# 11   alimentary part of gastrointestinal system
# 12                                     amygdala
# 13                       multicellular organism
# 14                                        aorta
# 15                                       artery
# 16                                         None
# 17                                         None
# 18                                         None
# 19                                         None
# 20                                         None
# 21                                      pallium
# 22                               basal ganglion
# 23                                         None
# 24                                    bile duct
# 25                         bile duct epithelium
# 26                 epithelium of biliary system
# 27                                bladder organ
# 28                                         None
# 29                                         None
# ..                                          ...
# 320                            calcareous tooth
# 321                                     trachea
# 322                                 trophoblast
# 323                                       trunk
# 324                              umbilical cord
# 325                              umbilical vein
# 326                                        None
# 327                  umbilical vein endothelium
# 328                             urinary bladder
# 329                                        None
# 330                                renal system
# 331                                renal system
# 332                                  urothelium
# 333                        genitourinary system
# 334                                        None
# 335                              uterine cervix
# 336                                 endometrium
# 337                                        None
# 338                                      uterus
# 339                                        None
# 340                                        None
# 341           cardiovascular system endothelium
# 342                             vascular system
# 343                          vermiform appendix
# 344                         musculature of body
# 345                        vestibular labyrinth
# 346                           vestibular system
# 347                                      viscus
# 348                                 body proper
# 349                                        None
#
# [350 rows x 5 columns]
